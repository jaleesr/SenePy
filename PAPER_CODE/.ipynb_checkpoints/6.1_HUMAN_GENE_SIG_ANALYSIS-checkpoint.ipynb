# %%
import scanpy as sc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from matplotlib.pyplot import rc_context
from tqdm import tqdm
#from scipy.optimize import curve_fit

#import scvi
import pickle
from adjustText import adjust_text

import itertools
#from numba import jit

import gseapy as gp
import random

# %%
adata = sc.concat((sc.read_h5ad('/home/jrlab/Downloads/HUMAN_CELLS_MS0203.h5ad')
                   ,sc.read_h5ad('/home/jrlab/Downloads/TS_harmonized.h5ad')))

hippo = sc.read_h5ad('/home/jrlab/Downloads/human_hippo_harmonized.h5ad')

# %% [markdown]
# # Signatures

# %%
import senepy as sp

sigs = sp.load_hubs(species = 'Human', sig_type = 'cell_type')

# %%
signatures = sigs.hubs

# %%
sig_metadata = sigs.metadata

# %%
all_genes_redundant = []

for x in list(signatures):
    all_genes_redundant += [x[0] for x in signatures[x]]

# %%
all_genes_nr = list(set(all_genes_redundant))

# %%
len(all_genes_nr)
# Out:
# 13730

# %%
out = []
for gene in all_genes_nr:
    out.append([gene, all_genes_redundant.count(gene)])

# %%
mcs = pd.DataFrame(out, columns = ['gene', 'Count']).sort_values('Count', ascending = False)
mcs
# Out:
#          gene  Count
# 8616     MYL9     14
# 12063    MMP9     13
# 8894      LTF     12
# 9217    PCSK6     12
# 4877    CALD1     11
# ...       ...    ...
# 6924    DEDD2      1
# 6923   LURAP1      1
# 6922    ARL14      1
# 6914    SYT16      1
# 13729   PYDC1      1
#
# [13730 rows x 2 columns]

# %%
all_genes_redundant.count('CDKN2A')
# Out:
# 8

# %%
#random distribution of gene commonality counts. ie, how many hubs were a gene in by chance

out = []
for x in tqdm(range(10000)):
    
    all_genes_redundant_temp = []
    for y in range(len(sig_metadata)):
        s = sig_metadata.iloc[y].size
        l = random.choices(adata.var_names, k = s)
        all_genes_redundant_temp += l
            
    all_genes_nr_temp = list(set(all_genes_redundant_temp))
    

    for gene in all_genes_nr_temp:
        out += [all_genes_redundant.count(gene)]
# Out:
#   3%|█▏                                     | 314/10000 [00:30<15:44, 10.26it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 16
#      12 all_genes_nr_temp = list(set(all_genes_redundant_temp))
#      15 for gene in all_genes_nr_temp:
# ---> 16     out += [all_genes_redundant.count(gene)]
#
# KeyboardInterrupt:

# %%
out = np.array(out)

# %%
def calc_mcg_p(x):
    return len(out[out >= x])/len(out)

mcs['p'] = mcs['Count'].map(calc_mcg_p)

# %%
mcs
# Out:
#            gene  Count         p
# 12533      MYL9     14  0.000050
# 4108       MMP9     13  0.000094
# 7024      PCSK6     12  0.000194
# 10827       LTF     12  0.000194
# 4587       POLE     11  0.000457
# ...         ...    ...       ...
# 10157      RPL3      1  0.609470
# 1968       KNG1      1  0.609470
# 6972      SGMS1      1  0.609470
# 10152  C16orf86      1  0.609470
# 4907     NKAPP1      1  0.609470
#
# [13730 rows x 3 columns]

# %%
len(signatures)
# Out:
# 50

# %%
mcs[mcs.Count >= 8]
# Out:
#            gene  Count         p
# 12533      MYL9     14  0.000050
# 4108       MMP9     13  0.000094
# 7024      PCSK6     12  0.000194
# 10827       LTF     12  0.000194
# 4587       POLE     11  0.000457
# ...         ...    ...       ...
# 11711     CCNB1      8  0.009656
# 9485       BLNK      8  0.009656
# 2312   MTRNR2L1      8  0.009656
# 387      PIK3R4      8  0.009656
# 1947      FUCA2      8  0.009656
#
# [211 rows x 3 columns]

# %%
#mcs.to_pickle('../data/files/6.1_mcs.pickle')

# %%
mcs = pd.read_pickle('../data/files/6.1_mcs.pickle')

# %%
mcs['nlogp'] = -np.log10(mcs.p)
mcs['prev'] = mcs.Count/len(signatures) * 100

# %%
mcs[mcs.Count >= 6]
# Out:
#          gene  Count         p     nlogp  prev
# 12533    MYL9     14  0.000050  4.298497  28.0
# 4108     MMP9     13  0.000094  4.026191  26.0
# 7024    PCSK6     12  0.000194  3.711460  24.0
# 10827     LTF     12  0.000194  3.711460  24.0
# 4587     POLE     11  0.000457  3.339646  22.0
# ...       ...    ...       ...       ...   ...
# 7646     NCF2      6  0.043382  1.362687  12.0
# 5145    ZFP30      6  0.043382  1.362687  12.0
# 5004     OLR1      6  0.043382  1.362687  12.0
# 5968    RBBP8      6  0.043382  1.362687  12.0
# 3496   POLR2E      6  0.043382  1.362687  12.0
#
# [947 rows x 5 columns]

# %%
sub = mcs[:30]

new_row = {'gene': '4% chance', 'Count': 6, 'p': 0.043382, 'nlogp':1.362687, 'prev':12.0}

# append the new row to the DataFrame
sub = pd.concat((sub, pd.DataFrame([new_row])))

# %% [markdown]
# ### Fig 4E

# %%
import matplotlib as mpl
from matplotlib import cm

fig, ax = plt.subplots(figsize = (0.3, 2))

cmap = mpl.cm.cool
#norm = mpl.colors.Normalize(vmin = sub.p.min(), vmax = sub.p.max())
norm = mpl.colors.Normalize(vmin = sub.nlogp.min(), vmax = sub.nlogp.max())

mapper = cm.ScalarMappable(norm = norm, cmap = cm.cool)

cbl = mpl.colorbar.ColorbarBase(ax, cmap = cmap, norm = norm, orientation = 'vertical')

#plt.savefig('figures/4E_pt2.png', dpi = 600, bbox_inches = 'tight')
#plt.savefig('figures/4E_pt2.svg', bbox_inches = 'tight')

# %%
plt.figure(figsize = (2.5,6.2))

ax = sns.barplot(data = sub, x = 'prev', y = 'gene', palette = mapper.to_rgba(sub.nlogp.values),
                edgecolor = 'k', lw = 1.5)

plt.yticks(size = 11, weight = 'bold')
plt.xticks(size = 11, weight = 'bold')


for axis in ['bottom', 'left', 'top', 'right']:
    ax.spines[axis].set_linewidth(1.5)
    
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)

ax.tick_params(width = 1.5, color = '0.2')


plt.xlabel("Signature prevalence (%)", size = 11, weight = 'bold')
plt.ylabel('')

plt.savefig('figures/4E_pt1.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4E_pt1.svg', bbox_inches = 'tight')

plt.show()
# Out:
# /tmp/ipykernel_1846983/3857983375.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = sub, x = 'prev', y = 'gene', palette = mapper.to_rgba(sub.nlogp.values),
# /tmp/ipykernel_1846983/3857983375.py:3: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   ax = sns.barplot(data = sub, x = 'prev', y = 'gene', palette = mapper.to_rgba(sub.nlogp.values),

# %%
mcs[mcs.Count >= 6] #ie, pvalue < 0.05
# Out:
#          gene  Count         p     nlogp  prev
# 12533    MYL9     14  0.000050  4.298497  28.0
# 4108     MMP9     13  0.000094  4.026191  26.0
# 7024    PCSK6     12  0.000194  3.711460  24.0
# 10827     LTF     12  0.000194  3.711460  24.0
# 4587     POLE     11  0.000457  3.339646  22.0
# ...       ...    ...       ...       ...   ...
# 7646     NCF2      6  0.043382  1.362687  12.0
# 5145    ZFP30      6  0.043382  1.362687  12.0
# 5004     OLR1      6  0.043382  1.362687  12.0
# 5968    RBBP8      6  0.043382  1.362687  12.0
# 3496   POLR2E      6  0.043382  1.362687  12.0
#
# [947 rows x 5 columns]

# %%
enr = gp.enrichr(gene_list= mcs[mcs.Count >= 6].gene,
             gene_sets=['KEGG_2019_Human', 'GO_Biological_Process_2021'],
             organism='human', # don't forget to set organism to the one you desired!
             outdir=None, # don't write to disk,
             background = adata.var_names.tolist()
            )

# %%
uni_enr = enr.results

# %%
res = uni_enr[uni_enr['Adjusted P-value'] < 0.05].sort_values('Adjusted P-value').reset_index(drop = True)
res['nlog10'] = -np.log10(res['Adjusted P-value'])

res = res[res.Gene_set == 'KEGG_2019_Human']

# %% [markdown]
# ### Fig 4F

# %%
plt.figure(figsize = (3,3.5))

ax = sns.barplot(data = res[0:15], x = 'nlog10', y = 'Term', color = 'grey', edgecolor = 'k', lw = 1)


plt.ylabel('')
plt.xlabel("-$log_{10}$ FDR", size = 12)

plt.savefig('figures/4F.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4F.svg', bbox_inches = 'tight')

plt.show()

# %%
#there are interesting GO pathways too

# %%
out = []


for hub in tqdm(list(signatures)):
    
    
    if hub[0] == 'hippocampus':
        var_names = hippo.var_names.tolist()
    else:
        var_names = adata.var_names.tolist()
    
    

    test = signatures[hub]

    test = [x[0] for x in test]


    for i in range(0,10):
        try:
            enr = gp.enrichr(gene_list= test,
                         gene_sets=['KEGG_2021_Human', 'GO_Biological_Process_2021', 'WikiPathways_2019_Human'],
                         organism='human', # don't forget to set organism to the one you desired!
                         outdir=None, # don't write to disk,
                         background = var_names
                        )
            break
        except:
            pass
        

    res = enr.results

    res = res[res['Adjusted P-value'] <= 0.05].reset_index(drop = True)
    
    
    res['tissue'] = hub[0]
    res['cell'] = hub[1]
    
    out.append(res)
# Out:
#  18%|███████▉                                    | 9/50 [00:26<01:25,  2.08s/it]

# %%
df = pd.concat(out)

df = df[df.Gene_set != 'WikiPathways_2019_Human'] #some redundancy with GO

# %%
#remove some reduntant GO pathways

removal = [
    'neutrophil degranulation (GO:0043312)',
    'neutrophil activation involved in immune response (GO:0002283)'
]

df = df[~df.Term.isin(removal)]

df
# Out:
#                       Gene_set  \
# 0              KEGG_2021_Human
# 0              KEGG_2021_Human
# 1              KEGG_2021_Human
# 2   GO_Biological_Process_2021
# 3   GO_Biological_Process_2021
# ..                         ...
# 88  GO_Biological_Process_2021
# 89  GO_Biological_Process_2021
# 90  GO_Biological_Process_2021
# 91  GO_Biological_Process_2021
# 92  GO_Biological_Process_2021
#
#                                                  Term       P-value  \
# 0                    Herpes simplex virus 1 infection  6.509745e-13
# 0   Viral protein interaction with cytokine and cy...  2.630322e-04
# 1                                 Platelet activation  7.259275e-04
# 2                 platelet degranulation (GO:0002576)  2.354752e-09
# 3                   regulated exocytosis (GO:0045055)  8.159535e-08
# ..                                                ...           ...
# 88         activation of GTPase activity (GO:0090630)  6.393474e-04
# 89  antigen processing and presentation of exogeno...  6.764156e-04
# 90  antigen processing and presentation of peptide...  6.764156e-04
# 91  positive regulation of cytokine production (GO...  7.008571e-04
# 92         regulation of GTPase activity (GO:0043087)  7.305166e-04
#
#     Adjusted P-value  Old P-value  Old adjusted P-value  Odds Ratio  \
# 0       1.881316e-10            0                     0    2.999669
# 0       3.103780e-02            0                     0    9.591946
# 1       4.282972e-02            0                     0    7.598926
# 2       2.554906e-06            0                     0   16.565027
# 3       4.426548e-05            0                     0   11.115773
# ..               ...          ...                   ...         ...
# 88      4.460678e-02            0                     0    2.494424
# 89      4.578425e-02            0                     0    2.553793
# 90      4.578425e-02            0                     0    2.553793
# 91      4.674099e-02            0                     0    1.738701
# 92      4.801294e-02            0                     0    2.033241
#
#     Combined Score                                              Genes  tissue  \
# 0        84.171639  ZNF571;ZNF570;ZNF250;ITGB3;ZFP82;ZNF808;ZNF81;...   blood
# 0        79.068654                    CCL4;TNFRSF10C;CCL3;CXCL5;PF4V1   blood
# 1        54.925496                           GP9;ITGB3;F2R;GP1BA;MYLK   blood
# 2       329.094571  SELP;ABCC4;ORM1;MMRN1;PROS1;ITGB3;ENDOD1;PDGFA...   blood
# 3       181.426020  SELP;ABCC4;ORM1;MMRN1;ITGB3;PROS1;ENDOD1;PDGFA...   blood
# ..             ...                                                ...     ...
# 88       18.346648  RAP1GAP2;ARHGEF10;ARHGEF26;GPR65;RALGAPA2;CCDC...  tongue
# 89       18.639374  CTSV;CTSS;KIF15;KIF18A;PIKFYVE;KLC2;HLA-DMB;RA...  tongue
# 90       18.639374  CTSV;CTSS;KIF15;KIF18A;PIKFYVE;KLC2;HLA-DMB;RA...  tongue
# 91       12.628545  PTGER4;CD274;CD40;PTPN22;NOD2;PTGS2;TNF;HMOX1;...  tongue
# 92       14.683578  RTN4R;ARHGAP11A;CD40;DOCK8;LRRK2;RGS16;ASAP3;S...  tongue
#
#              cell
# 0   memory b cell
# 0        monocyte
# 1        monocyte
# 2        monocyte
# 3        monocyte
# ..            ...
# 88     basal cell
# 89     basal cell
# 90     basal cell
# 91     basal cell
# 92     basal cell
#
# [5861 rows x 11 columns]

# %%
top_20 = df.groupby('Term').count().sort_values('Gene_set', ascending = False)[0:20]

order_d = dict(zip(top_20.index, range(20)))

overlap_d = dict(zip(top_20.index, top_20.Gene_set))

top_20
# Out:
#                                                     Gene_set  P-value  \
# Term
# neutrophil mediated immunity (GO:0002446)                 14       14
# inflammatory response (GO:0006954)                        13       13
# cellular response to cytokine stimulus (GO:0071...        12       12
# Human T-cell leukemia virus 1 infection                   12       12
# cytokine-mediated signaling pathway (GO:0019221)          12       12
# Hematopoietic cell lineage                                11       11
# regulation of immune response (GO:0050776)                11       11
# Osteoclast differentiation                                11       11
# DNA repair (GO:0006281)                                   10       10
# regulation of cell migration (GO:0030334)                 10       10
# platelet degranulation (GO:0002576)                       10       10
# Rheumatoid arthritis                                      10       10
# cellular protein modification process (GO:0006464)        10       10
# extracellular matrix organization (GO:0030198)            10       10
# Influenza A                                               10       10
# positive regulation of cellular process (GO:004...        10       10
# DNA metabolic process (GO:0006259)                        10       10
# regulation of transcription, DNA-templated (GO:...         9        9
# DNA replication (GO:0006260)                               9        9
# Prion disease                                              9        9
#
#                                                     Adjusted P-value  \
# Term
# neutrophil mediated immunity (GO:0002446)                         14
# inflammatory response (GO:0006954)                                13
# cellular response to cytokine stimulus (GO:0071...                12
# Human T-cell leukemia virus 1 infection                           12
# cytokine-mediated signaling pathway (GO:0019221)                  12
# Hematopoietic cell lineage                                        11
# regulation of immune response (GO:0050776)                        11
# Osteoclast differentiation                                        11
# DNA repair (GO:0006281)                                           10
# regulation of cell migration (GO:0030334)                         10
# platelet degranulation (GO:0002576)                               10
# Rheumatoid arthritis                                              10
# cellular protein modification process (GO:0006464)                10
# extracellular matrix organization (GO:0030198)                    10
# Influenza A                                                       10
# positive regulation of cellular process (GO:004...                10
# DNA metabolic process (GO:0006259)                                10
# regulation of transcription, DNA-templated (GO:...                 9
# DNA replication (GO:0006260)                                       9
# Prion disease                                                      9
#
#                                                     Old P-value  \
# Term
# neutrophil mediated immunity (GO:0002446)                    14
# inflammatory response (GO:0006954)                           13
# cellular response to cytokine stimulus (GO:0071...           12
# Human T-cell leukemia virus 1 infection                      12
# cytokine-mediated signaling pathway (GO:0019221)             12
# Hematopoietic cell lineage                                   11
# regulation of immune response (GO:0050776)                   11
# Osteoclast differentiation                                   11
# DNA repair (GO:0006281)                                      10
# regulation of cell migration (GO:0030334)                    10
# platelet degranulation (GO:0002576)                          10
# Rheumatoid arthritis                                         10
# cellular protein modification process (GO:0006464)           10
# extracellular matrix organization (GO:0030198)               10
# Influenza A                                                  10
# positive regulation of cellular process (GO:004...           10
# DNA metabolic process (GO:0006259)                           10
# regulation of transcription, DNA-templated (GO:...            9
# DNA replication (GO:0006260)                                  9
# Prion disease                                                 9
#
#                                                     Old adjusted P-value  \
# Term
# neutrophil mediated immunity (GO:0002446)                             14
# inflammatory response (GO:0006954)                                    13
# cellular response to cytokine stimulus (GO:0071...                    12
# Human T-cell leukemia virus 1 infection                               12
# cytokine-mediated signaling pathway (GO:0019221)                      12
# Hematopoietic cell lineage                                            11
# regulation of immune response (GO:0050776)                            11
# Osteoclast differentiation                                            11
# DNA repair (GO:0006281)                                               10
# regulation of cell migration (GO:0030334)                             10
# platelet degranulation (GO:0002576)                                   10
# Rheumatoid arthritis                                                  10
# cellular protein modification process (GO:0006464)                    10
# extracellular matrix organization (GO:0030198)                        10
# Influenza A                                                           10
# positive regulation of cellular process (GO:004...                    10
# DNA metabolic process (GO:0006259)                                    10
# regulation of transcription, DNA-templated (GO:...                     9
# DNA replication (GO:0006260)                                           9
# Prion disease                                                          9
#
#                                                     Odds Ratio  \
# Term
# neutrophil mediated immunity (GO:0002446)                   14
# inflammatory response (GO:0006954)                          13
# cellular response to cytokine stimulus (GO:0071...          12
# Human T-cell leukemia virus 1 infection                     12
# cytokine-mediated signaling pathway (GO:0019221)            12
# Hematopoietic cell lineage                                  11
# regulation of immune response (GO:0050776)                  11
# Osteoclast differentiation                                  11
# DNA repair (GO:0006281)                                     10
# regulation of cell migration (GO:0030334)                   10
# platelet degranulation (GO:0002576)                         10
# Rheumatoid arthritis                                        10
# cellular protein modification process (GO:0006464)          10
# extracellular matrix organization (GO:0030198)              10
# Influenza A                                                 10
# positive regulation of cellular process (GO:004...          10
# DNA metabolic process (GO:0006259)                          10
# regulation of transcription, DNA-templated (GO:...           9
# DNA replication (GO:0006260)                                 9
# Prion disease                                                9
#
#                                                     Combined Score  Genes  \
# Term
# neutrophil mediated immunity (GO:0002446)                       14     14
# inflammatory response (GO:0006954)                              13     13
# cellular response to cytokine stimulus (GO:0071...              12     12
# Human T-cell leukemia virus 1 infection                         12     12
# cytokine-mediated signaling pathway (GO:0019221)                12     12
# Hematopoietic cell lineage                                      11     11
# regulation of immune response (GO:0050776)                      11     11
# Osteoclast differentiation                                      11     11
# DNA repair (GO:0006281)                                         10     10
# regulation of cell migration (GO:0030334)                       10     10
# platelet degranulation (GO:0002576)                             10     10
# Rheumatoid arthritis                                            10     10
# cellular protein modification process (GO:0006464)              10     10
# extracellular matrix organization (GO:0030198)                  10     10
# Influenza A                                                     10     10
# positive regulation of cellular process (GO:004...              10     10
# DNA metabolic process (GO:0006259)                              10     10
# regulation of transcription, DNA-templated (GO:...               9      9
# DNA replication (GO:0006260)                                     9      9
# Prion disease                                                    9      9
#
#                                                     tissue  cell
# Term
# neutrophil mediated immunity (GO:0002446)               14    14
# inflammatory response (GO:0006954)                      13    13
# cellular response to cytokine stimulus (GO:0071...      12    12
# Human T-cell leukemia virus 1 infection                 12    12
# cytokine-mediated signaling pathway (GO:0019221)        12    12
# Hematopoietic cell lineage                              11    11
# regulation of immune response (GO:0050776)              11    11
# Osteoclast differentiation                              11    11
# DNA repair (GO:0006281)                                 10    10
# regulation of cell migration (GO:0030334)               10    10
# platelet degranulation (GO:0002576)                     10    10
# Rheumatoid arthritis                                    10    10
# cellular protein modification process (GO:0006464)      10    10
# extracellular matrix organization (GO:0030198)          10    10
# Influenza A                                             10    10
# positive regulation of cellular process (GO:004...      10    10
# DNA metabolic process (GO:0006259)                      10    10
# regulation of transcription, DNA-templated (GO:...       9     9
# DNA replication (GO:0006260)                             9     9
# Prion disease                                            9     9

# %%
def fix_term(x):
    if '(GO:' in x:
        return ' '.join(x.split(' ')[0:-1])
                        
    if x.split(' ')[-1].startswith('WP'):
        return ' '.join(x.split(' ')[0:-1])
                        
    else:
        return x
    
to_graph = df[df.Term.isin(top_20.index)]


to_graph['nlog10p'] = -np.log10(to_graph['Adjusted P-value'])

to_graph['Orderer'] = to_graph.Term.map(order_d)

to_graph = to_graph.sort_values('Orderer')


to_graph['Overlap'] = to_graph.Term.map(overlap_d)

to_graph['frac'] = to_graph['Overlap']/len(signatures) * 100


to_graph['term2'] = to_graph.Term.map(fix_term)

cell_type_2_annotations = pd.read_csv('../data/annotations/human/cell_classes.csv')

class_d = dict(zip(cell_type_2_annotations.cell_type_2, cell_type_2_annotations['class']))

to_graph['Class'] = to_graph.cell.map(class_d)

#cap at 10, make sure to put >= 10 in figure

to_graph['nlog10p'][to_graph['nlog10p'] > 10] = 10
# Out:
# /tmp/ipykernel_1846983/1752835246.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['nlog10p'] = -np.log10(to_graph['Adjusted P-value'])
# /tmp/ipykernel_1846983/1752835246.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['Orderer'] = to_graph.Term.map(order_d)
# /tmp/ipykernel_1846983/1752835246.py:36: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   to_graph['nlog10p'][to_graph['nlog10p'] > 10] = 10
# /tmp/ipykernel_1846983/1752835246.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['nlog10p'][to_graph['nlog10p'] > 10] = 10

# %%
to_graph
# Out:
#                       Gene_set                                       Term  \
# 84  GO_Biological_Process_2021  neutrophil mediated immunity (GO:0002446)
# 19  GO_Biological_Process_2021  neutrophil mediated immunity (GO:0002446)
# 46  GO_Biological_Process_2021  neutrophil mediated immunity (GO:0002446)
# 86  GO_Biological_Process_2021  neutrophil mediated immunity (GO:0002446)
# 68  GO_Biological_Process_2021  neutrophil mediated immunity (GO:0002446)
# ..                         ...                                        ...
# 64             KEGG_2021_Human                              Prion disease
# 28             KEGG_2021_Human                              Prion disease
# 3              KEGG_2021_Human                              Prion disease
# 17             KEGG_2021_Human                              Prion disease
# 4              KEGG_2021_Human                              Prion disease
#
#          P-value  Adjusted P-value  Old P-value  Old adjusted P-value  \
# 84  4.072931e-03      3.882012e-02            0                     0
# 19  1.828043e-04      3.430626e-02            0                     0
# 46  2.782041e-05      2.806694e-03            0                     0
# 86  4.289402e-17      2.217621e-14            0                     0
# 68  1.386451e-07      1.694936e-04            0                     0
# ..           ...               ...          ...                   ...
# 64  1.211093e-02      4.943355e-02            0                     0
# 28  6.162164e-03      4.802238e-02            0                     0
# 3   6.085686e-08      2.966772e-06            0                     0
# 17  1.904648e-02      4.655806e-02            0                     0
# 4   5.501779e-03      4.401423e-02            0                     0
#
#     Odds Ratio  Combined Score  \
# 84    6.866516       37.789131
# 19    2.019620       17.383061
# 46    3.449929       36.188857
# 86    2.500988       94.256730
# 68    3.491680       55.138338
# ..         ...             ...
# 64    2.404369       10.612036
# 28    3.081871       15.684650
# 3     5.964680       99.101610
# 17   10.403776       41.208038
# 4     9.180821       47.764908
#
#                                                 Genes       tissue  \
# 84                                 DSP;AGL;ITGB2;CD44        liver
# 19  CFD;FCN1;CYFIP1;GRN;ITGAM;RETN;AP2A2;MPO;CTSG;...  bone marrow
# 46  GRN;HEXB;SLC11A1;C5AR1;PLAUR;FPR1;LILRB3;SLC2A...        heart
# 86  CYFIP1;GHDC;TMEM179B;PYCARD;PSMD6;PSMD7;PSMD2;...    intestine
# 68  RAB5C;SERPINA1;HEXB;CTSS;PLAC8;CYB5R3;ANPEP;OR...    intestine
# ..                                                ...          ...
# 64  C1QB;C1QA;KLC4;CREB3L3;NCF1;CREB3L2;ITPR3;UQCR...    intestine
# 28     C1QB;C1QA;TUBB6;NCF4;UQCRC1;COX6A2;COX7A1;C1QC        heart
# 3   NDUFA8;NDUFB10;ADRM1;UQCRHL;PSMD8;PSMD9;TUBA1C...       kidney
# 17                                      COX6A2;COX7A1        heart
# 4                                          C8G;C6;C8A        liver
#
#                 cell    nlog10p  Orderer  Overlap  frac  \
# 84  endothelial cell   1.410943        0       14  28.0
# 19            t cell   1.464627        0       14  28.0
# 46     lymphoid cell   2.551805        0       14  28.0
# 86        macrophage  10.000000        0       14  28.0
# 68       plasma cell   3.770847        0       14  28.0
# ..               ...        ...      ...      ...   ...
# 64       plasma cell   1.305978       19        9  18.0
# 28     lymphoid cell   1.318556       19        9  18.0
# 3         macrophage   5.527716       19        9  18.0
# 17      myeloid cell   1.332005       19        9  18.0
# 4           monocyte   1.356407       19        9  18.0
#
#                            term2        Class
# 84  neutrophil mediated immunity  endothelial
# 19  neutrophil mediated immunity       immune
# 46  neutrophil mediated immunity       immune
# 86  neutrophil mediated immunity       immune
# 68  neutrophil mediated immunity       immune
# ..                           ...          ...
# 64                 Prion disease       immune
# 28                 Prion disease       immune
# 3                  Prion disease       immune
# 17                 Prion disease       immune
# 4                  Prion disease       immune
#
# [213 rows x 17 columns]

# %% [markdown]
# ### Figure 4G

# %%
plt.figure(figsize = (4, 7))

#ax = sns.barplot(data = to_graph, x = 'nlog10p', y = 'term2', color = 'grey',
#                capsize = 0.5, lw = 1.5, errwidth = 0)


kwargs = {'edgecolor':'k', 'linewidth':0.75}

ax = sns.stripplot(data = to_graph, x = 'nlog10p', y = 'term2', s = 7, **kwargs,
                  hue = 'Class', jitter = .25,
                  hue_order = ['immune', 'endothelial', 'parenchymal', 'stromal', 'epithelial', 'progenitor'])



for x in range(len(top_20)):
#    plt.text(x = 0.1, y = x, s = str(round(top_20.iloc[x].Overlap/len(hubs),2)), va = 'center')
    ax.axhline(x, zorder = 0, ls = '--', c = 'k', alpha = 0.5, lw = 2.5)
    
    
ax.axvline(-np.log10(0.05), ls = '--', c = 'k', alpha = 0.5, lw = 2.5)

    
plt.xlim(left = 0)

ax.legend(bbox_to_anchor=(1, .4))



for axis in ['bottom', 'left', 'top', 'right']:
    ax.spines[axis].set_linewidth(2.5)


plt.xticks(size = 13, ha = 'center', weight = 'bold')
plt.yticks(size = 12, weight = 'bold')

ax.tick_params(width = 2.5)

plt.ylabel('')
plt.xlabel("-$log_{10}$ FDR", size = 15)

plt.ylim(top = -.6)


plt.savefig('figures/4G.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4G.svg', bbox_inches = 'tight')

plt.show()

# %%
res[res.Gene_set == 'KEGG_2019_Human']
# Out:
#             Gene_set                                               Term  \
# 13   KEGG_2019_Human                         Hematopoietic cell lineage
# 14   KEGG_2019_Human                                    DNA replication
# 21   KEGG_2019_Human                                         Cell cycle
# 23   KEGG_2019_Human                        Chemokine signaling pathway
# 24   KEGG_2019_Human                   Fc gamma R-mediated phagocytosis
# 25   KEGG_2019_Human                                            Malaria
# 26   KEGG_2019_Human                    Staphylococcus aureus infection
# 27   KEGG_2019_Human                  Phospholipase D signaling pathway
# 30   KEGG_2019_Human                               Base excision repair
# 42   KEGG_2019_Human                         Non-homologous end-joining
# 56   KEGG_2019_Human                       NF-kappa B signaling pathway
# 67   KEGG_2019_Human            Human T-cell leukemia virus 1 infection
# 80   KEGG_2019_Human                                          Phagosome
# 82   KEGG_2019_Human                         Osteoclast differentiation
# 84   KEGG_2019_Human                               Rheumatoid arthritis
# 85   KEGG_2019_Human                Complement and coagulation cascades
# 90   KEGG_2019_Human                           Primary immunodeficiency
# 103  KEGG_2019_Human                                        Ferroptosis
# 104  KEGG_2019_Human                    Human cytomegalovirus infection
# 107  KEGG_2019_Human  AGE-RAGE signaling pathway in diabetic complic...
# 108  KEGG_2019_Human                                     Bladder cancer
# 114  KEGG_2019_Human                         PI3K-Akt signaling pathway
# 118  KEGG_2019_Human                   Protein digestion and absorption
# 119  KEGG_2019_Human                          Relaxin signaling pathway
# 120  KEGG_2019_Human                                    Mismatch repair
# 121  KEGG_2019_Human                             Acute myeloid leukemia
# 122  KEGG_2019_Human                             Fanconi anemia pathway
# 123  KEGG_2019_Human                   Th1 and Th2 cell differentiation
# 136  KEGG_2019_Human                          Th17 cell differentiation
#
#     Overlap   P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 13    17/97  0.000003          0.000617            0                     0
# 14    10/36  0.000004          0.000617            0                     0
# 21   18/124  0.000022          0.002013            0                     0
# 23   23/190  0.000035          0.002421            0                     0
# 24    14/91  0.000092          0.003189            0                     0
# 25    10/49  0.000082          0.003189            0                     0
# 26    12/68  0.000074          0.003189            0                     0
# 27   19/148  0.000074          0.003189            0                     0
# 30     8/33  0.000118          0.003639            0                     0
# 42     5/13  0.000220          0.006105            0                     0
# 56    13/95  0.000528          0.013295            0                     0
# 67   22/219  0.000744          0.017165            0                     0
# 80   17/152  0.000882          0.018802            0                     0
# 82   15/127  0.000994          0.019665            0                     0
# 84    12/91  0.001190          0.020754            0                     0
# 85    11/79  0.001199          0.020754            0                     0
# 90     7/37  0.001545          0.025174            0                     0
# 103    7/40  0.002473          0.036061            0                     0
# 104  21/225  0.002419          0.036061            0                     0
# 107  12/100  0.002691          0.037266            0                     0
# 108    7/41  0.002863          0.037764            0                     0
# 114  29/354  0.003036          0.038224            0                     0
# 118   11/90  0.003449          0.039811            0                     0
# 119  14/130  0.003444          0.039811            0                     0
# 120    5/23  0.003884          0.039848            0                     0
# 121    9/66  0.003771          0.039848            0                     0
# 122    8/54  0.003686          0.039848            0                     0
# 123   11/92  0.004093          0.040487            0                     0
# 136  12/107  0.004703          0.044925            0                     0
#
#      Odds Ratio  Combined Score  \
# 13     4.335228       55.466620
# 14     7.810114       96.228691
# 21     3.463310       37.172967
# 23     2.815006       28.885410
# 24     3.697944       34.363829
# 25     5.203185       48.932612
# 26     4.353782       41.390576
# 27     3.003508       28.569876
# 30     6.484515       58.637945
# 42    12.636014      106.396326
# 56     3.220126       24.300695
# 67     2.276482       16.399789
# 80     2.561577       18.015159
# 82     2.721825       18.818300
# 84     3.082488       20.756210
# 85     3.281093       22.070101
# 90     4.722021       30.564546
# 103    4.292070       25.761542
# 104    2.095398       12.623906
# 107    2.765921       16.368629
# 108    4.165613       24.393398
# 114    1.820385       10.553278
# 118    2.822595       16.002903
# 119    2.449625       13.892045
# 120    5.613057       31.157279
# 121    3.197621       17.843963
# 122    3.520304       19.725169
# 123    2.752612       15.135479
# 136    2.561171       13.726577
#
#                                                  Genes    nlog10
# 13   IL4R;ITGAM;CSF1;MME;ITGB3;CD3E;CD3D;CD2;GP9;CD...  3.209508
# 14   POLA1;FEN1;LIG1;POLD1;RPA2;MCM4;MCM5;MCM6;POLE...  3.209508
# 21   ZBTB17;CDKN2C;CDKN2A;PLK1;PKMYT1;CDC14B;ORC5;C...  2.696082
# 23   STAT5B;CXCL8;NCF1;CHUK;CCL21;CCL4L2;CXCR4;PIK3...  2.615973
# 24   NCF1;SYK;SPHK2;SPHK1;LIMK1;PLA2G4A;PIK3R2;ASAP...  2.496372
# 25   SELP;CXCL8;LRP1;KLRB1;SDC2;ITGB2;CCL2;CD36;THB...  2.496372
# 26   SELP;ITGAM;C1S;ITGB2;C5AR1;PTAFR;DEFA3;HLA-DQA...  2.496372
# 27   CXCL8;SYK;SPHK2;SPHK1;F2R;PLA2G4A;PIK3R2;PLD1;...  2.496372
# 30             POLB;FEN1;LIG1;POLD1;POLL;LIG3;POLE;UNG  2.438985
# 42                        FEN1;DCLRE1C;XRCC4;LIG4;POLL  2.214317
# 56   CXCL8;SYK;CHUK;CCL21;CCL4L2;CSNK2A2;TNFRSF11A;...  1.876318
# 67   STAT5B;NRP1;CDKN2C;CHUK;TRRAP;CDKN2A;CRTC1;ITG...  1.765361
# 80   COLEC12;SCARB1;ITGAM;NCF1;NCF2;ITGB3;ITGB2;THB...  1.725787
# 82   NCF1;CSF1;SYK;CHUK;NCF2;ITGB3;PIK3R2;TREM2;LIL...  1.706297
# 84   CXCL8;CSF1;CTSK;ITGB2;CCL3;CCL2;LTB;TNFRSF11A;...  1.682899
# 85   ITGAM;C1S;PROS1;ITGB2;F2R;C5AR1;BDKRB2;PLAUR;F...  1.682899
# 90                DCLRE1C;RFX5;BLNK;CD3E;IL7R;CD3D;UNG  1.599056
# 103  GCLC;MAP1LC3A;SLC40A1;SLC39A8;SLC7A11;ATG7;SLC...  1.442964
# 104  CXCL8;CHUK;CDKN2A;CCL4L2;ITGB3;CXCR4;PIK3R2;GN...  1.442964
# 107  COL1A1;STAT5B;COL3A1;COL1A2;CXCL8;CCND1;MMP2;P...  1.428690
# 108            CXCL8;CCND1;CDKN2A;MMP2;E2F3;THBS1;MMP9  1.422923
# 114  CSF1;ITGB3;PIK3R2;BRCA1;THBS2;THBS1;GNG10;PPP2...  1.417668
# 118  SLC36A1;DPP4;COL1A1;COL18A1;COL3A1;COL27A1;COL...  1.399994
# 119  MMP2;PIK3R2;ARRB1;GNG11;MMP9;ADCY7;COL1A1;ACTA...  1.399994
# 120                          MSH6;LIG1;MSH2;POLD1;RPA2  1.399591
# 121  STAT5B;ITGAM;CCND1;CHUK;PIK3R2;CD14;SOS2;MTOR;...  1.399591
# 122  FANCI;FANCD2;FANCL;FANCA;RPA2;BRCA1;BRCA2;FAAP100  1.399591
# 123  STAT5B;IL4R;CHUK;MAML3;PLCG1;CD3E;JAK2;CD3D;HL...  1.392685
# 136  STAT5B;IL4R;CHUK;PLCG1;CD3E;JAK2;HLA-DQA2;CD3D...  1.347516

# %%
#TF

# %%
out = []

for hub in tqdm(list(signatures)):
    
    if len(signatures[hub]) < 5:
        continue
    
    
    #convert hub list to \n sep string
    seq_str = ''
    for item in [x[0] for x in signatures[hub]]:
        seq_str += str(item) + '\n'
    
    #pass that string to this R script which returns a gene region df
    child = subprocess.Popen(['scripts/tf/sym_to_reg_human.R'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.DEVNULL)
    child.stdin.write(seq_str.encode())
    child_out = child.communicate()[0].decode('utf8')
    a = StringIO(child_out)
    child.stdin.close()
    
    #read the region df and slice up hg38 into a multi seq fasta
    a = pd.read_csv(a).dropna().reset_index(drop = True)
    a['slice_start'] = a['slice_start'].astype('int')
    a['slice_end'] = a['slice_end'].astype('int')
    
    outfa = []
    for row in a.index:
        values = a.iloc[row]
        record = hg38[values.TXCHROM][values.slice_start - 1:values.slice_end -1]
        record.id = values.symbol

        outfa.append(record)
    
    
    with open('tmpdir/test_human.fasta', 'w') as f:
        for seq in outfa:
            f.write( '>' + seq.id + '\n')
            f.write(str(seq.seq) + '\n')
            
            
    #process fasta with meme sea     
    child = subprocess.Popen(['sea', '--p', 'tmpdir/test_human.fasta', '--m',
                          'scripts/tf/JASPAR2020_CORE_vertebrates_non-redundant_pfms_meme.txt', 
                          '--text'], stdout=subprocess.PIPE, stderr=subprocess.DEVNULL)
    child_out = child.communicate()[0].decode('utf8')
    a = StringIO(child_out)
    a = pd.read_csv(a, delimiter='\t').dropna().drop(columns = ['DB'])
    
    a['tissue'] = hub[0]
    a['cell'] = hub[1]
    
    out.append(a)
# Out:
#  35%|██████████████                          | 18/51 [1:03:40<58:35, 106.54s/it]

# %%
tf = pd.concat(out)
tf
# Out:
#     RANK        ID        ALT_ID         CONSENSUS      TP    TP%      FP  \
# 0      1  MA1107.2          KLF9  MNGCCACACCCACHYV    59.0  57.28    24.0
# 1      2  MA0599.1          KLF5        GCCCCDCCCH    72.0  69.90    41.0
# 2      3  MA1596.1        ZNF460  GCCTCMGCCTCCCRAG    90.0  87.38    64.0
# 3      4  MA1587.1        ZNF135    CCTCGACCTCCYRR    17.0  16.50     1.0
# 4      5  MA0746.2           SP3     NGCCACGCCCMCH    71.0  68.93    42.0
# ..   ...       ...           ...               ...     ...    ...     ...
# 401  402  MA0137.3         STAT1       TTTCYRGGAAA   709.0  42.18   643.0
# 402  403  MA1619.1  Ptf1a(var.2)      NNACAGCTGTNN  1599.0  95.12  1567.0
# 403  404  MA0130.1       ZNF354C            MTCCAC   227.0  13.50   183.0
# 404  405  MA1536.1  NR2C2(var.2)          RRGGTCAN  1587.0  94.41  1554.0
# 405  406  MA0077.1          SOX9         CYATTGTTY  1606.0  95.54  1576.0
#
#        FP%  ENR_RATIO  SCORE_THR        PVALUE  LOG_PVALUE   EVALUE  \
# 0    23.30       2.40        9.7  5.220000e-07      -14.46  0.00039
# 1    39.81       1.74       10.0  1.170000e-05      -11.36  0.00869
# 2    62.14       1.40        4.3  2.340000e-05      -10.66  0.01750
# 3     0.97       9.00       14.0  3.820000e-05      -10.17  0.02850
# 4    40.78       1.67        8.4  4.000000e-05      -10.13  0.02980
# ..     ...        ...        ...           ...         ...      ...
# 401  38.25       1.10        7.6  1.110000e-02       -4.50  8.29000
# 402  93.22       1.02        4.7  1.110000e-02       -4.50  8.31000
# 403  10.89       1.24       11.0  1.170000e-02       -4.45  8.71000
# 404  92.44       1.02        8.1  1.290000e-02       -4.35  9.61000
# 405  93.75       1.02        5.7  1.300000e-02       -4.34  9.72000
#
#      LOG_EVALUE    QVALUE  LOG_QVALUE  tissue         cell
# 0         -7.85  0.000283       -8.17   blood  erythrocyte
# 1         -4.75  0.003160       -5.76   blood  erythrocyte
# 2         -4.05  0.004230       -5.47   blood  erythrocyte
# 3         -3.56  0.004340       -5.44   blood  erythrocyte
# 4         -3.51  0.004340       -5.44   blood  erythrocyte
# ..          ...       ...         ...     ...          ...
# 401        2.11  0.008030       -4.83  tongue   basal cell
# 402        2.12  0.008030       -4.82  tongue   basal cell
# 403        2.16  0.008390       -4.78  tongue   basal cell
# 404        2.26  0.009230       -4.69  tongue   basal cell
# 405        2.27  0.009310       -4.68  tongue   basal cell
#
# [9272 rows x 18 columns]

# %%
tf.to_pickle('../data/files/6.1_HUMAN_GENE_TF_ENRICHMENT_DF_SIGS.pickle')

# %%
tf = pd.read_pickle('../data/files/6.1_HUMAN_GENE_TF_ENRICHMENT_DF_SIGS.pickle')

# %%
tf = tf[tf.QVALUE < 0.05]

top_20 = tf.groupby('ALT_ID').count().sort_values('RANK', ascending = False)[0:20]

order_d = dict(zip(top_20.index, range(20)))

overlap_d = dict(zip(top_20.index, top_20.RANK))

top_20
# Out:
#               RANK  ID  CONSENSUS  TP  TP%  FP  FP%  ENR_RATIO  SCORE_THR  \
# ALT_ID
# ZNF135          43  43         43  43   43  43   43         43         43
# MEF2D           41  41         41  41   41  41   41         41         41
# ZNF460          41  41         41  41   41  41   41         41         41
# IRF1            40  40         40  40   40  40   40         40         40
# MEF2A           40  40         40  40   40  40   40         40         40
# MEF2B           39  39         39  39   39  39   39         39         39
# KLF5            38  38         38  38   38  38   38         38         38
# MEF2C           37  37         37  37   37  37   37         37         37
# KLF4            37  37         37  37   37  37   37         37         37
# Nr2f6(var.2)    37  37         37  37   37  37   37         37         37
# KLF2            35  35         35  35   35  35   35         35         35
# SPI1            35  35         35  35   35  35   35         35         35
# SP1             35  35         35  35   35  35   35         35         35
# FOXC2           35  35         35  35   35  35   35         35         35
# RREB1           35  35         35  35   35  35   35         35         35
# Foxd3           34  34         34  34   34  34   34         34         34
# FOXD2           34  34         34  34   34  34   34         34         34
# Lhx3            34  34         34  34   34  34   34         34         34
# SPIB            34  34         34  34   34  34   34         34         34
# KLF15           34  34         34  34   34  34   34         34         34
#
#               PVALUE  LOG_PVALUE  EVALUE  LOG_EVALUE  QVALUE  LOG_QVALUE  \
# ALT_ID
# ZNF135            43          43      43          43      43          43
# MEF2D             41          41      41          41      41          41
# ZNF460            41          41      41          41      41          41
# IRF1              40          40      40          40      40          40
# MEF2A             40          40      40          40      40          40
# MEF2B             39          39      39          39      39          39
# KLF5              38          38      38          38      38          38
# MEF2C             37          37      37          37      37          37
# KLF4              37          37      37          37      37          37
# Nr2f6(var.2)      37          37      37          37      37          37
# KLF2              35          35      35          35      35          35
# SPI1              35          35      35          35      35          35
# SP1               35          35      35          35      35          35
# FOXC2             35          35      35          35      35          35
# RREB1             35          35      35          35      35          35
# Foxd3             34          34      34          34      34          34
# FOXD2             34          34      34          34      34          34
# Lhx3              34          34      34          34      34          34
# SPIB              34          34      34          34      34          34
# KLF15             34          34      34          34      34          34
#
#               tissue  cell
# ALT_ID
# ZNF135            43    43
# MEF2D             41    41
# ZNF460            41    41
# IRF1              40    40
# MEF2A             40    40
# MEF2B             39    39
# KLF5              38    38
# MEF2C             37    37
# KLF4              37    37
# Nr2f6(var.2)      37    37
# KLF2              35    35
# SPI1              35    35
# SP1               35    35
# FOXC2             35    35
# RREB1             35    35
# Foxd3             34    34
# FOXD2             34    34
# Lhx3              34    34
# SPIB              34    34
# KLF15             34    34

# %%
to_graph = tf[tf.ALT_ID.isin(top_20.index)]


#to_graph['nlog10p'] = -np.log10(to_graph['Adjusted P-value'])

to_graph['Orderer'] = to_graph.ALT_ID.map(order_d)

to_graph = to_graph.sort_values('Orderer')


to_graph['Overlap'] = to_graph.ALT_ID.map(overlap_d)

to_graph['frac'] = to_graph['Overlap']/len(signatures) * 100

to_graph['Class'] = to_graph.cell.map(class_d)


to_graph
# Out:
# /tmp/ipykernel_1846983/2557413998.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['Orderer'] = to_graph.ALT_ID.map(order_d)
#    RANK        ID  ALT_ID       CONSENSUS     TP    TP%     FP    FP%  \
# 1     2  MA1587.1  ZNF135  CCTCGACCTCCYRR   58.0  16.76    3.0   0.87
# 1     2  MA1587.1  ZNF135  CCTCGACCTCCYRR   28.0  25.00    4.0   3.57
# 1     2  MA1587.1  ZNF135  CCTCGACCTCCYRR  123.0  40.73   23.0   7.62
# 6     7  MA1587.1  ZNF135  CCTCGACCTCCYRR   16.0  33.33    1.0   2.08
# 9    10  MA1587.1  ZNF135  CCTCGACCTCCYRR  150.0  63.83   91.0  38.72
# ..  ...       ...     ...             ...    ...    ...    ...    ...
# 1     2  MA1513.1   KLF15     SCCCCGCCCCS  324.0  43.67  120.0  16.17
# 17   18  MA1513.1   KLF15     SCCCCGCCCCS   61.0  41.22   34.0  22.97
# 17   18  MA1513.1   KLF15     SCCCCGCCCCS   26.0  23.64    9.0   8.18
# 19   20  MA1513.1   KLF15     SCCCCGCCCCS  275.0  50.27  164.0  29.98
# 2     3  MA1513.1   KLF15     SCCCCGCCCCS  583.0  36.51  180.0  11.27
#
#     ENR_RATIO  SCORE_THR  ...        EVALUE  LOG_EVALUE        QVALUE  \
# 1       14.80       15.0  ...  1.160000e-12      -27.48  3.340000e-13
# 1        5.80       12.0  ...  1.680000e-03       -6.39  6.600000e-04
# 1        5.17       11.0  ...  6.930000e-20      -44.12  1.950000e-20
# 6        8.50       11.0  ...  5.380000e-02       -2.92  3.410000e-03
# 9        1.64        6.7  ...  2.790000e-05      -10.49  1.530000e-06
# ..        ...        ...  ...           ...         ...           ...
# 1        2.69       12.0  ...  6.720000e-29      -64.87  1.400000e-29
# 17       1.77       12.0  ...  4.290000e-01       -0.85  1.530000e-02
# 17       2.70       13.0  ...  1.040000e+00        0.04  4.100000e-02
# 19       1.67       12.0  ...  3.580000e-09      -19.45  9.430000e-11
# 2        3.23       13.0  ...  2.240000e-62     -141.96  2.840000e-63
#
#     LOG_QVALUE       tissue          cell Orderer Overlap  frac        Class
# 1       -28.73        blood        t cell       0      43  86.0       immune
# 1        -7.32        blood      monocyte       0      43  86.0       immune
# 1       -45.38         lung      monocyte       0      43  86.0       immune
# 6        -5.68        heart      pericyte       0      43  86.0      stromal
# 9       -13.39       kidney    macrophage       0      43  86.0       immune
# ..         ...          ...           ...     ...     ...   ...          ...
# 1       -66.44  bone marrow        t cell      19      34  68.0       immune
# 17       -4.18         lung    macrophage      19      34  68.0       immune
# 17       -3.20  hippocampus     microglia      19      34  68.0       immune
# 19      -23.08         skin  spinous cell      19      34  68.0  parenchymal
# 2      -144.02         lung    fibroblast      19      34  68.0      stromal
#
# [738 rows x 22 columns]

# %%
to_graph['ENR_RATIO'][to_graph['ENR_RATIO'] > 15] = 15 #because of a few high outliers, make sure to add >= on plot

#note the few above 10 have been reduced to 10

plt.figure(figsize = (4, 7))

#ax = sns.barplot(data = to_graph, x = 'ENR_RATIO', y = 'ALT_ID', color = 'grey',
#                capsize = 0.5, lw = 1.5, errwidth = 0)


kwargs = {'edgecolor':'k', 'linewidth':0.75}

ax = sns.stripplot(data = to_graph, x = 'ENR_RATIO', y = 'ALT_ID', s = 7, **kwargs,
                  hue = 'Class', jitter = .25,
                  hue_order = ['immune', 'endothelial', 'parenchymal', 'stromal', 'epithelial', 'progenitor'])



for x in range(len(top_20)):
   # plt.text(x = 0.1, y = x, s = str(round(top_20.iloc[x].Overlap/len(hubs),2)), va = 'center')
    ax.axhline(x, zorder = 0, ls = '--', c = 'k', alpha = 0.5, lw = 2.5)

ax.axvline(1,zorder = 0, ls = '--', c = 'k', alpha = 0.5, lw = 2.5)
    
plt.xlim(left = 0)

ax.legend(bbox_to_anchor=(1, .4))



for axis in ['bottom', 'left', 'top', 'right']:
    ax.spines[axis].set_linewidth(2.5)


plt.xticks(size = 13, ha = 'center', weight = 'bold')
plt.yticks(size = 12, weight = 'bold')

ax.tick_params(width = 2.5)

plt.ylabel('')
plt.xlabel("Enrichment Ratio", size = 15)

plt.ylim(top = -.6)

plt.savefig('figures/4H.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4H.svg', bbox_inches = 'tight')

plt.show()
# Out:
# /tmp/ipykernel_1846983/1800161206.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   to_graph['ENR_RATIO'][to_graph['ENR_RATIO'] > 15] = 15 #because of a few high outliers, make sure to add >= on plot
# /tmp/ipykernel_1846983/1800161206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['ENR_RATIO'][to_graph['ENR_RATIO'] > 15] = 15 #because of a few high outliers, make sure to add >= on plot
