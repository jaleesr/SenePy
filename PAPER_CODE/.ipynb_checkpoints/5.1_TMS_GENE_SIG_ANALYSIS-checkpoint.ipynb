# %%
import scanpy as sc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from matplotlib.pyplot import rc_context
from tqdm import tqdm
#from scipy.optimize import curve_fit

#import scvi
import pickle
from adjustText import adjust_text

import itertools
#from numba import jit

import gseapy as gp
import random

import subprocess
from io import StringIO
from Bio import SeqIO

# %%
adata = sc.read_h5ad('../data/tms/tms-scVI-raw-data_BDATA.h5ad')

# %% [markdown]
# # Most common - signature

# %%
import senepy as sp

# %%
sigs = sp.load_hubs(species = 'Mouse', sig_type = 'cell_type')

# %%
signatures = sigs.hubs

# %%
all_genes_redundant = []

for x in list(signatures):
    all_genes_redundant += [x[0] for x in signatures[x]]

# %%
signatures
# Out:
# {('Bladder', 'bladder cell'): [('Sfrp5', 23),
#   ('Agtr1a', 30),
#   ('Rasgef1c', 17),
#   ('Rxrg', 21),
#   ('Plce1', 30),
#   ('Kcna2', 23),
#   ('Slc35f1', 20),
#   ('Ppp1r14c', 7),
#   ('Cadm4', 27),
#   ('Matn4', 13),
#   ('Gfra3', 20),
#   ('Lgi1', 18),
#   ('Tmprss5', 17),
#   ('Mpz', 21),
#   ('Ngfr', 9),
#   ('Cadm2', 32),
#   ('Fam89a', 20),
#   ('Nat8l', 16),
#   ('Klk8', 19),
#   ('Kcna1', 23),
#   ('Syt7', 13),
#   ('Map3k9', 5),
#   ('Msln', 31),
#   ('Slpi', 27),
#   ('Dpp4', 44),
#   ('Pcnxl2', 27),
#   ('Pkhd1l1', 33),
#   ('Slurp1', 29),
#   ('Podxl', 33),
#   ('Gpr64', 29),
#   ('Col8a2', 28),
#   ('Prr15l', 33),
#   ('Cdon', 27),
#   ('Nrxn2', 15),
#   ('Prlr', 26),
#   ('Ablim3', 29),
#   ('Hoxc6', 23),
#   ('Bex1', 8),
#   ('Sgcd', 18),
#   ('Slc4a8', 25),
#   ('Myl7', 32),
#   ('Rspo1', 30),
#   ('Wt1', 38),
#   ('Gpm6a', 36),
#   ('Mira', 4),
#   ('Cdh3', 37),
#   ('Clic3', 26),
#   ('Hoxd10', 22),
#   ('Fgf9', 18),
#   ('Hoxd13', 10),
#   ('Espn', 26),
#   ('Hoxc4', 14),
#   ('Smpd3', 36),
#   ('Me3', 10),
#   ('Kcnj8', 20),
#   ('Plscr2', 19),
#   ('Rnf165', 3),
#   ('Ccrl1', 26),
#   ('Itgbl1', 28),
#   ('Cdh13', 25),
#   ('6330403K07Rik', 6),
#   ('Prrx1', 27),
#   ('Ccl19', 8),
#   ('Des', 9),
#   ('Vwc2', 7),
#   ('Fam167a', 14),
#   ('Fgl2', 27),
#   ('Mrgprg', 15),
#   ('Syn2', 8),
#   ('C530028O21Rik', 14),
#   ('Dact2', 17),
#   ('Inhba', 21),
#   ('Penk', 34),
#   ('Fibin', 31),
#   ('Pcsk6', 39),
#   ('Eya2', 6),
#   ('Scgb1a1', 6),
#   ('1700019D03Rik', 14),
#   ('Ccbe1', 14),
#   ('Mcf2l', 7),
#   ('Dner', 14),
#   ('Efhd1', 32),
#   ('Rtn1', 8),
#   ('C130026I21Rik', 2),
#   ('Ccbp2', 10),
#   ('Fbln7', 14),
#   ('Angptl7', 15),
#   ('Islr2', 9),
#   ('Vit', 24),
#   ('Zfhx4', 8),
#   ('Ifi204', 14),
#   ('Sult5a1', 15),
#   ('Lancl3', 10),
#   ('Aldh1a3', 37),
#   ('Inhbb', 8),
#   ('4931408D14Rik', 2),
#   ('Fst', 23),
#   ('Hecw2', 7),
#   ('Ltbp2', 17),
#   ('Ebf2', 30),
#   ('Slc38a5', 11),
#   ('Gm4956', 11),
#   ('Npy', 5),
#   ('Fgf16', 9),
#   ('AA467197', 6),
#   ('Shisa9', 5),
#   ('AI607873', 17),
#   ('Gdf10', 24),
#   ('Prrt4', 12),
#   ('Duoxa1', 14),
#   ('Stk32b', 9),
#   ('Cilp', 21),
#   ('Slc6a4', 11),
#   ('Tac1', 8),
#   ('Ace', 15),
#   ('Sult1e1', 24),
#   ('Cxxc4', 6)],
#  ('Bladder', 'endothelial cell'): [('Mc1r', 3),
#   ('Nos2', 3),
#   ('Timp4', 5),
#   ('Fmo1', 7),
#   ('Slc26a10', 5),
#   ('Car4', 6),
#   ('Trim69', 3),
#   ('Rtn1', 3),
#   ('Fam89a', 6),
#   ('Car8', 8),
#   ('Slc28a2', 8),
#   ('Rhov', 3),
#   ('Mmrn1', 18),
#   ('Popdc2', 3),
#   ('Dennd4a', 11),
#   ('Gm11837', 3),
#   ('Gjb2', 3),
#   ('Cd2', 12),
#   ('Sema3d', 18),
#   ('Nts', 18),
#   ('Slc45a3', 14),
#   ('F2rl1', 17),
#   ('Nipal1', 6),
#   ('Wnt7b', 3),
#   ('Igsf3', 2),
#   ('AA467197', 8),
#   ('Pcsk6', 13),
#   ('Rasl10b', 4),
#   ('Gm1987', 11),
#   ('Reln', 18),
#   ('Gpm6a', 18),
#   ('Sh3gl3', 19),
#   ('Lyve1', 18),
#   ('Lst1', 9),
#   ('Ccbp2', 16),
#   ('Cyp2s1', 2),
#   ('Slc38a4', 15),
#   ('Gpx2', 5),
#   ('Dtx1', 15),
#   ('Ttc9', 14),
#   ('Tmem198', 3),
#   ('Hnmt', 2),
#   ('Nrip3', 4),
#   ('Irf5', 1),
#   ('Kcnma1', 4),
#   ('Bdh1', 2),
#   ('Ngb', 6),
#   ('Tmeff2', 3),
#   ('Trim38', 3),
#   ('D030028A08Rik', 4),
#   ('Ankrd9', 5),
#   ('Gm5124', 6),
#   ('Ntrk3', 4)],
#  ('Brain', 'endothelial cell'): [('Hbb-b2', 3),
#   ('Hbb-b1', 4),
#   ('Hba-a1', 3),
#   ('Hba-a2', 4),
#   ('4933432B09Rik', 2),
#   ('Rprml', 8),
#   ('B230209E15Rik', 7),
#   ('Prtg', 7),
#   ('Gm996', 10),
#   ('Cbr3', 6),
#   ('Sprn', 8),
#   ('Lrrc4b', 8),
#   ('Pcsk4', 7),
#   ('7530420F21Rik', 3),
#   ('Asxl3', 7),
#   ('Gm10845', 2),
#   ('Bcl2a1d', 7),
#   ('Ccr2', 3),
#   ('Wdfy4', 9),
#   ('Ccdc88b', 7),
#   ('Slamf9', 9),
#   ('1700025K23Rik', 7),
#   ('Klri1', 7),
#   ('Tlr13', 3),
#   ('Fndc7', 9),
#   ('Cxcr3', 7),
#   ('H2-Q7', 3),
#   ('Osm', 3),
#   ('Apol9a', 5),
#   ('Fcnb', 3),
#   ('1810014F10Rik', 2),
#   ('Clec12a', 1),
#   ('Upp1', 2),
#   ('1700088E04Rik', 5),
#   ('Nol3', 2),
#   ('Gm5127', 2),
#   ('Nckap5', 3),
#   ('H2-Q2', 2),
#   ('Cyp2e1', 2),
#   ('4930473A02Rik', 3),
#   ('Gm4951', 1),
#   ('Gm8909', 2),
#   ('Itgb3', 2)],
#  ('Brain', 'oligodendrocyte'): [('Slc17a7', 4),
#   ('Acvr1c', 6),
#   ('Diras2', 3),
#   ('Reln', 6),
#   ('Nell2', 10),
#   ('Syt4', 9),
#   ('Fam57b', 4),
#   ('A230070E04Rik', 4),
#   ('Gabra6', 3),
#   ('Scn2b', 4),
#   ('Fat2', 6),
#   ('Lyl1', 6),
#   ('L1cam', 6),
#   ('Kcnt1', 3),
#   ('Cdh8', 2),
#   ('Ptprg', 3),
#   ('Gatsl3', 2),
#   ('Pitpnm2', 1),
#   ('Emx2', 2),
#   ('Olfr613', 6),
#   ('C4a', 5),
#   ('St8sia5', 3),
#   ('Nhedc2', 8),
#   ('Dlx1', 5),
#   ('Spc24', 2),
#   ('Art3', 8),
#   ('Atp6v0c-ps2', 2),
#   ('Tubb2a-ps2', 3),
#   ('AY358078', 5),
#   ('Npb', 9),
#   ('Plk5', 3),
#   ('Neurod1', 4),
#   ('Igf2bp2', 2),
#   ('Calb2', 4),
#   ('Zic2', 3)],
#  ('Diaphragm', 'mesenchymal stem cell'): [('Rad54b', 4),
#   ('Lphn3', 12),
#   ('Snx32', 4),
#   ('Arhgef5', 26),
#   ('Adam28', 3),
#   ('Zfp2', 10),
#   ('Ano1', 22),
#   ('4932438H23Rik', 6),
#   ('Pkhd1', 2),
#   ('Acot3', 5),
#   ('Gm11127', 10),
#   ('Atp8b5', 7),
#   ('Abca7', 3),
#   ('Myo7a', 4),
#   ('Trhde', 8),
#   ('Rp1', 3),
#   ('Svip', 6),
#   ('Cdt1', 15),
#   ('Lgals2', 18),
#   ('1700048O20Rik', 7),
#   ('Hydin', 7),
#   ('Msln', 35),
#   ('Dnahc1', 5),
#   ('Stmn2', 21),
#   ('A330021E22Rik', 16),
#   ('Zfp352', 4),
#   ('Hand2', 13),
#   ('BC048546', 2),
#   ('Map3k13', 5),
#   ('Iqch', 7),
#   ('Folh1', 3),
#   ('Sis', 3),
#   ('Dnahc6', 8),
#   ('Lamc3', 8),
#   ('E230008N13Rik', 6),
#   ('Pawr', 12),
#   ('Acvr1c', 3),
#   ('Myo5b', 12),
#   ('Cntnap2', 2),
#   ('Arhgap22', 3),
#   ('Ifi44', 18),
#   ('Myo3b', 4),
#   ('5031434C07Rik', 3),
#   ('Il17re', 31),
#   ('AU021092', 15),
#   ('H2-Q8', 7),
#   ('Bex1', 5),
#   ('Slco2a1', 15),
#   ('Cdh3', 26),
#   ('Ros1', 5),
#   ('Ptpro', 5),
#   ('Gm8909', 4),
#   ('B3gnt7', 9),
#   ('Gpr126', 6),
#   ('Lrrn4', 21),
#   ('Zfp707', 30),
#   ('Dock8', 3),
#   ('Lrp2', 29),
#   ('Cit', 13),
#   ('Dlgap5', 7),
#   ('H2-Bl', 7),
#   ('Fras1', 5),
#   ('Pkhd1l1', 13),
#   ('Oca2', 2),
#   ('Il18r1', 19),
#   ('Aim1', 16),
#   ('A830018L16Rik', 7),
#   ('Rnf17', 4),
#   ('BC021891', 4),
#   ('Ryr3', 5),
#   ('Dmkn', 24),
#   ('Inadl', 4),
#   ('Unc13c', 7),
#   ('Ryr2', 4),
#   ('1300002K09Rik', 4),
#   ('Met', 15),
#   ('Gabrq', 10),
#   ('Pcdh15', 7),
#   ('Sox6', 19),
#   ('C4a', 7),
#   ('Atp6v0a4', 9),
#   ('Kcnq2', 5),
#   ('Pole', 4),
#   ('Prr15', 11),
#   ('4930431P03Rik', 4),
#   ('Tmc5', 4),
#   ('Nudt17', 7),
#   ('Ect2l', 5),
#   ('Izumo4', 9),
#   ('Dsg2', 8),
#   ('Pcdh17', 5),
#   ('Kcnh4', 6),
#   ('Ltbp2', 9),
#   ('Itgae', 7),
#   ('Ccl19', 6),
#   ('Nrg4', 6),
#   ('Tmem54', 8),
#   ('Gm14207', 11),
#   ('Taf4a', 8),
#   ('Extl1', 9),
#   ('Dbx2', 8),
#   ('Ubd', 10),
#   ('Olfr456', 9),
#   ('Tmsb15l', 6),
#   ('Gja4', 11),
#   ('Csmd1', 7),
#   ('Olfr613', 36),
#   ('Arhgap30', 54),
#   ('Gzmb', 43),
#   ('Ipcef1', 6),
#   ('Csf2rb', 102),
#   ('Rbm47', 54),
#   ('Mgst2', 20),
#   ('Acpp', 21),
#   ('Myf5', 58),
#   ('Rgs1', 156),
#   ('Tnfrsf4', 118),
#   ('Gm20324', 48),
#   ('Mmp9', 274),
#   ('Rdh12', 93),
#   ('Ccr2', 30),
#   ('Cyp4f18', 126),
#   ('Cd48', 138),
#   ('Stxbp2', 139),
#   ('Clec4a1', 25),
#   ('Ccna2', 50),
#   ('Faah', 17),
#   ('Cib2', 9),
#   ('Ankrd16', 14),
#   ('H2-DMb1', 116),
#   ('Slfn4', 81),
#   ('Aurkb', 41),
#   ('Ripply3', 75),
#   ('Gpr77', 12),
#   ('Ccl5', 254),
#   ('Ramp3', 64),
#   ('Spib', 67),
#   ('Ankrd22', 99),
#   ('Cd207', 113),
#   ('Slc26a10', 79),
#   ('Cd7', 75),
#   ('Pik3cd', 12),
#   ('Alg10b', 7),
#   ('6720401G13Rik', 4),
#   ('Trem1', 86),
#   ('Clec4a2', 104),
#   ('Stap2', 24),
#   ('Pilrb1', 118),
#   ('Nkg7', 249),
#   ('Fam132b', 34),
#   ('Pdcd1lg2', 11),
#   ('Tmem170', 10),
#   ('Clec5a', 61),
#   ('Tas1r3', 9),
#   ('5830416P10Rik', 29),
#   ('Sdcbp2', 8),
#   ('Arg2', 48),
#   ('Tpd52l1', 12),
#   ('Nrip2', 50),
#   ('AI662270', 32),
#   ('Trp63', 16),
#   ('Apobec1', 22),
#   ('Gm15987', 70),
#   ('Gjb3', 18),
#   ('Ccr8', 41),
#   ('AB124611', 149),
#   ('Cenpf', 7),
#   ('Napsa', 212),
#   ('Mpeg1', 33),
#   ('Mpo', 262),
#   ('AF251705', 81),
#   ('Treml4', 16),
#   ('Vpreb3', 124),
#   ('Mmp12', 58),
#   ('Cdk1', 99),
#   ('Cfp', 210),
#   ('Cd163', 26),
#   ('Cst7', 60),
#   ('Ms4a4b', 221),
#   ('Cd209f', 30),
#   ('Arhgef15', 14),
#   ('Ltb4r1', 214),
#   ('Trp53i11', 18),
#   ('A530064D06Rik', 51),
#   ('D630042P16Rik', 31),
#   ('Alox5', 122),
#   ('Ctla2a', 145),
#   ('Il1b', 176),
#   ('Neurl3', 61),
#   ('B430306N03Rik', 57),
#   ('S1pr4', 173),
#   ('Cd19', 63),
#   ('Tnfrsf13c', 91),
#   ('Igj', 120),
#   ('Kif23', 6),
#   ('Snca', 114),
#   ('Asprv1', 60),
#   ('Clec7a', 26),
#   ('Arhgap15', 26),
#   ('Cenpq', 15),
#   ('Saa3', 77),
#   ('Olfm4', 23),
#   ('D10Bwg1379e', 9),
#   ('Gria4', 5),
#   ('Serpina3g', 133),
#   ('Pkib', 10),
#   ('Padi4', 77),
#   ('Gm4902', 81),
#   ('Ltb', 243),
#   ('Fam65b', 23),
#   ('Cd4', 20),
#   ('Ms4a6c', 92),
#   ('Ccr1', 54),
#   ('Ctsg', 44),
#   ('Gm8369', 122),
#   ('Hba-a1', 239),
#   ('Blk', 77),
#   ('Fgr', 123),
#   ('Bcl2a1d', 56),
#   ('Faim3', 265),
#   ('Cyb561d1', 39),
#   ('Tgm4', 32),
#   ('Adssl1', 100),
#   ('Cd209d', 7),
#   ('Irg1', 42),
#   ('B230208H11Rik', 16),
#   ('Bank1', 54),
#   ('Gca', 64),
#   ('Rapsn', 26),
#   ('Cd209g', 35),
#   ('Cenpw', 14),
#   ('Ccl9', 169),
#   ('Asb2', 9),
#   ('Cd177', 272),
#   ('Lipc', 14),
#   ('Ednrb', 120),
#   ('Gm16845', 9),
#   ('Nos3', 33),
#   ('Mbnl3', 66),
#   ('Pim2', 40),
#   ('Hspb6', 27),
#   ('Ms4a1', 103),
#   ('Ccl17', 59),
#   ('Fblim1', 9),
#   ('Ctsw', 160),
#   ('Cd33', 130),
#   ('Hck', 118),
#   ('Lyve1', 63),
#   ('Myl3', 16),
#   ('Ckap2l', 9),
#   ('6330512M04Rik', 67),
#   ('Rgs4', 10),
#   ('Slamf6', 67),
#   ('Zfp69', 9),
#   ('Erg', 7),
#   ('Scrg1', 53),
#   ('Samd10', 21),
#   ('Gata2', 18),
#   ('Glipr1', 149),
#   ('Des', 63),
#   ('Bst1', 53),
#   ('Gimap5', 63),
#   ('Fuk', 5),
#   ('Cdkn2b', 5),
#   ('Lime1', 19),
#   ('Cxcr3', 142),
#   ('Cnr2', 46),
#   ('Zfp825', 18),
#   ('Il1f9', 23),
#   ('Sit1', 54),
#   ('Fcgr1', 59),
#   ('Cyfip2', 97),
#   ('Mad2l1', 48),
#   ('Lilra6', 17),
#   ('Trem3', 219),
#   ('Csf3r', 125),
#   ('Sigirr', 37),
#   ('Sell', 152),
#   ('Cd2', 176),
#   ('Cyth4', 79),
#   ('Clps', 58),
#   ('Fermt3', 151),
#   ('Lpxn', 23),
#   ('Tbx20', 73),
#   ('Atp6v0c-ps2', 37),
#   ('Rinl', 53),
#   ('Slamf8', 51),
#   ('Ctla2b', 58),
#   ('Cd300ld', 22),
#   ('AI467606', 132),
#   ('Tbc1d2', 19),
#   ('Gimap3', 143),
#   ('Cd84', 97),
#   ('1100001G20Rik', 126),
#   ('1700055N04Rik', 39),
#   ('Cybb', 261),
#   ('Acer2', 64),
#   ('Klrb1a', 15),
#   ('Mrgpra2b', 123),
#   ('Hmha1', 124),
#   ('Gapt', 28),
#   ('Fbxo5', 12),
#   ('Osm', 69),
#   ('Aoah', 15),
#   ('Ms4a4c', 63),
#   ('H2-DMb2', 242),
#   ('2010016I18Rik', 6),
#   ('Snx20', 131),
#   ('Srpk3', 26),
#   ('Klrb1c', 50),
#   ('Poc1a', 14),
#   ('Rgs14', 10),
#   ('Mogat2', 14),
#   ('Serpina3m', 67),
#   ('Mgl2', 81),
#   ('Sh2d2a', 99),
#   ('Igsf6', 159),
#   ('Ms4a6d', 40),
#   ('Dennd1c', 16),
#   ('Epsti1', 27),
#   ('Pik3r5', 19),
#   ('Chaf1b', 11),
#   ('Serpinb10-ps', 28),
#   ('Sncg', 10),
#   ('Haao', 68),
#   ('Spc24', 48),
#   ('Xlr4b', 12),
#   ('Fcrla', 45),
#   ('Tmem8', 10),
#   ('Ptprc', 194),
#   ('Lrrc25', 64),
#   ('Ube2c', 60),
#   ('4430402I18Rik', 5),
#   ('Spn', 22),
#   ('Kcnj8', 117),
#   ('Cdh5', 68),
#   ('Vsig4', 94),
#   ('Grrp1', 30),
#   ('Apbb3', 11),
#   ('2010001M09Rik', 130),
#   ('Cebpe', 167),
#   ('Ocln', 14),
#   ('Zfp612', 8),
#   ('Fcnb', 251),
#   ('Asf1b', 63),
#   ('Tmem51', 69),
#   ('Lama3', 4),
#   ('Slamf9', 118),
#   ('Trcg1', 8),
#   ('Pyroxd1', 37),
#   ('Mrgpra2a', 18),
#   ('Cd22', 49),
#   ('5430421N21Rik', 32),
#   ('Ms4a7', 37),
#   ('Gcnt1', 27),
#   ('Rin3', 102),
#   ('Shisa9', 7),
#   ('Gm962', 22),
#   ('Ifitm1', 101),
#   ('Oas3', 50),
#   ('Vwf', 55),
#   ('Tnfrsf18', 171),
#   ('Vav1', 34),
#   ('Dok4', 35),
#   ('Fbxl12', 43),
#   ('Gpr35', 11),
#   ('6030408B16Rik', 17),
#   ('Pou2f2', 53),
#   ('Cd3g', 205),
#   ('Gimap4', 101),
#   ('Lilrb3', 86),
#   ('Gbp8', 11),
#   ('Arap3', 65),
#   ('Chi3l1', 183),
#   ('Rgs18', 65),
#   ('Slpi', 222),
#   ('Fam181b', 42),
#   ('Rapgef5', 7),
#   ('Sirpb1b', 6),
#   ('Amz1', 50),
#   ('Gimap7', 112),
#   ('Cpa1', 61),
#   ('Sh2d3c', 137),
#   ('Gga3', 27),
#   ('Myb', 15),
#   ('Ccl22', 23),
#   ('F630028O10Rik', 51),
#   ('Cxcr2', 133),
#   ('Treml2', 58),
#   ('Slc16a7', 9),
#   ('Ebi3', 108),
#   ('Ms4a3', 45),
#   ('Klrd1', 50),
#   ('Ccdc125', 59),
#   ('Pdcd1', 8),
#   ('Dnajb13', 10),
#   ('March1', 60),
#   ('Pf4', 149),
#   ('Sox17', 49),
#   ('Fyb', 116),
#   ('H2-Oa', 155),
#   ('Psd4', 27),
#   ('Sprr1a', 100),
#   ('C5ar1', 195),
#   ('Arhgap4', 13),
#   ('Klra2', 44),
#   ('4931408D14Rik', 8),
#   ('Dpep2', 20),
#   ('Slc7a8', 41),
#   ('Il2rg', 228),
#   ('Artn', 6),
#   ('Ddx59', 3),
#   ('Fpr1', 100),
#   ('Cxcl13', 167),
#   ('Prkcb', 156),
#   ('Hdc', 170),
#   ('Zfp647', 6),
#   ('Stk10', 98),
#   ('Mob3b', 7),
#   ('Samsn1', 68),
#   ('Atp2a3', 54),
#   ('Mmp25', 51),
#   ('Akr1c12', 8),
#   ('Arhgap9', 129),
#   ('Gm11428', 136),
#   ('Folr4', 78),
#   ('Pctp', 38),
#   ('Slfn1', 67),
#   ('Itgb2l', 153),
#   ('Lst1', 55),
#   ('Pnliprp1', 19),
#   ('Tmem149', 30),
#   ('Ncf2', 157),
#   ('Hcls1', 183),
#   ('Adam8', 36),
#   ('Tmem184a', 41),
#   ('Fpr2', 186),
#   ('Gmfg', 191),
#   ('Cxcr6', 84),
#   ('Lilrb4', 197),
#   ('Cd300lf', 150),
#   ('Klrg1', 14),
#   ('Shcbp1', 31),
#   ('Reg1', 52),
#   ('Gm9733', 29),
#   ('Irf4', 19),
#   ('Mrc1', 24),
#   ('Nfe2', 113),
#   ('Tespa1', 31),
#   ('Rnase6', 107),
#   ('Slc2a9', 8),
#   ('Sfpi1', 203),
#   ('Tmem180', 9),
#   ('C130026I21Rik', 23),
#   ('Hist1h2ao', 13),
#   ('Pilra', 180),
#   ('9830107B12Rik', 10),
#   ('Myct1', 62),
#   ('Prtn3', 212),
#   ('Cd8b1', 98),
#   ('Clec4e', 45),
#   ('Itgal', 101),
#   ('Scarf1', 16),
#   ('Cand2', 10),
#   ('Rhoh', 153),
#   ('Clec4n', 17),
#   ('Rab44', 54),
#   ('Pik3cg', 11),
#   ('Inpp5d', 74),
#   ('Gpr18', 159),
#   ('Eppk1', 12),
#   ('Sox18', 89),
#   ('Smpx', 10),
#   ('Ccl3', 72),
#   ('Stk30', 46),
#   ('Pde2a', 147),
#   ('Rcsd1', 89),
#   ('Hk3', 80),
#   ('Itgam', 161),
#   ('1810033B17Rik', 194),
#   ('H2-Q6', 98),
#   ('Ica1', 36),
#   ('Zdhhc24', 48),
#   ('Clec12a', 117),
#   ('Ncr1', 9),
#   ('A430084P05Rik', 49),
#   ('Gm10872', 32),
#   ('Ly75', 59),
#   ('Clcf1', 14),
#   ('Ciita', 32),
#   ('Megf10', 10),
#   ('Gpr65', 40),
#   ('Apoc2', 14),
#   ('Bid', 80),
#   ('Hcst', 32),
#   ('Clec4d', 63),
#   ('Ncf4', 203),
#   ('Ms4a6b', 64),
#   ('Traf1', 52),
#   ('Ccr6', 86),
#   ('Ankrd1', 108),
#   ('Birc5', 77),
#   ('Hps6', 19),
#   ('Emcn', 207),
#   ('Chrdl2', 151),
#   ('Siglecg', 140),
#   ('Ceacam10', 65),
#   ('Rab19', 39),
#   ('Tmem40', 47),
#   ('Ccnb2', 80),
#   ('Dok2', 164),
#   ('Gal', 75),
#   ('Rasl2-9-ps', 5),
#   ('Fam83a', 6),
#   ('Folr2', 60),
#   ('Lcp2', 13),
#   ('Gp49a', 102),
#   ('Slc17a9', 45),
#   ('Foxq1', 51),
#   ('Eif2c4', 27),
#   ('Tnfaip8l2', 145),
#   ('Tspan32', 120),
#   ('Cd300lg', 140),
#   ('Pilrb2', 49),
#   ('Csf2rb2', 6),
#   ('Colec11', 72),
#   ('Ccl12', 75),
#   ('Upp1', 59),
#   ('Ptpn18', 129),
#   ('Cd72', 227),
#   ('Pstpip1', 110),
#   ('Tmem37', 97),
#   ('Kif21b', 8),
#   ('Dusp2', 92),
#   ('Bmf', 5),
#   ('Wdfy4', 25),
#   ('Popdc3', 6),
#   ('Smagp', 137),
#   ('Clec4a3', 73),
#   ('1520402A15Rik', 5),
#   ('Dok3', 116),
#   ('Ncf1', 199)],
#  ('Diaphragm', 'skeletal muscle satellite cell'): [('Adcy1', 6),
#   ('Naip1', 6),
#   ('Chd5', 10),
#   ('Phactr1', 16),
#   ('Cacna1d', 9),
#   ('Pcdhb16', 6),
#   ('Adamts19', 18),
#   ('Slc6a18', 35),
#   ('Blm', 4),
#   ('Tinag', 19),
#   ('Itga4', 21),
#   ('Rtel1', 22),
#   ('Dnahc7b', 9),
#   ('Gpr114', 13),
#   ('Cyp4a10', 6),
#   ('Crtam', 7),
#   ('Olfr558', 5),
#   ('Nrxn3', 7),
#   ('Cntnap5b', 21),
#   ('Abca7', 24),
#   ('Sspo', 10),
#   ('1700019D03Rik', 9),
#   ('Col4a4', 14),
#   ('Zfp108', 6),
#   ('Nfatc4', 17),
#   ('Nlrp4e', 22),
#   ('Dync1i1', 5),
#   ('Hydin', 42),
#   ('Hmmr', 8),
#   ('Mpped1', 8),
#   ('Scn2a1', 20),
#   ('9830166K06Rik', 26),
#   ('Esco2', 32),
#   ('Nek11', 22),
#   ('Dlgap1', 11),
#   ('Gnb1l', 6),
#   ('Dnahc5', 12),
#   ('Lrrtm2', 15),
#   ('Nrxn2', 13),
#   ('Slc9a10', 9),
#   ('Ttk', 25),
#   ('Mlc1', 12),
#   ('Sis', 38),
#   ('Dnahc6', 60),
#   ('Erc2', 27),
#   ('Acnat1', 4),
#   ('Unc79', 39),
#   ('2010317E24Rik', 21),
#   ('Col4a3', 26),
#   ('Mei4', 7),
#   ('Fat3', 22),
#   ('Fam135b', 7),
#   ('Zic1', 7),
#   ('Lrp8', 29),
#   ('Skint5', 22),
#   ('Abcc8', 29),
#   ('Abca13', 30),
#   ('Cdh8', 8),
#   ('Lao1', 19),
#   ('2900011O08Rik', 7),
#   ('Cyp4f17', 6),
#   ('Spnb3', 7),
#   ('D430041D05Rik', 6),
#   ('Skint6', 24),
#   ('Adam23', 23),
#   ('Col19a1', 3),
#   ('Cftr', 11),
#   ('Cubn', 10),
#   ('Cyp2c53-ps', 3),
#   ('Gbp11', 12),
#   ('Fap', 8),
#   ('Ccbe1', 7),
#   ('Fastkd1', 9),
#   ('Lrrc48', 24),
#   ('Sept12', 5),
#   ('Dnahc10', 22),
#   ('Abca4', 41),
#   ('1110012J17Rik', 13),
#   ('F5', 25),
#   ('Grik1', 22),
#   ('Glb1l3', 30),
#   ('Eme1', 26),
#   ('Sorcs3', 14),
#   ('Spnb1', 29),
#   ('Abca16', 9),
#   ('Jag2', 19),
#   ('Pde6a', 17),
#   ('Clip2', 13),
#   ('Lrp2', 50),
#   ('Gpr98', 36),
#   ('Gm13154', 11),
#   ('Rgs22', 30),
#   ('Trp73', 32),
#   ('Espl1', 19),
#   ('Serac1', 17),
#   ('Dnahc9', 44),
#   ('Scn9a', 44),
#   ('Cep55', 15),
#   ('Evl', 29),
#   ('Oca2', 6),
#   ('Il18r1', 5),
#   ('Gng3', 11),
#   ('Col6a6', 28),
#   ('Rnf17', 33),
#   ('Mak', 5),
#   ('Mpped2', 5),
#   ('Lrrc9', 11),
#   ('Slit1', 6),
#   ('Rgs17', 7),
#   ('Slc22a29', 21),
#   ('Pex26', 16),
#   ('Slc7a14', 14),
#   ('Aoc3', 17),
#   ('Spag16', 7),
#   ('Fabp7', 18),
#   ('Eno2', 14),
#   ('Cd19', 24),
#   ('Slc16a13', 22),
#   ('Plag1', 7),
#   ('Gng8', 16),
#   ('Atp2b2', 37),
#   ('Tll2', 6),
#   ('Gucy1a2', 9),
#   ('Xylb', 9),
#   ('Pth1r', 23),
#   ('Cdh12', 41),
#   ('Rsad2', 56),
#   ('Usp13', 15),
#   ('Ncan', 11),
#   ('Obscn', 22),
#   ('Diras2', 15),
#   ('Armc9', 8),
#   ('Clnk', 19),
#   ('4930547E14Rik', 9),
#   ('Sfmbt2', 8),
#   ('Cdh23', 15),
#   ('Onecut2', 6),
#   ('Lrp1b', 34),
#   ('Lepr', 9),
#   ('Atcay', 30),
#   ('Spink5', 26),
#   ('Ccdc88b', 38),
#   ('Fam65b', 10),
#   ('Heatr7b1', 28),
#   ('Mypn', 33),
#   ('Alox12', 12),
#   ('Mirlet7f-1', 11),
#   ('Kcnt2', 15),
#   ('Adam22', 7),
#   ('Fndc7', 15),
#   ('Sorcs2', 16),
#   ('Bex4', 9),
#   ('Plxna4', 20),
#   ('Rbm11', 28),
#   ('Adcy10', 33),
#   ('Hormad1', 8),
#   ('Tdrd1', 23),
#   ('Smgc', 23),
#   ('Trpc4', 22),
#   ('Cdc20', 32),
#   ('Slc5a4a', 11),
#   ('Pira6', 6),
#   ('Trim30d', 31),
#   ('Slc28a3', 5),
#   ('Otogl', 11),
#   ('Tpo', 8),
#   ('Cacna1h', 15),
#   ('Trpm8', 10),
#   ('Tecta', 15),
#   ('Plcb1', 5),
#   ('Tmem116', 21),
#   ('Hnf4g', 13),
#   ('3110047P20Rik', 5),
#   ('Kif26a', 23),
#   ('Rims2', 6),
#   ('Nova2', 36),
#   ('Papln', 17),
#   ('Plch1', 11),
#   ('Selp', 8),
#   ('Gpr135', 29),
#   ('Dsc3', 6),
#   ('Muc19', 20),
#   ('Myh8', 7),
#   ('Eomes', 21),
#   ('Dnahc17', 42),
#   ('F10', 6),
#   ('Snap91', 6),
#   ('Veph1', 7),
#   ('Aox3l1', 19),
#   ('5930412G12Rik', 24),
#   ('Plcg2', 34),
#   ('Bpifb2', 15),
#   ('Tg', 9),
#   ('Atp13a5', 7),
#   ('Alkbh4', 15),
#   ('Cacna2d3', 15),
#   ('Cend1', 12),
#   ('Asah2', 8),
#   ('Myof', 20),
#   ('Pdzrn4', 23),
#   ('Zfp882', 4),
#   ('Cmah', 13),
#   ('Sox2', 5),
#   ('Fbxo16', 15),
#   ('Csmd3', 10),
#   ('Col25a1', 38),
#   ('Kif1a', 8),
#   ('Lama1', 26),
#   ('Myom1', 20),
#   ('Cdk15', 13),
#   ('Atp12a', 15),
#   ('Fam184b', 17),
#   ('Zan', 29),
#   ('Cdh6', 13),
#   ('Hells', 9),
#   ('Hephl1', 21),
#   ('Pzp', 28),
#   ('Smyd1', 16),
#   ('Tdrd9', 6),
#   ('Myo3b', 19),
#   ('Sgcg', 16),
#   ('Pik3c2g', 17),
#   ('Gm16119', 25),
#   ('Rimbp2', 13),
#   ('Rad51', 13),
#   ('Shank2', 23),
#   ('Casc5', 6),
#   ('Cbl', 15),
#   ('Megf11', 16),
#   ('Dock2', 27),
#   ('Armc4', 28),
#   ('Cldn19', 30),
#   ('Gimap9', 11),
#   ('Slc22a30', 5),
#   ('Col22a1', 34),
#   ('Scn11a', 42),
#   ('Gm17821', 31),
#   ('Mgam', 12),
#   ('Nsun7', 5),
#   ('Wdr62', 19),
#   ('Upb1', 6),
#   ('Tex15', 8),
#   ('Cenpe', 6),
#   ('Kcnd3', 37),
#   ('Gabrr1', 23),
#   ('Adamts3', 26),
#   ('Slc6a12', 11),
#   ('Asb15', 19),
#   ('Mybpc2', 24),
#   ('Col7a1', 48),
#   ('Card9', 42),
#   ('Dnahc2', 8),
#   ('Lrrc2', 9),
#   ('Slc22a14', 18),
#   ('Kcnh4', 7),
#   ('Tnip3', 10),
#   ('9430018G01Rik', 26),
#   ('Slc18a1', 7),
#   ('5830473C10Rik', 5),
#   ('Mybphl', 40),
#   ('Ccdc114', 15),
#   ('Vwa3a', 9),
#   ('Neu3', 14),
#   ('Epha5', 16),
#   ('Ush2a', 41),
#   ('Inadl', 15),
#   ('Pik3ap1', 42),
#   ('Tiam1', 28),
#   ('Psma8', 9),
#   ('Pcdh15', 12),
#   ('Reln', 8),
#   ('Scn3a', 32),
#   ('Kif21b', 13),
#   ('Dcc', 31),
#   ('Myh6', 18),
#   ('Gys2', 10),
#   ('L3mbtl1', 32),
#   ('Tbc1d2', 14),
#   ('2810417H13Rik', 21),
#   ('Nrgn', 18),
#   ('Msh5', 16),
#   ('Exog', 6),
#   ('BC030867', 6),
#   ('Odz2', 12),
#   ('Dok5', 9),
#   ('Trpm2', 43),
#   ('Dpys', 16),
#   ('Nalcn', 30),
#   ('Ptprt', 50),
#   ('Trim66', 16),
#   ('Olfr56', 4),
#   ('Olfr613', 20),
#   ('Wisp2', 24),
#   ('Ptpn7', 27),
#   ('Arhgap30', 76),
#   ('Galm', 29),
#   ('Gzmb', 31),
#   ('Xlr4a', 43),
#   ('Csf2rb', 39),
#   ('Ccdc85a', 17),
#   ('Gm12250', 40),
#   ('Acpp', 10),
#   ('Prss57', 26),
#   ('Mrap', 8),
#   ('Pla2g7', 16),
#   ('Ccl8', 10),
#   ('Myoc', 102),
#   ('Tnfrsf4', 45),
#   ('Gm20324', 12),
#   ('Itgb7', 93),
#   ('Cyp4f18', 105),
#   ('Cd48', 84),
#   ('Rdh12', 25),
#   ('1700047M11Rik', 18),
#   ('Zfp563', 14),
#   ('Gpr97', 81),
#   ('Abhd6', 14),
#   ('Ell3', 6),
#   ('Gm5483', 10),
#   ('H2-DMb1', 82),
#   ('Slfn4', 48),
#   ('Fetub', 40),
#   ('Slc15a3', 20),
#   ('Ankrd22', 46),
#   ('Slc26a10', 79),
#   ('Cd7', 33),
#   ('Hamp', 15),
#   ('Cd40', 32),
#   ('Clec4a2', 67),
#   ('Gm9696', 11),
#   ('Pilrb1', 26),
#   ('Nkg7', 164),
#   ('Ifi203', 40),
#   ('Fcrl5', 26),
#   ('BC013712', 38),
#   ('Tmem170', 13),
#   ('Clec5a', 45),
#   ('Naip2', 7),
#   ('Gm3435', 5),
#   ('Pxmp2', 5),
#   ('Lat', 48),
#   ('Arg2', 20),
#   ('Il5ra', 7),
#   ('Hist1h2bb', 5),
#   ('AI662270', 37),
#   ('Gm15987', 41),
#   ('Vill', 16),
#   ('Pyhin1', 18),
#   ('Inhba', 52),
#   ('Tmem154', 42),
#   ('Sh2d1a', 12),
#   ('Csf2ra', 37),
#   ('E330020D12Rik', 15),
#   ('Bak1', 10),
#   ('AB124611', 73),
#   ('Ifitm6', 150),
#   ('Napsa', 130),
#   ('Mpo', 146),
#   ('Rhof', 25),
#   ('Pex11c', 29),
#   ('Gpr133', 22),
#   ('5031426D15Rik', 5),
#   ('Efemp1', 94),
#   ('Vpreb3', 30),
#   ('Tnnt2', 93),
#   ('Mmp12', 29),
#   ('Cdk1', 34),
#   ('Ctsk', 24),
#   ('Cfp', 116),
#   ('Cygb', 116),
#   ('Ramp1', 10),
#   ('Cst7', 31),
#   ('Lrrc27', 10),
#   ('Ms4a4b', 126),
#   ('A930024E05Rik', 16),
#   ('Lbp', 80),
#   ('Cd209f', 6),
#   ('Arhgef15', 18),
#   ('Siglece', 51),
#   ('Ltb4r1', 108),
#   ('Serpina3f', 11),
#   ('Nbeal2', 5),
#   ('A530064D06Rik', 51),
#   ('Htra4', 24),
#   ('2310005G13Rik', 19),
#   ('Alox5', 54),
#   ('Il1b', 136),
#   ('Dhrs9', 15),
#   ('B430306N03Rik', 53),
#   ('S1pr4', 110),
#   ('Stat4', 18),
#   ('Mapk13', 39),
#   ('Ear2', 24),
#   ('Igj', 30),
#   ('Tnfrsf13c', 67),
#   ('Krba1', 11),
#   ('Lmo7', 15),
#   ('Syk', 44),
#   ('Nfkbid', 36),
#   ('Snca', 41),
#   ('Fbxl16', 20),
#   ('2200002D01Rik', 7),
#   ('Asprv1', 22),
#   ('Clec7a', 25),
#   ('Ccdc69', 19),
#   ('Saa3', 15),
#   ('Olfm4', 10),
#   ('Fcer2a', 44),
#   ('Gm13212', 8),
#   ('Serpina3g', 56),
#   ('Col6a5', 27),
#   ('Padi4', 33),
#   ('Gm4902', 83),
#   ('Lefty1', 6),
#   ('Pygl', 125),
#   ('9430060I03Rik', 7),
#   ('Ms4a6c', 26),
#   ('Ccr1', 51),
#   ('Ctsg', 49),
#   ('Neil3', 28),
#   ('Gm8369', 29),
#   ('Wdr54', 7),
#   ('Hba-a1', 152),
#   ('Fgr', 9),
#   ('Blk', 54),
#   ('Bcl2a1d', 40),
#   ('Faim3', 149),
#   ('Gzmk', 11),
#   ('Bmx', 14),
#   ('Treml1', 11),
#   ('C4b', 89),
#   ('Wdhd1', 16),
#   ('C920009B18Rik', 20),
#   ('Bank1', 23),
#   ('Tro', 16),
#   ('Ccl9', 68),
#   ('1500031L02Rik', 26),
#   ('Ankrd39', 29),
#   ('Tnni3', 48),
#   ('Lipc', 9),
#   ('Gabre', 4),
#   ('Fam150b', 31),
#   ('Rgs19', 56),
#   ('G0s2', 67),
#   ('Mbnl3', 21),
#   ('Ms4a1', 45),
#   ('Trib2', 16),
#   ('Rnf144a', 40),
#   ('Acp5', 47),
#   ('Rspo1', 12),
#   ('Gatsl3', 20),
#   ('Ctsw', 39),
#   ('Ahsg', 93),
#   ('Cd33', 42),
#   ('Fanca', 9),
#   ('Fes', 5),
#   ('Sult1e1', 28),
#   ('Ankrd37', 8),
#   ('Spock2', 41),
#   ('Nipal3', 18),
#   ('Gimap8', 6),
#   ('Slamf6', 35),
#   ('Khdrbs3', 8),
#   ('Kif22', 38),
#   ('Bmper', 15),
#   ('Il1r2', 58),
#   ('Scrg1', 6),
#   ('Il1rn', 11),
#   ('Mnda', 27),
#   ('Stap1', 15),
#   ('Cd300lb', 33),
#   ('Glipr1', 38),
#   ('Tmem204', 84),
#   ('Bst1', 39),
#   ('Penk', 146),
#   ('Myl7', 22),
#   ('Cxcr3', 54),
#   ('Tbc1d10c', 56),
#   ('Fmnl1', 28),
#   ('Gdf15', 12),
#   ('6330407A03Rik', 6),
#   ('Il1f9', 25),
#   ('1810013D10Rik', 24),
#   ('Gm8909', 9),
#   ('Sit1', 29),
#   ('Doc2g', 6),
#   ('Pigz', 21),
#   ('Cyfip2', 31),
#   ('Casp2', 42),
#   ('Sirpb1a', 9),
#   ('Unc119', 23),
#   ('Trem3', 146),
#   ('Csf3r', 67),
#   ('Ppm1m', 22),
#   ('Ebf2', 8),
#   ('Cd2', 126),
#   ('Cd69', 14),
#   ('Hist1h2an', 7),
#   ('Fut7', 20),
#   ('Lca5l', 8),
#   ('Atp6v0c-ps2', 7),
#   ('AA467197', 38),
#   ('Gys1', 55),
#   ('AI607873', 54),
#   ('Slfn2', 106),
#   ('Arid3a', 45),
#   ('Cilp', 33),
#   ('Il17d', 16),
#   ('Tac1', 12),
#   ('Batf', 123),
#   ('Gimap3', 41),
#   ('1100001G20Rik', 40),
#   ('Cybb', 170),
#   ('Mrgpra2b', 63),
#   ('Eno4', 8),
#   ('Atp1a3', 9),
#   ('Hmha1', 98),
#   ('Osm', 31),
#   ('Tigit', 44),
#   ('Aoah', 39),
#   ('Ms4a4c', 52),
#   ('Snx20', 45),
#   ('Arhgap19', 16),
#   ('Klrb1c', 20),
#   ('Lect1', 35),
#   ('Rgs14', 36),
#   ('Lyz1', 59),
#   ('Mgl2', 14),
#   ('Sh2d2a', 18),
#   ('Igsf6', 79),
#   ('Serpina3m', 36),
#   ('Ptprcap', 175),
#   ('Epsti1', 18),
#   ('Pik3r5', 13),
#   ('1810021B22Rik', 31),
#   ('Prg4', 12),
#   ('Klk14', 6),
#   ('Matk', 10),
#   ('Srpx', 76),
#   ('Mns1', 21),
#   ('Haao', 30),
#   ('Fcrla', 19),
#   ('Cd160', 7),
#   ('Unc13d', 14),
#   ('Ptprc', 74),
#   ('Lrrc25', 37),
#   ('Ube2c', 42),
#   ('Spn', 28),
#   ('Vsig4', 57),
#   ('Hs3st1', 13),
#   ('Cdca8', 11),
#   ('Cacna1s', 5),
#   ('Fcnb', 188),
#   ('Cebpe', 50),
#   ('Pik3r6', 16),
#   ('Asf1b', 26),
#   ('2010001M09Rik', 104),
#   ('Cd22', 15),
#   ('5430421N21Rik', 34),
#   ('Ms4a7', 16),
#   ('Rin3', 26),
#   ('Srcrb4d', 6),
#   ('Amica1', 22),
#   ('Gm962', 8),
#   ('Twf2', 98),
#   ('Oas3', 20),
#   ('Tnfrsf18', 45),
#   ('Vwf', 16),
#   ('Ccdc51', 9),
#   ('Acap1', 19),
#   ('Plk1', 9),
#   ('Itgax', 19),
#   ('Gimap4', 99),
#   ('Cd3g', 97),
#   ('Lilrb3', 44),
#   ('Apobr', 19),
#   ('Il28ra', 5),
#   ('Chi3l1', 126),
#   ('Rgs18', 23),
#   ('Slpi', 140),
#   ('Rnasel', 29),
#   ('Meox1', 26),
#   ('Sirpb1b', 6),
#   ('C1rl', 27),
#   ('Gimap7', 30),
#   ('Sh2d3c', 35),
#   ('Osbpl7', 13),
#   ('Ikzf1', 23),
#   ('Pram1', 25),
#   ('F630028O10Rik', 33),
#   ('Cxcr2', 101),
#   ('Tmem53', 17),
#   ('4931431C16Rik', 5),
#   ('Pi15', 21),
#   ('Treml2', 51),
#   ('Zfp296', 9),
#   ('Ms4a3', 39),
#   ('Sostdc1', 30),
#   ('Klrd1', 12),
#   ('Ccdc125', 16),
#   ('Icos', 14),
#   ('H2-Oa', 59),
#   ('Car8', 29),
#   ('Gm13315', 7),
#   ('C5ar1', 123),
#   ('Gda', 135),
#   ('Psd4', 28),
#   ('BC100451', 8),
#   ('Hspb7', 6),
#   ('Clec10a', 8),
#   ('Dock8', 21),
#   ('4931408D14Rik', 5),
#   ('Stac2', 41),
#   ('Dpep2', 17),
#   ('Fpr1', 32),
#   ('Cxcl13', 106),
#   ('Prkcb', 20),
#   ('Hdc', 72),
#   ('Ccdc28b', 15),
#   ('Mmp25', 9),
#   ('Tnfsf13b', 35),
#   ('Sh3tc1', 8),
#   ('Arhgap9', 53),
#   ('Gm11428', 63),
#   ('Folr4', 26),
#   ('Slfn1', 64),
#   ('Zap70', 41),
#   ('Csrp3', 15),
#   ('Itgb2l', 48),
#   ('Ncf2', 92),
#   ('LOC100038947', 21),
#   ('Serpina3c', 5),
#   ('Adam8', 38),
#   ('Ctla4', 19),
#   ('Tarm1', 32),
#   ('Cd3d', 78),
#   ('Itgb2', 110),
#   ('Arhgap25', 55),
#   ('Fpr2', 93),
#   ('Arrb2', 97),
#   ('Gmfg', 108),
#   ('Mblac1', 16),
#   ('Cxcr6', 35),
#   ('Tk1', 5),
#   ('Lilrb4', 76),
#   ('Cd300lf', 50),
#   ('Prdm16', 19),
#   ('Atp8b4', 9),
#   ('Irf4', 24),
#   ('Nfam1', 71),
#   ('Tespa1', 17),
#   ('Nfe2', 55),
#   ('Rnase6', 45),
#   ('Sfpi1', 136),
#   ('C130026I21Rik', 9),
#   ('Myct1', 39),
#   ('Tox2', 8),
#   ('9830107B12Rik', 16),
#   ('Prtn3', 135),
#   ('Cd8b1', 12),
#   ('Pilra', 65),
#   ('Clec4e', 17),
#   ('Ptplad2', 17),
#   ('Ccl6', 147),
#   ('Ralgps2', 14),
#   ('Skap1', 54),
#   ('Ndufa4l2', 20),
#   ('Malt1', 12),
#   ('Tmod4', 23),
#   ('Ccdc92', 11),
#   ('Ifi30', 110),
#   ('Stmn2', 6),
#   ('Ccdc99', 6),
#   ('Fcho1', 9),
#   ('Ifi205', 53),
#   ('Gpr18', 113),
#   ('Sox18', 71),
#   ('Gm7609', 17),
#   ('Gimap1', 83),
#   ('Ccl3', 54),
#   ('Avpr1a', 19),
#   ('Lax1', 11),
#   ('Ssbp4', 50),
#   ('Stk30', 22),
#   ('Pgf', 31),
#   ('Gm885', 38),
#   ('Elovl4', 6),
#   ('Rcsd1', 65),
#   ('Slc2a6', 20),
#   ('Rasgrp2', 30),
#   ('Hk3', 73),
#   ('Wipf3', 10),
#   ('Gas2', 5),
#   ('1810033B17Rik', 147),
#   ('Txlnb', 9),
#   ('Clec12a', 94),
#   ('Ncr1', 34),
#   ('Adora2a', 6),
#   ('A530032D15Rik', 29),
#   ('A430084P05Rik', 82),
#   ('Gm10872', 24),
#   ('Gpsm3', 16),
#   ('Gm11346', 12),
#   ('Sept1', 29),
#   ('Clec4d', 29),
#   ('Hcst', 25),
#   ('Ciita', 17),
#   ('Apoc2', 28),
#   ('Rassf4', 18),
#   ('Traf1', 11),
#   ('Ncf4', 117),
#   ('Ccr6', 46),
#   ('Birc5', 28),
#   ('Trim30a', 33),
#   ('H2-Q8', 6),
#   ('Mndal', 72),
#   ('Batf3', 14),
#   ('Emcn', 101),
#   ('Thbs4', 38),
#   ('Siglecg', 39),
#   ('Ceacam10', 43),
#   ('Rab19', 7),
#   ('Ccnb2', 50),
#   ('Zfp94', 11),
#   ('Dok2', 25),
#   ('5430435G22Rik', 39),
#   ('Tmem40', 8),
#   ('Aldh1a2', 11),
#   ('Paox', 16),
#   ('Robo4', 20),
#   ('Gja4', 47),
#   ('Lcp2', 24),
#   ('C7', 46),
#   ('Gp49a', 48),
#   ('Ankrd33b', 15),
#   ('Mmp23', 40),
#   ('Slc17a9', 43),
#   ('Zc3h12d', 16),
#   ('Gpr182', 24),
#   ('Tnfaip8l2', 74),
#   ('2610039C10Rik', 33),
#   ('Tspan32', 50),
#   ('Cd300lg', 98),
#   ('Pilrb2', 52),
#   ('Pla1a', 25),
#   ('Colec11', 58),
#   ('Pnkp', 70),
#   ('Enpp6', 28),
#   ('Ccl12', 10),
#   ('Klrk1', 9),
#   ('Ptpn18', 60),
#   ('Rab3a', 39),
#   ('Cd72', 106),
#   ('Epyc', 9),
#   ('Ankrd29', 19),
#   ('Pstpip1', 82),
#   ('St8sia4', 17),
#   ('Susd1', 6),
#   ('Spic', 6),
#   ('Myo1f', 63),
#   ('Mapk4', 9),
#   ('Zwilch', 14),
#   ('Dok3', 60),
#   ('Cd37', 149),
#   ('Ncf1', 141)],
#  ('Fat', 'endothelial cell'): [('Pou5f2', 6),
#   ('Pla2r1', 97),
#   ('Hoga1', 13),
#   ('Mgst2', 5),
#   ('Taf4a', 30),
#   ('Pde1a', 97),
#   ('Xk', 12),
#   ('Tfap4', 9),
#   ('Ctxn1', 8),
#   ('Ggt7', 21),
#   ('Myoc', 12),
#   ('2310050B05Rik', 47),
#   ('Ccl8', 7),
#   ('H2-Q7', 10),
#   ('Lrrc45', 34),
#   ('Fam158a', 23),
#   ('Rad51ap2', 27),
#   ('Klc2', 15),
#   ('Mpl', 11),
#   ('Adcyap1r1', 48),
#   ('Meis3', 27),
#   ('1190007F08Rik', 76),
#   ('Ppp1r3a', 16),
#   ('Tnnc2', 7),
#   ('1110002L01Rik', 6),
#   ('Pcdhb13', 6),
#   ('Tmtc4', 6),
#   ('Col12a1', 14),
#   ('Rem1', 83),
#   ('Camk2n2', 20),
#   ('Cd83', 17),
#   ('Hoxc6', 87),
#   ('Zbp1', 29),
#   ('P2ry10', 15),
#   ('Daam2', 121),
#   ('Itga7', 120),
#   ('Gpr132', 9),
#   ('Serf1', 46),
#   ('Hspb8', 66),
#   ('Rpgrip1', 5),
#   ('Stac', 120),
#   ('Fbxw9', 30),
#   ('H1fx', 41),
#   ('Gm12185', 7),
#   ('Gm15708', 5),
#   ('Kctd15', 51),
#   ('Zfp365', 21),
#   ('Apoc1', 6),
#   ('Ppbp', 10),
#   ('Ng23', 14),
#   ('Agt', 64),
#   ('Fap', 52),
#   ('Gp1bb', 10),
#   ('5031426D15Rik', 7),
#   ('Dlk1', 37),
#   ('Clip2', 58),
#   ('Ngb', 34),
#   ('Fcna', 7),
#   ('Htra4', 42),
#   ('F830016B08Rik', 10),
#   ('Irx2', 7),
#   ('Zbed4', 5),
#   ('Il2ra', 65),
#   ('E030013I19Rik', 38),
#   ('Vmn2r-ps129', 14),
#   ('Dnm1', 7),
#   ('Ggt5', 48),
#   ('Eya1', 6),
#   ('2610019E17Rik', 42),
#   ('Saa3', 4),
#   ('Hbb-b2', 5),
#   ('Echdc1', 11),
#   ('Sfmbt2', 7),
#   ('Twist2', 33),
#   ('Plxdc1', 60),
#   ('Mpv17l', 10),
#   ('Xrcc6bp1', 7),
#   ('Hoxc9', 42),
#   ('Entpd4', 12),
#   ('Cdh2', 94),
#   ('Uchl1', 13),
#   ('Mrvi1', 110),
#   ('Bcl2a1d', 8),
#   ('Adig', 9),
#   ('Fgd4', 7),
#   ('Treml1', 11),
#   ('Rab37', 20),
#   ('Il34', 134),
#   ('1810011H11Rik', 116),
#   ('Pabpn1l', 3),
#   ('Clec4b1', 9),
#   ('Shox2', 53),
#   ('Adssl1', 19),
#   ('Svip', 13),
#   ('Brsk1', 18),
#   ('Zfp874a', 10),
#   ('Nlrp5', 9),
#   ('Wscd2', 30),
#   ('E130203B14Rik', 115),
#   ('2010204K13Rik', 45),
#   ('Gm14295', 56),
#   ('Fzd2', 41),
#   ('Vtn', 101),
#   ('Figf', 25),
#   ('Cxcl2', 21),
#   ('Slc17a7', 5),
#   ('Ttll3', 19),
#   ('Rasl10b', 39),
#   ('Cend1', 45),
#   ('Ppox', 50),
#   ('Speg', 77),
#   ('Ccl11', 39),
#   ('Pip4k2b', 26),
#   ('Adcy7', 8),
#   ('S1pr3', 107),
#   ('Agtr1a', 120),
#   ('Prosapip1', 5),
#   ('Tnnt3', 8),
#   ('Cdkn2b', 13),
#   ('Nkd1', 98),
#   ('Ntrk3', 49),
#   ('Lmtk3', 4),
#   ('Abhd3', 19),
#   ('Miip', 4),
#   ('Tmem14a', 21),
#   ('Atf5', 70),
#   ('Apol9b', 5),
#   ('Gm3646', 56),
#   ('Samd4', 77),
#   ('Pdgfc', 18),
#   ('Ccl7', 11),
#   ('Hbb-b1', 24),
#   ('Tbx18', 83),
#   ('Ptpla', 86),
#   ('Cilp', 8),
#   ('Slc2a3', 29),
#   ('Fgf9', 11),
#   ('Peg10', 8),
#   ('Gdpd3', 8),
#   ('Rasl12', 119),
#   ('Zfp938', 10),
#   ('Galntl1', 74),
#   ('3930402G23Rik', 37),
#   ('Hebp2', 27),
#   ('Ccl19', 9),
#   ('Sytl2', 27),
#   ('Arhgef17', 112),
#   ('Adipoq', 11),
#   ('Lyz1', 8),
#   ('Gm10941', 19),
#   ('Slc16a6', 34),
#   ('Foxo4', 40),
#   ('Zbtb12', 19),
#   ('Kcne4', 113),
#   ('Abcc9', 123),
#   ('Dact3', 64),
#   ('Gtdc1', 8),
#   ('Gp9', 7),
#   ('Lrrc25', 12),
#   ('Spn', 7),
#   ('Kcnj8', 104),
#   ('Msln', 17),
#   ('Dlg4', 28),
#   ('2010001M09Rik', 24),
#   ('Cpne7', 9),
#   ('2810032G03Rik', 27),
#   ('Ttc39c', 5),
#   ('4930572J05Rik', 16),
#   ('Rab42-ps', 29),
#   ('Ifitm1', 75),
#   ('Iqsec3', 16),
#   ('Ccne1', 8),
#   ('Arhgef10l', 61),
#   ('2700038G22Rik', 7),
#   ('Slc2a4', 97),
#   ('Sfrp4', 12),
#   ('Orm1', 6),
#   ('Zic1', 8),
#   ('Gm5176', 5),
#   ('Src', 68),
#   ('Mark1', 82),
#   ('Rgs18', 9),
#   ('1500009L16Rik', 109),
#   ('Slpi', 7),
#   ('2010320M18Rik', 9),
#   ('Lin7a', 89),
#   ('Mnd1', 111),
#   ('March9', 17),
#   ('Cxcr4', 20),
#   ('A030009H04Rik', 12),
#   ('Ybx2', 52),
#   ('Trnp1', 36),
#   ('Gins2', 9),
#   ('Lrrc23', 21),
#   ('Gm3604', 6),
#   ('Rpl39l', 17),
#   ('Gm3833', 91),
#   ('Pf4', 28),
#   ('2410004N09Rik', 31),
#   ('Psd4', 6),
#   ('Upk3b', 8),
#   ('6230409E13Rik', 10),
#   ('Slc6a17', 47),
#   ('Sema5b', 42),
#   ('D630041G03Rik', 53),
#   ('Batf2', 5),
#   ('Zfp647', 6),
#   ('Gm527', 6),
#   ('Fbxo2', 9),
#   ('Rgma', 53),
#   ('Hoxc8', 87),
#   ('Aoc3', 133),
#   ('Zfp781', 4),
#   ('Gstm6', 6),
#   ('Tead3', 54),
#   ('Mpz', 9),
#   ('Csrp3', 4),
#   ('Higd1b', 133),
#   ('Prph', 22),
#   ('Ffar2', 45),
#   ('Gucy1a2', 92),
#   ('Hoxc4', 42),
#   ('Cd163l1', 11),
#   ('Rhod', 18),
#   ('Kcnip3', 22),
#   ('Gm9899', 28),
#   ('Gdap10', 34),
#   ('Prrx1', 95),
#   ('Plekhh2', 49),
#   ('Tnni2', 6),
#   ('Hspb2', 100),
#   ('Gipr', 65),
#   ('Gm10653', 15),
#   ('Fbxl15', 11),
#   ('Twist1', 97),
#   ('4921530L18Rik', 17),
#   ('Cdkn2a', 9),
#   ('Dtx4', 66),
#   ('Pip5k1b', 52),
#   ('Pcgf2', 15),
#   ('Fxyd2', 14),
#   ('Urb1', 16),
#   ('Gvin1', 9),
#   ('Ckm', 5),
#   ('Synpo2', 111),
#   ('Gm3002', 21),
#   ('1600015I10Rik', 57),
#   ('Gm7609', 15),
#   ('Avpr1a', 90),
#   ('Itga10', 19),
#   ('Olfr920', 4),
#   ('Mgat3', 31),
#   ('Cadm1', 11),
#   ('Gm10400', 53),
#   ('Npy1r', 94),
#   ('Adra2a', 53),
#   ('Col5a3', 78),
#   ('Cdk15', 50),
#   ('Ddit4l', 83),
#   ('2410022L05Rik', 5),
#   ('Ccl24', 9),
#   ('Ciita', 7),
#   ('Haghl', 21),
#   ('Csprs', 13),
#   ('Timm8a1', 21),
#   ('Cadm3', 25),
#   ('Gm5069', 7),
#   ('Zfp385a', 26),
#   ('Gm17762', 7),
#   ('D630033O11Rik', 23),
#   ('Tnf', 15),
#   ('2010001M06Rik', 81),
#   ('Ppp1r1a', 19),
#   ('Neurl4', 37),
#   ('Wnt5b', 8),
#   ('Pacsin3', 50),
#   ('Shf', 11),
#   ('Isoc2a', 39),
#   ('Gm4832', 8),
#   ('Sh3yl1', 6),
#   ('Hdac11', 48),
#   ('Hnmt', 24),
#   ('Htr7', 33),
#   ('Efna2', 42),
#   ('Rom1', 8),
#   ('AI429214', 7),
#   ('Tmc5', 34),
#   ('Syp', 4),
#   ('Meg3', 69),
#   ('Prkca', 69),
#   ('2610016A17Rik', 9)],
#  ('Fat', 'mesenchymal stem cell'): [('Tcap', 25),
#   ('Sgcg', 32),
#   ('Pvalb', 36),
#   ('Mylpf', 30),
#   ('Ccdc85a', 3),
#   ('Mybpc1', 29),
#   ('Gm5069', 16),
#   ('Myf5', 11),
#   ('Chrdl2', 9),
#   ('Fitm1', 33),
#   ('Lmod2', 31),
#   ('Myl1', 29),
#   ('Murc', 28),
#   ('Magix', 14),
#   ('Myct1', 9),
#   ('Mb', 22),
#   ('Atp2a1', 25),
#   ('Actn2', 26),
#   ('Mybpc2', 30),
#   ('Cacna1s', 12),
#   ('Cox6a2', 27),
#   ('Tnnc2', 30),
#   ('Pgam2', 24),
#   ('Rapsn', 26),
#   ('Ckm', 22),
#   ('Armc3', 4),
#   ('Myot', 29),
#   ('Smpx', 32),
#   ('Eef1a2', 34),
#   ('Xirp2', 25),
#   ('Pax7', 9),
#   ('St8sia5', 41),
#   ('Csrp3', 26),
#   ('4933436C20Rik', 6),
#   ('Cdh15', 11),
#   ('Stac3', 19),
#   ('Phospho1', 19),
#   ('Kbtbd10', 30),
#   ('A330049M08Rik', 20),
#   ('Fam181b', 13),
#   ('Sfrp5', 25),
#   ('Cyyr1', 3),
#   ('Egfl8', 21),
#   ('Rimklb', 18),
#   ('Fa2h', 23),
#   ('Rasgef1c', 10),
#   ('Ephb1', 17),
#   ('Slc35f1', 16),
#   ('Zfp536', 12),
#   ('Cadm4', 22),
#   ('Lypd2', 5),
#   ('Ddn', 19),
#   ('Vmn2r-ps129', 3),
#   ('Reln', 22),
#   ('2310046A06Rik', 28),
#   ('Gm106', 22),
#   ('Foxd3', 24),
#   ('Sox10', 25),
#   ('Kank4', 18),
#   ('Vat1l', 20),
#   ('Mpz', 24),
#   ('Mt3', 23),
#   ('Snca', 22),
#   ('Kcna6', 13),
#   ('Dhh', 23),
#   ('L1cam', 14),
#   ('Rbp7', 21),
#   ('A530032D15Rik', 8),
#   ('Timp4', 13),
#   ('Slpi', 9),
#   ('Egfl7', 21),
#   ('Gm6531', 5),
#   ('Cxcr4', 12),
#   ('Mrgprg', 29),
#   ('1700003F12Rik', 4),
#   ('Adipoq', 12),
#   ('Csprs', 6),
#   ('Irx3', 6),
#   ('Ankrd1', 9),
#   ('Tgfb1', 12),
#   ('Ablim3', 6),
#   ('Cfd', 22),
#   ('Ccl4', 30),
#   ('Sncg', 34),
#   ('Rpl39l', 31),
#   ('C130026I21Rik', 9),
#   ('C1qtnf9', 16),
#   ('Gm12504', 18),
#   ('Cdh5', 20),
#   ('ORF63', 13),
#   ('2010001M09Rik', 5),
#   ('Dach1', 15),
#   ('Snhg11', 4),
#   ('Fcna', 8),
#   ('Isoc2a', 11),
#   ('Podxl', 7),
#   ('4930572J05Rik', 4),
#   ('Gpihbp1', 23),
#   ('Dll4', 9),
#   ('Gpr132', 14),
#   ('Irx1', 15),
#   ('Rpgrip1', 9),
#   ('Zic1', 10),
#   ('Retn', 5),
#   ('4930503E24Rik', 8)],
#  ('HSC', 'hematopoietic stem cell'): [('Irgc1', 9),
#   ('Bpifa2', 9),
#   ('Syt4', 10),
#   ('Cryaa', 10),
#   ('Snhg11', 8),
#   ('Actc1', 8),
#   ('Mup3', 10),
#   ('Ldhc', 9),
#   ('Spt1', 9),
#   ('Chia', 10),
#   ('4930528F23Rik', 4),
#   ('Ermap', 40),
#   ('Il1rl1', 24),
#   ('Rhag', 39),
#   ('Fam55b', 39),
#   ('Slc25a21', 40),
#   ('Asb17', 35),
#   ('2200002K05Rik', 21),
#   ('Cpt1c', 10),
#   ('Stk32c', 21),
#   ('Hpn', 39),
#   ('Ng23', 19),
#   ('Slc4a1', 13),
#   ('Kel', 37),
#   ('Hba-a1', 12),
#   ('Cited4', 44),
#   ('Rhd', 36),
#   ('Ank1', 32),
#   ('Prss50', 39),
#   ('2610034M16Rik', 10),
#   ('Gpr77', 36),
#   ('Snca', 30),
#   ('AI427809', 27),
#   ('Gm15915', 40),
#   ('Aldh1a7', 33),
#   ('Paqr9', 35),
#   ('D930028M14Rik', 31),
#   ('Hba-a2', 10),
#   ('Cldn13', 38),
#   ('BC021614', 29),
#   ('AA986860', 11),
#   ('Klf1', 43),
#   ('Phyhip', 29),
#   ('Sphk1', 39),
#   ('Add2', 37),
#   ('Trim10', 28),
#   ('Ces2g', 45),
#   ('Ccl17', 24),
#   ('Ccdc68', 35),
#   ('Ephx2', 34),
#   ('Fcer1a', 3),
#   ('Pklr', 34),
#   ('Epor', 42),
#   ('Csrp3', 17),
#   ('Tmem56', 32),
#   ('Tspo2', 43),
#   ('Gypa', 42),
#   ('2510003D18Rik', 36),
#   ('Il4i1', 13),
#   ('Prg2', 6),
#   ('Tigit', 16),
#   ('Ms4a4c', 52),
#   ('Nkx6-1', 7),
#   ('Mogat2', 14),
#   ('Sh2d2a', 44),
#   ('Gpr142', 8),
#   ('Slc2a2', 29),
#   ('Tnfrsf4', 17),
#   ('Cyp4f18', 62),
#   ('Lta', 46),
#   ('Ell3', 43),
#   ('Pou2af1', 63),
#   ('Fcrla', 55),
#   ('Kcnip1', 10),
#   ('Gm5483', 11),
#   ('Slfn4', 6),
#   ('Vwa5b2', 13),
#   ('Krt4', 12),
#   ('Frzb', 28),
#   ('Hs3st1', 19),
#   ('Grap', 94),
#   ('Spib', 82),
#   ('2010001M09Rik', 56),
#   ('Cebpe', 19),
#   ('A330076H08Rik', 29),
#   ('Mrgpra2a', 13),
#   ('Cd22', 54),
#   ('Rab30', 25),
#   ('Cd83', 65),
#   ('Cd40', 54),
#   ('Clec4a2', 17),
#   ('C2cd4b', 58),
#   ('Fcrl5', 16),
#   ('Rab3b', 13),
#   ('Orm1', 7),
#   ('Ddc', 42),
#   ('Gimap4', 71),
#   ('Cd3g', 67),
#   ('Abcc8', 56),
#   ('Chst3', 25),
#   ('B830017H08Rik', 20),
#   ('Ncam1', 24),
#   ('Stk32a', 6),
#   ('Il9r', 23),
#   ('Scd1', 31),
#   ('Gpr183', 64),
#   ('Pdx1', 20),
#   ('Smpdl3b', 5),
#   ('Entpd3', 6),
#   ('Gm15987', 39),
#   ('Sh2d1a', 12),
#   ('Tcf7', 64),
#   ('Ifitm6', 18),
#   ('Scg5', 80),
#   ('Snap25', 36),
#   ('Scgn', 55),
#   ('Them5', 10),
#   ('Prf1', 6),
#   ('1300014I06Rik', 47),
#   ('Ebf1', 79),
#   ('Pdcd1', 8),
#   ('Myt1l', 7),
#   ('Gng4', 32),
#   ('Neurod1', 18),
#   ('Gm13315', 24),
#   ('Slc29a4', 9),
#   ('Cd8a', 29),
#   ('Chst13', 15),
#   ('H2-Eb2', 29),
#   ('Krt13', 7),
#   ('Ikzf3', 33),
#   ('Cr2', 46),
#   ('Slc7a14', 23),
#   ('Tmem215', 17),
#   ('Fam151a', 16),
#   ('Folr4', 41),
#   ('Trpm5', 8),
#   ('Slfn1', 11),
#   ('Dnase1l3', 36),
#   ('Krtdap', 9),
#   ('Isl1', 41),
#   ('Ucn3', 63),
#   ('Ctla4', 10),
#   ('Cd3d', 34),
#   ('Saa3', 5),
#   ('Fcer2a', 75),
#   ('Pgap1', 18),
#   ('Wnt4', 56),
#   ('Gm8369', 34),
#   ('Blk', 77),
#   ('Irf4', 7),
#   ('Bcl2a1d', 15),
#   ('Cacna1f', 15),
#   ('Gzmk', 7),
#   ('Slc30a8', 79),
#   ('Cd8b1', 49),
#   ('Fam46c', 8),
#   ('Pmaip1', 29),
#   ('Skap1', 45),
#   ('Bank1', 67),
#   ('Dbpht2', 22),
#   ('Prss16', 8),
#   ('Asb2', 9),
#   ('Cma1', 17),
#   ('Gpr18', 90),
#   ('Slitrk2', 7),
#   ('Gm1604b', 6),
#   ('Chgb', 68),
#   ('Cacna2d1', 7),
#   ('6330512M04Rik', 7),
#   ('Ncr1', 10),
#   ('Slamf6', 49),
#   ('A430084P05Rik', 5),
#   ('Syt13', 44),
#   ('Ciita', 20),
#   ('Gm6377', 15),
#   ('Traf1', 27),
#   ('Ccr6', 62),
#   ('Gad1', 9),
#   ('Cxcr3', 43),
#   ('Scg3', 77),
#   ('Igfbp2', 11),
#   ('Upb1', 5),
#   ('Tmem90a', 8),
#   ('Sphkap', 18),
#   ('Lrg1', 19),
#   ('Il1f9', 10),
#   ('Gjd2', 10),
#   ('Sit1', 14),
#   ('Insrr', 5),
#   ('Serpina10', 9),
#   ('Zc3h12d', 57),
#   ('Il2rb', 15),
#   ('Trem3', 22),
#   ('Ppp1r1a', 18),
#   ('Klrk1', 5),
#   ('Cd2', 77),
#   ('Mreg', 10),
#   ('Cd3e', 6),
#   ('Tmem27', 74),
#   ('Bcl11b', 6),
#   ('Pcsk1n', 79),
#   ('Tnfrsf9', 17),
#   ('Ccdc109b', 5),
#   ('1700045I19Rik', 10),
#   ('Sntg2', 8),
#   ('Gimap3', 77),
#   ('Nap1l5', 27),
#   ('1100001G20Rik', 21),
#   ('Ptprn2', 51),
#   ('Cybb', 58),
#   ('Dtx1', 35),
#   ('G6pc2', 97),
#   ('Mrgpra2b', 20),
#   ('Gm13546', 5),
#   ('Rhoj', 17),
#   ('Muc1', 7),
#   ('Tdrd9', 4),
#   ('Agtr1a', 9),
#   ('Tc2n', 10),
#   ('Gkn3', 6),
#   ('A230065H16Rik', 19),
#   ('Efna1', 10),
#   ('Darc', 8),
#   ('2410017I17Rik', 4),
#   ('Ehd3', 24),
#   ('Dnm3', 6),
#   ('Slamf1', 26),
#   ('Rhbdl2', 4),
#   ('Vwf', 23),
#   ('Matn4', 26),
#   ('Glipr1l1', 9),
#   ('Rbpjl', 8),
#   ('Reep2', 17),
#   ('Gp1bb', 19),
#   ('Jam2', 23),
#   ('Rorc', 17),
#   ('Tnfsf4', 6),
#   ('Gm5833', 11),
#   ('Hoxb6', 4),
#   ('Myo1e', 9),
#   ('Clca1', 25),
#   ('Rcvrn', 17),
#   ('Gpx8', 17),
#   ('Hoxb9', 4),
#   ('Dync1i1', 1),
#   ('Cyp26b1', 15),
#   ('Runx1t1', 18),
#   ('Myom1', 15)],
#  ('Heart_and_Aorta', 'endocardial cell'): [('Dnase1l2', 7),
#   ('Afap1l2', 74),
#   ('Tbx1', 58),
#   ('Ncaph', 23),
#   ('Gpr30', 41),
#   ('Pou5f2', 7),
#   ('Lhx6', 55),
#   ('Cyp7b1', 45),
#   ('Cxcl17', 5),
#   ('Fmn1', 5),
#   ('Foxp2', 37),
#   ('Pcdhb20', 12),
#   ('Ccdc85a', 44),
#   ('Slco2b1', 30),
#   ('Zbtb12', 17),
#   ('Klk14', 35),
#   ('Ntf3', 31),
#   ('Prg4', 56),
#   ('Fgfr3', 97),
#   ('Tril', 24),
#   ('Ch25h', 53),
#   ('Spc24', 29),
#   ('Fam55d', 97),
#   ('Fam57b', 7),
#   ('Ccbp2', 57),
#   ('Pcdhb12', 10),
#   ('Islr2', 42),
#   ('Gm694', 81),
#   ('Ces2e', 7),
#   ('Dtx1', 75),
#   ('Unc5b', 80),
#   ('Cdt1', 45),
#   ('Cyp26b1', 61),
#   ('C1qtnf9', 116),
#   ('C1qtnf6', 18),
#   ('Alpl', 95),
#   ('Ramp3', 130),
#   ('AI836003', 66),
#   ('Cdca8', 49),
#   ('Grrp1', 122),
#   ('Tbc1d9', 13),
#   ('Itih3', 12),
#   ('Tnfrsf26', 9),
#   ('Slc26a10', 100),
#   ('Car4', 51),
#   ('Tmem51', 11),
#   ('Plek2', 66),
#   ('Brip1', 6),
#   ('Tbxa2r', 71),
#   ('Pcdhb9', 6),
#   ('Arhgef10l', 5),
#   ('Nepn', 67),
#   ('Sgsm1', 39),
#   ('Cdca3', 22),
#   ('Lrrn4cl', 59),
#   ('Ckap2', 47),
#   ('Srgap3', 28),
#   ('Frk', 13),
#   ('Lrrc18', 24),
#   ('Rd3', 9),
#   ('Fbxw9', 8),
#   ('Cmklr1', 57),
#   ('Sdcbp2', 56),
#   ('Pthlh', 40),
#   ('Il20rb', 36),
#   ('Rbp7', 117),
#   ('2700099C18Rik', 24),
#   ('1500009L16Rik', 43),
#   ('Map3k5', 48),
#   ('Meox1', 101),
#   ('Tnfrsf25', 54),
#   ('4930422G04Rik', 12),
#   ('Nov', 67),
#   ('Endou', 15),
#   ('Thrsp', 99),
#   ('Kctd15', 45),
#   ('2210009G21Rik', 8),
#   ('Adamts8', 12),
#   ('Cfb', 132),
#   ('Thy1', 60),
#   ('Cacna1a', 6),
#   ('Gja5', 84),
#   ('Tmc8', 13),
#   ('Kcna5', 56),
#   ('Sh3gl3', 53),
#   ('Sema7a', 82),
#   ('Rasa4', 72),
#   ('Clspn', 54),
#   ('Cxcl9', 58),
#   ('Hdac9', 51),
#   ('Ube2t', 52),
#   ('C2', 28),
#   ('Sox17', 131),
#   ('Kremen2', 20),
#   ('Ifi204', 18),
#   ('Cgref1', 30),
#   ('Aplnr', 60),
#   ('Jag2', 77),
#   ('Hba-a2', 9),
#   ('Ret', 41),
#   ('E130012A19Rik', 16),
#   ('Tchh', 4),
#   ('Armc3', 24),
#   ('Reep1', 18),
#   ('Tmem178', 53),
#   ('Pcdh1', 92),
#   ('Fam101b', 130),
#   ('Trim46', 10),
#   ('St14', 57),
#   ('Pcdh19', 68),
#   ('Bambi-ps1', 71),
#   ('Atp2a3', 71),
#   ('Mmp17', 12),
#   ('Adamtsl1', 61),
#   ('Lpar4', 60),
#   ('Aoc3', 47),
#   ('Gpr56', 106),
#   ('Fam71a', 34),
#   ('Ebf3', 58),
#   ('Kif4', 74),
#   ('G630055G22Rik', 59),
#   ('Ccdc67', 21),
#   ('Prkcz', 45),
#   ('Gjc1', 126),
#   ('Pbx3', 12),
#   ('Sema3g', 75),
#   ('Apol10b', 24),
#   ('Kif23', 51),
#   ('Duoxa2', 46),
#   ('Eps8l2', 83),
#   ('Spa17', 4),
#   ('Cecr2', 20),
#   ('Bach2', 7),
#   ('Cenpq', 22),
#   ('Serpinb6b', 96),
#   ('Gm15706', 18),
#   ('6430548M08Rik', 36),
#   ('Hbb-b2', 4),
#   ('Agmo', 6),
#   ('Fam64a', 42),
#   ('Cst6', 23),
#   ('Stk32c', 32),
#   ('Alox12', 55),
#   ('Ido1', 7),
#   ('Naip5', 11),
#   ('Ablim3', 55),
#   ('Snai1', 45),
#   ('Hist2h3c1', 13),
#   ('Wdr54', 11),
#   ('Uchl1', 45),
#   ('Cdc20', 7),
#   ('2610305D13Rik', 87),
#   ('C130026I21Rik', 7),
#   ('Magix', 28),
#   ('Il7', 51),
#   ('Hspa1b', 55),
#   ('Fam89a', 63),
#   ('Scn3b', 64),
#   ('L1cam', 12),
#   ('Meox2', 126),
#   ('Cdkn2a', 28),
#   ('Ank3', 49),
#   ('Selp', 19),
#   ('Pcbp3', 21),
#   ('Efr3b', 67),
#   ('Pdgfa', 82),
#   ('Wnt9b', 58),
#   ('Oas2', 54),
#   ('Stmn2', 143),
#   ('Ptprr', 122),
#   ('Hoxd4', 53),
#   ('Sele', 19),
#   ('Sema3d', 61),
#   ('Tcf23', 76),
#   ('Arhgef26', 34),
#   ('Gm8580', 3),
#   ('E2f2', 4),
#   ('Car7', 78),
#   ('Eef1a2', 17),
#   ('Pcdhb22', 12),
#   ('Slc52a3', 81),
#   ('Tbx3', 48),
#   ('Gm1987', 64),
#   ('Tnfrsf11a', 21),
#   ('Hip1r', 33),
#   ('Pparg', 50),
#   ('Cblb', 27),
#   ('Hist1h2ac', 15),
#   ('Ltc4s', 106),
#   ('Trpm3', 21),
#   ('Gprc5a', 76),
#   ('Ankrd37', 111),
#   ('Ckap2l', 30),
#   ('Chst1', 14),
#   ('Mlf1', 14),
#   ('2900041M22Rik', 36),
#   ('Adora2a', 26),
#   ('Syt7', 94),
#   ('Timp4', 69),
#   ('Kif22', 25),
#   ('Kcnb1', 79),
#   ('Ciita', 17),
#   ('Apba2', 54),
#   ('Fam167a', 14),
#   ('Syn2', 27),
#   ('Csprs', 20),
#   ('Dnm3', 110),
#   ('Cadm3', 30),
#   ('Birc5', 41),
#   ('Nkd1', 24),
#   ('Pcsk6', 103),
#   ('Mndal', 90),
#   ('Gap43', 38),
#   ('Slc28a2', 80),
#   ('Bean1', 35),
#   ('4930506M07Rik', 99),
#   ('Wt1', 78),
#   ('6530418L21Rik', 6),
#   ('Miip', 14),
#   ('Hoxd9', 42),
#   ('B230312A22Rik', 22),
#   ('Lbx2', 53),
#   ('Htr2b', 62),
#   ('Rspo3', 73),
#   ('D930048N14Rik', 13),
#   ('Neurl1b', 25),
#   ('Slc27a3', 54),
#   ('4833422C13Rik', 50),
#   ('Mmrn1', 72),
#   ('Wdr67', 4),
#   ('Lfng', 55),
#   ('Csf2rb2', 39),
#   ('Tmem71', 91),
#   ('Pcdh17', 84),
#   ('Ccl12', 16),
#   ('Dach1', 64),
#   ('4632434I11Rik', 18),
#   ('Pllp', 54),
#   ('Aim1', 55),
#   ('Olfr1372-ps1', 54),
#   ('Slc12a8', 22),
#   ('Npl', 24),
#   ('Fam38b', 47),
#   ('St8sia4', 63),
#   ('AA467197', 64),
#   ('Trpc3', 35),
#   ('Serpina1b', 65),
#   ('Lmo1', 102),
#   ('Tpx2', 34),
#   ('Reln', 62),
#   ('Scn3a', 53),
#   ('Cks2', 39),
#   ('Ttyh1', 45),
#   ('Nod2', 72),
#   ('Arid3a', 12),
#   ('Prom1', 66),
#   ('Zbtb7c', 59),
#   ('1520402A15Rik', 9),
#   ('Hoxa7', 73),
#   ('St8sia6', 62),
#   ('Gm14393', 5),
#   ('Olfr613', 85),
#   ('Wisp2', 113),
#   ('Crlf1', 28),
#   ('Ptpn7', 39),
#   ('1700001C19Rik', 7),
#   ('Mgst2', 18),
#   ('Csf2rb', 88),
#   ('Mmp8', 172),
#   ('Ccl8', 8),
#   ('Rgs1', 128),
#   ('Mmp9', 174),
#   ('Itgb7', 173),
#   ('Slc11a1', 159),
#   ('Bpifa2', 20),
#   ('Clec4a1', 123),
#   ('Slfn4', 74),
#   ('Mpl', 16),
#   ('Fetub', 44),
#   ('Ccl5', 159),
#   ('Frzb', 57),
#   ('Tfrc', 46),
#   ('Myo1g', 165),
#   ('Spib', 119),
#   ('Cd7', 179),
#   ('Msr1', 126),
#   ('Trem1', 140),
#   ('Chia', 20),
#   ('Fam132b', 118),
#   ('Nkg7', 175),
#   ('Basp1', 151),
#   ('Gpr153', 44),
#   ('Nrm', 76),
#   ('1810044D09Rik', 19),
#   ('Tnni1', 15),
#   ('Apbb1ip', 140),
#   ('S100a4', 74),
#   ('Lat', 167),
#   ('Bcl2a1b', 152),
#   ('Corin', 8),
#   ('Chst3', 104),
#   ('Prkar1b', 11),
#   ('Apod', 184),
#   ('Lad1', 57),
#   ('Adamts4', 53),
#   ('Car11', 7),
#   ('Tmem154', 39),
#   ('Ifitm6', 165),
#   ('Slc4a3', 60),
#   ('Mpo', 176),
#   ('Napsa', 177),
#   ('Pydc3', 105),
#   ('Rhof', 149),
#   ('Cpeb1', 12),
#   ('Mmp12', 148),
#   ('Cd163', 102),
#   ('Cst7', 82),
#   ('Ms4a4d', 211),
#   ('Unc5a', 4),
#   ('Ms4a4b', 198),
#   ('Cd209f', 41),
#   ('Siglece', 110),
#   ('Ltb4r1', 157),
#   ('Fcna', 16),
#   ('A530064D06Rik', 93),
#   ('Htra4', 6),
#   ('Ly6g6c', 51),
#   ('Pla2g1b', 20),
#   ('B430306N03Rik', 125),
#   ('Kif9', 11),
#   ('Alox5ap', 197),
#   ('Rab25', 47),
#   ('Fgfbp1', 65),
#   ('Ear2', 121),
#   ('Tnfrsf13c', 121),
#   ('Igj', 99),
#   ('Ropn1l', 11),
#   ('Syk', 117),
#   ('Fam178b', 8),
#   ('4833419F23Rik', 23),
#   ('Clec7a', 80),
#   ('Arhgap15', 116),
#   ('Saa3', 63),
#   ('Fcer2a', 25),
#   ('Spink5', 62),
#   ('Padi4', 161),
#   ('Gm4902', 83),
#   ('Fam102a', 32),
#   ('Akr1c13', 22),
#   ('Ltb', 192),
#   ('1700025K23Rik', 14),
#   ('Stambpl1', 29),
#   ('Camp', 186),
#   ('Klhl29', 10),
#   ('Ms4a6c', 133),
#   ('Pcdhb21', 16),
#   ('Ccr1', 138),
#   ('Ctsg', 57),
#   ('Reg3g', 76),
#   ('Hba-a1', 111),
#   ('Fgr', 109),
#   ('Blk', 68),
#   ('Gzmk', 123),
#   ('Ugt1a6a', 130),
#   ('Ankrd35', 77),
#   ('Bank1', 85),
#   ('Krt36', 91),
#   ('Gca', 18),
#   ('Cd177', 192),
#   ('Elf4', 45),
#   ('Lipc', 5),
#   ('Cela3b', 30),
#   ('Cxcl2', 142),
#   ('Tg', 73),
#   ('Ager', 22),
#   ('Ccl17', 83),
#   ('Acp5', 148),
#   ('Rspo1', 76),
#   ('Slc25a13', 9),
#   ('Ccl11', 192),
#   ('Pnlip', 19),
#   ('Wdr90', 32),
#   ('Rorb', 22),
#   ('Klf8', 6),
#   ('Il1r2', 122),
#   ('Mnda', 126),
#   ('Cd300lb', 108),
#   ('Glipr1', 138),
#   ('Penk', 197),
#   ('Cdkn2b', 25),
#   ('Fam154b', 6),
#   ('Tbc1d10c', 170),
#   ('Fcgr4', 44),
#   ('Fam129c', 72),
#   ('Tubb3', 20),
#   ('Was', 130),
#   ('Trem3', 157),
#   ('Thbs1', 55),
#   ('Clps', 18),
#   ('Lpxn', 130),
#   ('Tbx20', 44),
#   ('5730528L13Rik', 8),
#   ('9030612E09Rik', 27),
#   ('Cenpm', 51),
#   ('Ccl7', 171),
#   ('Il17d', 122),
#   ('Cilp', 75),
#   ('Cd79b', 206),
#   ('Map4k1', 135),
#   ('1100001G20Rik', 46),
#   ('Cybb', 164),
#   ('Mecr', 22),
#   ('Mrgpra2b', 130),
#   ('Slc9a9', 34),
#   ('Osm', 133),
#   ('Tigit', 110),
#   ('Emid1', 108),
#   ('Mki67', 81),
#   ('Aoah', 114),
#   ('Ms4a4c', 84),
#   ('Krt6a', 87),
#   ('Cttnbp2', 6),
#   ('Lect1', 43),
#   ('Mrc2', 148),
#   ('Rgs14', 45),
#   ('Lyz1', 133),
#   ('Mgl2', 128),
#   ('Serpina3m', 144),
#   ('Igsf6', 112),
#   ('Bpifa1', 88),
#   ('Serpinb10-ps', 42),
#   ('Hp', 213),
#   ('Kcne4', 23),
#   ('Cd160', 157),
#   ('Ube2c', 77),
#   ('Spn', 159),
#   ('Dio2', 9),
#   ('Vsig4', 158),
#   ('2010001M09Rik', 135),
#   ('Cebpe', 138),
#   ('Fcnb', 184),
#   ('Asf1b', 74),
#   ('Kmo', 106),
#   ('Ms4a7', 17),
#   ('Tnfrsf18', 154),
#   ('Plk1', 79),
#   ('Scg2', 64),
#   ('Fhit', 40),
#   ('Rnf157', 12),
#   ('Lilrb3', 129),
#   ('Retnlg', 172),
#   ('Cntfr', 135),
#   ('Ly6c2', 190),
#   ('Rtn4rl1', 120),
#   ('Slpi', 152),
#   ('Sirpb1b', 54),
#   ('Smpdl3b', 70),
#   ('Amz1', 25),
#   ('Ccl22', 87),
#   ('Kif26b', 11),
#   ('F630028O10Rik', 129),
#   ('Cxcr2', 100),
#   ('Scgb1a1', 76),
#   ('Ebi3', 126),
#   ('Gpatch3', 6),
#   ('Ms4a3', 109),
#   ('Camk1d', 34),
#   ('Gm13315', 34),
#   ('Hs3st3a1', 30),
#   ('Gda', 155),
#   ('Cd8a', 148),
#   ('Scgb3a1', 52),
#   ('Adamtsl5', 8),
#   ('Msc', 111),
#   ('Dpep2', 81),
#   ('Fpr1', 90),
#   ('Cxcl13', 159),
#   ('Krt13', 92),
#   ('Prkcb', 171),
#   ('Dmkn', 111),
#   ('Kng2', 20),
#   ('Arhgap9', 145),
#   ('Folr4', 73),
#   ('Cyp2u1', 9),
#   ('Barx2', 83),
#   ('Lst1', 14),
#   ('Higd1b', 33),
#   ('Klc3', 82),
#   ('Gng8', 31),
#   ('Ncf2', 150),
#   ('Adam8', 144),
#   ('Pglyrp1', 200),
#   ('Il6', 197),
#   ('Fpr2', 126),
#   ('Muc1', 9),
#   ('Gmfg', 127),
#   ('Gdap10', 49),
#   ('Cxcr6', 48),
#   ('Tk1', 86),
#   ('Ccdc88b', 20),
#   ('Tnni2', 6),
# ...
#   ('Mblac2', 85),
#   ('Rtkn', 23),
#   ('Tpsb2', 17),
#   ('A730090N16Rik', 8),
#   ('Dmpk', 29),
#   ('Tmem98', 59),
#   ('Mirlet7d', 14),
#   ('Klkb1', 62),
#   ('Sema5a', 36),
#   ('Abtb1', 69),
#   ('Cidea', 14),
#   ('Ccl20', 26),
#   ('Adamts5', 167),
#   ('Rab37', 71),
#   ('Colq', 66),
#   ('Slc30a8', 118),
#   ('Clca1', 15),
#   ('Ntrk2', 129),
#   ('Mvk', 66),
#   ('Rhebl1', 21),
#   ('Parp16', 21),
#   ('Pdxp', 58),
#   ('Zfp772', 78),
#   ('Cryba2', 65),
#   ('Krt36', 432),
#   ('Serpinb2', 135),
#   ('Ehd2', 117),
#   ('Fbln2', 337),
#   ('F10', 151),
#   ('Krt10', 72),
#   ('Zfp367', 13),
#   ('Tnni3', 85),
#   ('Rnls', 25),
#   ('Nags', 39),
#   ('Gm4956', 49),
#   ('Car7', 73),
#   ('Cd109', 10),
#   ('Tmtc1', 27),
#   ('2810055F11Rik', 32),
#   ('Ccdc28a', 23),
#   ('Dsp', 294),
#   ('Tmem25', 14),
#   ('Tfcp2', 15),
#   ('Cyp4f39', 82),
#   ('Timm8a2', 9),
#   ('Sult1e1', 62),
#   ('Hic1', 17),
#   ('Gm6194', 65),
#   ('Sftpb', 139),
#   ('Lekr1', 12),
#   ('Gas8', 137),
#   ('S1pr3', 154),
#   ('Lpar3', 26),
#   ('Kdr', 101),
#   ('Greb1l', 10),
#   ('Igfbp2', 349),
#   ('Dnajc12', 75),
#   ('Abhd3', 8),
#   ('Slco2a1', 24),
#   ('Tnnc1', 44),
#   ('Musk', 89),
#   ('Gpx2', 273),
#   ('1700013N18Rik', 19),
#   ('Zfp384', 24),
#   ('Zfp93', 9),
#   ('Myo6', 111),
#   ('Lamc2', 69),
#   ('Rnf217', 32),
#   ('Lrrc36', 57),
#   ('Atp6v0c-ps2', 98),
#   ('Pcsk1n', 78),
#   ('Gm8615', 37),
#   ('Hbb-b1', 134),
#   ('Mgll', 380),
#   ('Tmem100', 247),
#   ('Rsph9', 31),
#   ('Gm94', 119),
#   ('Ace', 124),
#   ('Dsc2', 21),
#   ('Klrb1a', 29),
#   ('Rasl12', 49),
#   ('Vasn', 239),
#   ('Lrat', 54),
#   ('Klhdc8a', 15),
#   ('5730577I03Rik', 9),
#   ('Casc4', 15),
#   ('Fam81a', 22),
#   ('Zfp182', 26),
#   ('4930404N11Rik', 8),
#   ('Tacc2', 120),
#   ('Jmjd7', 28),
#   ('Adprhl2', 52),
#   ('D330050I16Rik', 13),
#   ('Ptges2', 13),
#   ('Gins1', 31),
#   ('Steap4', 250),
#   ('Dph1', 16),
#   ('Kcnmb1', 11),
#   ('Hp', 370),
#   ('Srpx', 295),
#   ('1700019D03Rik', 106),
#   ('Abcc9', 94),
#   ('Dpp10', 10),
#   ('4930402H24Rik', 43),
#   ('Sip1', 26),
#   ('Echdc2', 29),
#   ('Krt6b', 356),
#   ('C1qtnf9', 72),
#   ('Hs3st1', 199),
#   ('Shprh', 20),
#   ('P2rx5', 41),
#   ('March8', 77),
#   ('Dapl1', 197),
#   ('Tmem97', 44),
#   ('Lamb2', 360),
#   ('Islr', 219),
#   ('Cpxm2', 163),
#   ('Mcpt2', 14),
#   ('F2rl2', 76),
#   ('Mustn1', 177),
#   ('Slc27a2', 64),
#   ('Fam83c', 15),
#   ('Gm15663', 24),
#   ('Lmod3', 25),
#   ('C2cd4b', 70),
#   ('Hectd3', 30),
#   ('Vmac', 24),
#   ('Hs1bp3', 12),
#   ('Aqp3', 361),
#   ('Chst15', 14),
#   ('Klra8', 50),
#   ('Gli1', 41),
#   ('Spon2', 341),
#   ('Hoxb2', 98),
#   ('Ikbke', 56),
#   ('Anxa8', 422),
#   ('Arc', 76),
#   ('Nipal2', 178),
#   ('Mtap6', 45),
#   ('Reck', 106),
#   ('Fam181b', 158),
#   ('Grhl3', 119),
#   ('Rapgef5', 85),
#   ('Glmn', 11),
#   ('Sh2d3c', 114),
#   ('Ttc38', 96),
#   ('Adc', 9),
#   ('Fstl3', 32),
#   ('Fibin', 164),
#   ('Tmem53', 32),
#   ('Irgc1', 23),
#   ('Cachd1', 68),
#   ('Cnrip1', 220),
#   ('Them5', 329),
#   ('Sostdc1', 34),
#   ('Foxf2', 18),
#   ('Adh1', 374),
#   ('Mtfp1', 49),
#   ('Lrp4', 132),
#   ('Zcchc12', 80),
#   ('Endog', 21),
#   ('Mttp', 16),
#   ('Phyhd1', 76),
#   ('Cobl', 59),
#   ('Cldn18', 61),
#   ('Sprr1a', 131),
#   ('Mcat', 85),
#   ('Mirg', 80),
#   ('Myoz2', 46),
#   ('Slc36a2', 149),
#   ('Tymp', 25),
#   ('Gm1574', 37),
#   ('Adamtsl2', 45),
#   ('Asns', 91),
#   ('Gpm6b', 334),
#   ('Cr2', 23),
#   ('Wbscr27', 31),
#   ('Egfr', 44),
#   ('Traf3ip1', 8),
#   ('Tmem59l', 103),
#   ('Akr1c12', 47),
#   ('BC024659', 35),
#   ('Krt23', 92),
#   ('S1pr5', 25),
#   ('Krt24', 266),
#   ('AI428936', 19),
#   ('Csrp3', 83),
#   ('Prelp', 301),
#   ('Mavs', 93),
#   ('Tarm1', 20),
#   ('Slit3', 84),
#   ('Fam110c', 26),
#   ('Bace2', 167),
#   ('Fahd2a', 17),
#   ('C030034I22Rik', 13),
#   ('Zfp7', 24),
#   ('Ccdc11', 31),
#   ('Gpnmb', 106),
#   ('Zfp712', 8),
#   ('Cd164l2', 73),
#   ('Svopl', 135),
#   ('Tm7sf2', 33),
#   ('Cst6', 41),
#   ('Abhd14b', 59),
#   ('Neil1', 58),
#   ('Edaradd', 69),
#   ('BC022687', 123),
#   ('Mucl1', 170),
#   ('Slc12a5', 8),
#   ('Gm3925', 10),
#   ('Vwa1', 174),
#   ('Poc5', 34),
#   ('Wnt4', 275),
#   ('2610528J11Rik', 94),
#   ('Sept4', 316),
#   ('Gm2011', 15),
#   ('Chi3l3', 197),
#   ('Amelx', 9),
#   ('6530401N04Rik', 21),
#   ('1700088E04Rik', 39),
#   ('Prtn3', 55),
#   ('Nqo1', 146),
#   ('Calcb', 7),
#   ('Cdkn2a', 58),
#   ('Resp18', 110),
#   ('Pgam2', 14),
#   ('Dcp1b', 8),
#   ('1700030K09Rik', 36),
#   ('Ccdc92', 87),
#   ('Kif19a', 61),
#   ('Glt25d2', 113),
#   ('Prss16', 64),
#   ('Cma1', 16),
#   ('Tm4sf4', 111),
#   ('Fgf7', 119),
#   ('Angpt2', 123),
#   ('Snap47', 54),
#   ('Zfp523', 78),
#   ('Krt16', 442),
#   ('Syngr1', 98),
#   ('Gna14', 16),
#   ('Psd3', 50),
#   ('Mlf1', 122),
#   ('Igtp', 24),
#   ('6030446N20Rik', 18),
#   ('9030025P20Rik', 4),
#   ('Slc16a11', 63),
#   ('Tcap', 15),
#   ('Tmem9', 107),
#   ('Sftpc', 382),
#   ('Gpt', 167),
#   ('Elane', 335),
#   ('Zfp784', 16),
#   ('Ramp2', 243),
#   ('Thbs4', 101),
#   ('Lamb3', 114),
#   ('Itfg2', 10),
#   ('Niacr1', 250),
#   ('Gpsm2', 42),
#   ('Tmem40', 37),
#   ('Peg12', 54),
#   ('B3gnt1', 115),
#   ('Cpz', 42),
#   ('Mmp23', 323),
#   ('Dzip1l', 56),
#   ('Mir5133', 8),
#   ('Slc9a4', 52),
#   ('Fam176a', 110),
#   ('Xpnpep2', 9),
#   ('Fsd1l', 11),
#   ('Spata2l', 123),
#   ('Anxa9', 57),
#   ('Flrt1', 43),
#   ('Ccl12', 15),
#   ('Ism1', 33),
#   ('Fam84a', 29),
#   ('Mybphl', 38),
#   ('Tmc5', 95),
#   ('Plekhh3', 14),
#   ('Kl', 71),
#   ('Ccdc126', 26),
#   ('C1qtnf7', 197),
#   ('Tusc5', 25),
#   ('Dtwd1', 37),
#   ('Tgtp1', 15),
#   ('Fkbp11', 16),
#   ('Gm5779', 29),
#   ('Sftpa1', 367),
#   ('Kcnq1', 105),
#   ('2310042E22Rik', 70),
#   ('Dennd2a', 22),
#   ('Exog', 55),
#   ('Fbp2', 32),
#   ('Nefh', 16),
#   ('Wisp2', 378),
#   ('Wwc1', 8),
#   ('Acpp', 71),
#   ('Rcn1', 108),
#   ('Mylk', 39),
#   ('Gabrp', 19),
#   ('Ccl8', 62),
#   ('Wdr4', 34),
#   ('Cops7b', 57),
#   ('Slc2a2', 69),
#   ('Rdh12', 31),
#   ('Tril', 74),
#   ('Esam', 214),
#   ('Amy1', 30),
#   ('Mb', 124),
#   ('Unc5b', 59),
#   ('Snx21', 25),
#   ('Lgals7', 398),
#   ('Catsper2', 76),
#   ('Vsig10', 14),
#   ('Nme5', 28),
#   ('Angptl2', 173),
#   ('Slc26a10', 21),
#   ('2310061I04Rik', 72),
#   ('Gins3', 62),
#   ('Plek2', 258),
#   ('Eml1', 93),
#   ('Gucy1a3', 131),
#   ('Klk10', 241),
#   ('Krt1', 72),
#   ('Ms4a8a', 44),
#   ('Pou6f1', 14),
#   ('Dusp4', 21),
#   ('Amacr', 69),
#   ('Scnn1b', 10),
#   ('Aspa', 28),
#   ('Myoz1', 26),
#   ('Cd59a', 270),
#   ('Gm5150', 23),
#   ('Mrgprf', 77),
#   ('Tom1l1', 9),
#   ('Gpr180', 154),
#   ('Bspry', 109),
#   ('Fam124a', 12),
#   ('Nxph1', 22),
#   ('Btbd6', 50),
#   ('Clip3', 21),
#   ('Mst1', 23),
#   ('Ncam1', 19),
#   ('Cldn12', 145),
#   ('Adamts4', 117),
#   ('Zfp532', 76),
#   ('Htra3', 290),
#   ('Sox13', 12),
#   ('Pcsk2', 127),
#   ('Cog1', 18),
#   ('Apoc1', 34),
#   ('Ces1b', 115),
#   ('Ephx3', 118),
#   ('Inhba', 90),
#   ('Prickle2', 32),
#   ('Cfb', 269),
#   ('Gstm5', 181),
#   ('Scrn1', 95),
#   ('Tspan7', 200),
#   ('Arv1', 20),
#   ('Gpr133', 63),
#   ('5031426D15Rik', 17),
#   ('Neurod1', 84),
#   ('Hs3st6', 45),
#   ('Eme1', 59),
#   ('Rusc2', 159),
#   ('Lrrc27', 55),
#   ('Lbp', 394),
#   ('Stmn3', 67),
#   ('Tmeff2', 45),
#   ('Fcna', 21),
#   ('Gjb4', 28),
#   ('Spns2', 70),
#   ('Ap1m2', 125),
#   ('B430306N03Rik', 22),
#   ('AU040972', 110),
#   ('Fam151a', 130),
#   ('Rsph1', 79),
#   ('Serpinb12', 31),
#   ('Bcdin3d', 31),
#   ('Slc41a2', 16),
#   ('Mtss1l', 14),
#   ('Armc9', 8),
#   ('Saa3', 143),
#   ('Adcy9', 146),
#   ('Fam183b', 10),
#   ('D10Bwg1379e', 18),
#   ('6430548M08Rik', 64),
#   ('Nfib', 330),
#   ('Kctd21', 17),
#   ('Spink5', 349),
#   ('Mex3d', 22),
#   ('Dsg1b', 159),
#   ('Pcolce2', 372),
#   ('Gm4262', 24),
#   ('Lrrc14', 19),
#   ('Igsf3', 277),
#   ('Cdo1', 270),
#   ('Zfp385c', 18),
#   ('Tgfb1i1', 179),
#   ('Il34', 68),
#   ('Ccdc24', 22),
#   ('Tgm4', 40),
#   ('Hddc3', 16),
#   ('BC090627', 40),
#   ('Fjx1', 20),
#   ('9930012K11Rik', 22),
#   ('Rims2', 7),
#   ('Irg1', 7),
#   ('Meox2', 126),
#   ('Zcchc24', 21),
#   ('Egflam', 27),
#   ('Maob', 170),
#   ('Ccdc17', 19),
#   ('D6Mm5e', 7),
#   ('Slc38a5', 117),
#   ('Gm16845', 26),
#   ('Deaf1', 39),
#   ('Cd200r4', 61),
#   ('Slitrk2', 13),
#   ('Traf3ip3', 52),
#   ('Gon4l', 5),
#   ('Zfp180', 26),
#   ('Hrct1', 36),
#   ('Fbxo25', 44),
#   ('Helb', 15),
#   ('Tsen2', 37),
#   ('Tmem79', 12),
#   ('Poli', 29),
#   ('Ahsg', 233),
#   ('Rspo1', 19),
#   ('Arl10', 25),
#   ('Sybu', 42),
#   ('Foxa2', 53),
#   ('Zfp882', 16),
#   ('Tbx2', 57),
#   ('Samd14', 12),
#   ('Mccc1', 20),
#   ('Lyve1', 26),
#   ('Calr3', 77),
#   ('Gm10565', 44),
#   ('6330512M04Rik', 198),
#   ('Ccdc45', 51),
#   ('Sobp', 99),
#   ('Slamf6', 155),
#   ('Tgds', 102),
#   ('Dnajc18', 42),
#   ('Itgbl1', 57),
#   ('Cdh13', 78),
#   ('Nppa', 341),
#   ('Pdgfrl', 134),
#   ('Cd200r3', 67),
#   ('Gata2', 91),
#   ('100043387', 18),
#   ('Tmem204', 289),
#   ('Gimap5', 113),
#   ('Ctu1', 13),
#   ('Adcy6', 119),
#   ('Penk', 367),
#   ('Mypop', 11),
#   ('Myl7', 154),
#   ('Gstk1', 140),
#   ('Pcsk6', 23),
#   ('Scg3', 86),
#   ('Tubb3', 170),
#   ('Lims2', 242),
#   ('Gprc5b', 15),
#   ('Tnfsf13', 18),
#   ('Klf5', 240),
#   ('Rab36', 74),
#   ('Arxes2', 68),
#   ('AI854517', 36),
#   ('Limch1', 195),
#   ('Klf15', 70),
#   ('Zfp940', 10),
#   ('Crebl2', 42),
#   ('Mcpt4', 73),
#   ('Cyp4b1', 366),
#   ('2700062C07Rik', 55),
#   ('Gdf3', 9),
#   ('Fmo2', 330),
#   ('Tead2', 64),
#   ('Fbxo22', 57),
#   ('Bmp4', 249),
#   ('4930502E09Rik', 30),
#   ('Ptprd', 49),
#   ('Tac1', 22),
#   ('Cyp2s1', 23),
#   ('Tmem202', 20),
#   ('Iigp1', 76),
#   ('Exoc3l', 9),
#   ('Mrgpra2b', 33),
#   ('Il4i1', 67),
#   ('Tspan18', 9),
#   ('2010016I18Rik', 70),
#   ('Hebp2', 46),
#   ('Capn5', 10),
#   ('Arhgef17', 51),
#   ('Ctcfl', 15),
#   ('Efs', 124),
#   ('Kcne4', 50),
#   ('Lgi4', 26),
#   ('Tle6', 9),
#   ('4930432K21Rik', 58),
#   ('Kif21a', 73),
#   ('Psapl1', 50),
#   ('Doc2a', 39),
#   ('Sema3b', 56),
#   ('Zhx2', 51),
#   ('AA986860', 25),
#   ('Alas2', 116),
#   ('2610206C17Rik', 23),
#   ('Kifc5b', 30),
#   ('Ptges', 300),
#   ('Eral1', 24),
#   ('Celsr2', 57),
#   ('4833423E24Rik', 216),
#   ('4930481A15Rik', 28),
#   ('Sfrp4', 111),
#   ('Epha1', 68),
#   ('Dolk', 17),
#   ('Edar', 23),
#   ('Plin4', 16),
#   ('Klra9', 8),
#   ('Rgs5', 94),
#   ('Efna4', 28),
#   ('Tpcn2', 107),
#   ('Baiap2l1', 30),
#   ('Taf1c', 70),
#   ('Cntfr', 188),
#   ('Notum', 30),
#   ('Pik3r4', 10),
#   ('Lsamp', 86),
#   ('Trim29', 289),
#   ('C1rl', 54),
#   ('Gimap7', 36),
#   ('Thrsp', 71),
#   ('Gpr160', 40),
#   ('Defb1', 51),
#   ('Tcf15', 229),
#   ('Aox1', 23),
#   ('H2-M2', 45),
#   ('Ms4a3', 68),
#   ('Zfp28', 22),
#   ('Sox17', 145),
#   ('Rcan2', 43),
#   ('Tspyl3', 50),
#   ('Lysmd2', 87),
#   ('Serpini1', 60),
#   ('Copz2', 222),
#   ('Gm13315', 37),
#   ('Fat2', 22),
#   ('Jmjd4', 49),
#   ('Pick1', 46),
#   ('Pitpnm3', 36),
#   ('Gsdma', 11),
#   ('Oma1', 47),
#   ('Stac2', 49),
#   ('Rtn2', 38),
#   ('Szt2', 14),
#   ('Ret', 71),
#   ('Tchh', 88),
#   ('6430562O15Rik', 12),
#   ('Tslp', 17),
#   ('E130311K13Rik', 117),
#   ('Dgcr14', 69),
#   ('Slc43a1', 28),
#   ('Acaa1b', 7),
#   ('Rpp38', 10),
#   ('Gpihbp1', 357),
#   ('Slc39a4', 135),
#   ('2010305A19Rik', 20),
#   ('2010109A12Rik', 72),
#   ('Pwp2', 41),
#   ('Tcf21', 73),
#   ('E230016K23Rik', 52),
#   ('Gstm6', 58),
#   ('Traf5', 21),
#   ('Gjb5', 34),
#   ('Nadsyn1', 57),
#   ('Gm6568', 83),
#   ('Synm', 70),
#   ('Crabp1', 18),
#   ('Plekhn1', 30),
#   ('Crkl', 12),
#   ('Fam83e', 8),
#   ('Prrx1', 282),
#   ('Ccdc48', 17),
#   ('Rnf152', 11),
#   ('Gm5766', 34),
#   ('Scube2', 55),
#   ('Gm8801', 39),
#   ('Snai1', 127),
#   ('Lgals12', 36),
#   ('Hormad1', 11),
#   ('Car12', 46),
#   ('Agrn', 71),
#   ('Kank3', 89),
#   ('Scarf1', 19),
#   ('Fgf12', 78),
#   ('Angpt4', 21),
#   ('Runx1t1', 11),
#   ('Zfp213', 11),
#   ('Gm1332', 12),
#   ('Sgce', 240),
#   ('Ldhd', 16),
#   ('Lhfp', 367),
#   ('Smyd4', 12),
#   ('Rhoj', 373),
#   ('Epb4.9', 21),
#   ('Myl4', 19),
#   ('Gm17359', 21),
#   ('Hand2', 66),
#   ('Prss53', 71),
#   ('Mettl17', 12),
#   ('Rftn2', 24),
#   ('Aldh3a1', 460),
#   ('Sox18', 213),
#   ('Rhbg', 98),
#   ('Otx1', 22),
#   ('Tdo2', 17),
#   ('Agbl3', 23),
#   ('Tbx3', 113),
#   ('Pigg', 40),
#   ('Sox2', 44),
#   ('C1qtnf2', 37),
#   ('Gm5523', 33),
#   ('4930473A02Rik', 25),
#   ('Cdk20', 58),
#   ('Xrcc5', 106),
#   ('Pawr', 30),
#   ('Armcx1', 88),
#   ('Gltpd1', 27),
#   ('Ddit4l', 25),
#   ('Mt4', 290),
#   ('Ttc36', 18),
#   ('Vangl1', 93),
#   ('Ccl24', 42),
#   ('Txnl4b', 54),
#   ('Pdlim3', 301),
#   ('Gm6484', 20),
#   ('Rab34', 225),
#   ('Robo2', 16),
#   ('Nr2f2', 151),
#   ('Iqcg', 10),
#   ('Ankrd1', 71),
#   ('Zmynd10', 20),
#   ('Akap5', 20),
#   ('Dusp26', 28),
#   ('C1ra', 300),
#   ('Zfp94', 15),
#   ('Sbsn', 147),
#   ('Tnfaip8l3', 26),
#   ('Lhfpl4', 30),
#   ('Clic3', 191),
#   ('Emp2', 299),
#   ('Rspo3', 30),
#   ('Fez1', 149),
#   ('Sult5a1', 105),
#   ('Nradd', 161),
#   ('Gm5434', 28),
#   ('Ankrd54', 58),
#   ('Omp', 47),
#   ('Colec11', 70),
#   ('Plekhg6', 88),
#   ('Enpp6', 45),
#   ('Lama2', 109),
#   ('Tc2n', 8),
#   ('Serpinb5', 281),
#   ('Yipf2', 67),
#   ('Ildr2', 10),
#   ('Olfr1372-ps1', 49),
#   ('Col20a1', 14),
#   ('Nid1', 265),
#   ('Zfp316', 26),
#   ('Upk1a', 11),
#   ('Epyc', 107),
#   ('Gpr157', 11),
#   ('Gja1', 355),
#   ('Foxs1', 100),
#   ('Xpo5', 22),
#   ('Sema3c', 109),
#   ('Xylt2', 30),
#   ('BC020402', 22),
#   ('Fbxl22', 12),
#   ('Ccdc148', 7),
#   ('Trpm1', 8),
#   ('4833427F10Rik', 42),
#   ('Zfp334', 9),
#   ('Ppp1r12b', 12),
#   ('Sncaip', 22),
#   ('Enc1', 94),
#   ('Cmbl', 17),
#   ('Bag2', 49),
#   ('Aldh3b2', 154),
#   ('Efna1', 317),
#   ('Prrg4', 62),
#   ('Hook1', 38),
#   ('Adamtsl3', 8),
#   ('Gba2', 18),
#   ('Nnmt', 211),
#   ('Mrap', 113),
#   ('Ntf3', 61),
#   ('Pkp1', 105),
#   ('Aldh5a1', 69),
#   ('Hs3st3b1', 52),
#   ('Klk11', 30),
#   ('Ankrd16', 18),
#   ('Med18', 22),
#   ('Frzb', 23),
#   ('Larp6', 38),
#   ('Ikbip', 72),
#   ('Cd207', 31),
#   ('Mal', 49),
#   ('Ccdc153', 116),
#   ('Cenpo', 22),
#   ('C77080', 33),
#   ('Dgcr8', 19),
#   ('Moxd1', 177),
#   ('Col12a1', 54),
#   ('Pamr1', 85),
#   ('Rem1', 16),
#   ('Afp', 4),
#   ('Col23a1', 48),
#   ('2310002L13Rik', 44),
#   ('Dvl1', 13),
#   ('Ak1', 221),
#   ('Antxr1', 80),
#   ('Otop3', 21),
#   ('Mtrf1', 111),
#   ('Pemt', 116),
#   ('Cald1', 355),
#   ('Hspb8', 140),
#   ('Cldn5', 367),
#   ('Il20rb', 22),
#   ('Prkar1b', 79),
#   ('Hoxb1', 53),
#   ('Slc22a17', 44),
#   ('2610020C07Rik', 35),
#   ('E330013P06', 127),
#   ('Has1', 423),
#   ('Lypd6b', 73),
#   ('Bmp3', 13),
#   ('Ccnjl', 16),
#   ('Clec11a', 184),
#   ('Nov', 121),
#   ('Calb1', 69),
#   ('Ccdc18', 61),
#   ('Syde1', 70),
#   ('BC057022', 35),
#   ('A430110N23Rik', 70),
#   ('Ccr8', 60),
#   ('Zbtb38', 83),
#   ('Pla2g10', 16),
#   ('Hmgcs2', 143),
#   ('Scgn', 65),
#   ('Gm16793', 73),
#   ('Mfsd2b', 9),
#   ('Nsun5', 10),
#   ('Lcn2', 264),
#   ('Alox15', 23),
#   ('Ighmbp2', 14),
#   ('Lrp2bp', 8),
#   ('Efemp1', 232),
#   ('Gng4', 56),
#   ('Tnnt2', 180),
#   ('Cgref1', 51),
#   ('Ear1', 26),
#   ('Ccdc62', 7),
#   ('Cygb', 322),
#   ('Ms4a4d', 271),
#   ('2700046A07Rik', 52),
#   ('Bcam', 232),
#   ('Tubg2', 28),
#   ('Gm14326', 23),
#   ('Loxl1', 315),
#   ('Fam25c', 36),
#   ('Fras1', 8),
#   ('Pdzd2', 16),
#   ('Aldob', 11),
#   ('Lamc1', 95),
#   ('Mxra8', 429),
#   ('Echdc3', 11),
#   ('Prr15l', 101),
#   ('Prss34', 292),
#   ('Slc25a14', 15),
#   ('Lrdd', 32),
#   ('Psmb11', 43),
#   ('Fam65a', 53),
#   ('Serpine2', 337),
#   ('Rab25', 351),
#   ('Loxl3', 26),
#   ('Efnb2', 136),
#   ('Ptpru', 17),
#   ('A230050P20Rik', 49),
#   ('Tspan11', 45),
#   ('Bdh2', 144),
#   ('Pbx3', 18),
#   ('Lmo7', 13),
#   ('Fam20c', 110),
#   ('Gas1', 168),
#   ('Asprv1', 53),
#   ('Sprr1b', 44),
#   ('Igf2', 30),
#   ('Ly6k', 41),
#   ('Cbx8', 10),
#   ('Fstl1', 281),
#   ('Svep1', 230),
#   ('Nckap1', 29),
#   ('Camp', 259),
#   ('Bok', 84),
#   ('Ccdc149', 11),
#   ('Mfn2', 17),
#   ('Plxna1', 103),
#   ('Gfra3', 69),
#   ('Wnk4', 35),
#   ('Gpx8', 357),
#   ('Nexn', 15),
#   ('Hmga2', 29),
#   ('Eid2b', 11),
#   ('Kctd12b', 14),
#   ('Fndc1', 35),
#   ('Clstn3', 11),
#   ('Zc3h6', 27),
#   ('Icam2', 193),
#   ('Sdc1', 278),
#   ('Tinagl1', 383),
#   ('Wwox', 107),
#   ('Sdpr', 351),
#   ('Ces1d', 442),
#   ('Gypc', 139),
#   ('Spef1', 44),
#   ('Fam150b', 223),
#   ('Ndn', 175),
#   ('Vtn', 169),
#   ('LOC545261', 85),
#   ('Plekhf1', 161),
#   ('G0s2', 104),
#   ('Tnxb', 260),
#   ('Trib2', 108),
#   ('Krt17', 401),
#   ('Dmxl2', 101),
#   ('Ptpn13', 55),
#   ('E530011L22Rik', 91),
#   ('Odz3', 35),
#   ('Ccl11', 326),
#   ('Igf2bp2', 32),
#   ('Bnc2', 45),
#   ('Spock2', 53),
#   ('Plscr2', 133),
#   ('Timp4', 237),
#   ('Serpinc1', 18),
#   ('Setd4', 17),
#   ('Elf3', 221),
#   ('Efhc1', 16),
#   ('Mn1', 193),
#   ('Mkrn2', 15),
#   ('Tshz2', 70),
#   ('Rrp1b', 27),
#   ('Spon1', 189),
#   ('Gng11', 311),
#   ('Cdkn2b', 81),
#   ('Stradb', 37),
#   ('Esrp1', 13),
#   ('Pecr', 30),
#   ('Csl', 9),
#   ('Ankrd46', 38),
#   ('Stambp', 38),
#   ('BC051019', 27),
#   ('Pigz', 31),
#   ('Bace1', 182),
#   ('Pcolce', 404),
#   ('Lipt2', 31),
#   ('Hist1h3a', 9),
#   ('Fcrl1', 9),
#   ('Pter', 17),
#   ('Ebf2', 16),
#   ('Cpne8', 82),
#   ('Atp1a2', 89),
#   ('Tsku', 9),
#   ('Gfpt2', 292),
#   ('Ces2g', 127),
#   ('Porcn', 162),
#   ('1700023L04Rik', 9),
#   ('Hyal2', 152),
#   ('Iqcc', 64),
#   ('2410004P03Rik', 64),
#   ('Ina', 70),
#   ('Ftsj1', 125),
#   ('Sec14l3', 87),
#   ...]}

# %%
all_genes_nr = list(set(all_genes_redundant))

# %%
len(all_genes_nr)
# Out:
# 8995

# %%
out = []
for gene in all_genes_nr:
    out.append([gene, all_genes_redundant.count(gene)])

# %%
mcs = pd.DataFrame(out, columns = ['gene', 'Count']).sort_values('Count', ascending = False)
mcs
# Out:
#          gene  Count
# 4931   Hba-a1     28
# 5025   Hbb-b1     20
# 7108  Gm11428     18
# 2248     Saa3     18
# 8142    Vsig4     17
# ...       ...    ...
# 4976     Myot      1
# 4974    Syt15      1
# 4969    Ap1s3      1
# 4968    Msrb2      1
# 0       Stim2      1
#
# [8995 rows x 2 columns]

# %%
all_genes_redundant.count('Cdkn2a')
# Out:
# 12

# %%
#random distribution of gene commonality counts. ie, how many hubs were a gene in by chance

out = []
for x in tqdm(range(10000)):
    
    all_genes_redundant_temp = []
    for y in range(len(sig_metadata)):
        s = sig_metadata.iloc[y].size
        l = random.choices(adata.var_names, k = s)
        all_genes_redundant_temp += l
            
    all_genes_nr_temp = list(set(all_genes_redundant_temp))
    

    for gene in all_genes_nr_temp:
        out += [all_genes_redundant.count(gene)]

# %%
out = np.array(out)

# %%
mcs['p'] = mcs['Count'].map(calc_mcg_p)

# %%
mcs

# %%
mcs['nlogp'] = -np.log10(mcs.p)
mcs['prev'] = mcs.Count/len(signatures) * 100

# %%
#mcs.to_pickle('../data/files/5.1_mcs.pickle')

# %%
mcs = pd.read_pickle('../data/files/5.1_mcs.pickle')

# %%
mcs
# Out:
#                gene  Count         p     nlogp       prev
# 5789         Hba-a1     28  0.000052  4.282177  59.574468
# 6950         Hbb-b1     20  0.000098  4.008701  42.553191
# 5926        Gm11428     18  0.000192  3.717258  38.297872
# 5492           Saa3     18  0.000192  3.717258  38.297872
# 1905          Vsig4     17  0.000241  3.617257  36.170213
# ...             ...    ...       ...       ...        ...
# 5681       Hepacam2      1  0.446561  0.350119   2.127660
# 5679       BC049762      1  0.446561  0.350119   2.127660
# 2410  A330076H08Rik      1  0.446561  0.350119   2.127660
# 5677         Scn2a1      1  0.446561  0.350119   2.127660
# 0             Dmbt1      1  0.446561  0.350119   2.127660
#
# [8995 rows x 5 columns]

# %%
mcs[mcs.p < 0.05]
# Out:
#          gene  Count         p     nlogp       prev
# 5789   Hba-a1     28  0.000052  4.282177  59.574468
# 6950   Hbb-b1     20  0.000098  4.008701  42.553191
# 5926  Gm11428     18  0.000192  3.717258  38.297872
# 5492     Saa3     18  0.000192  3.717258  38.297872
# 1905    Vsig4     17  0.000241  3.617257  36.170213
# ...       ...    ...       ...       ...        ...
# 5350      F10      5  0.033264  1.478020  10.638298
# 8452    H2-Ob      5  0.033264  1.478020  10.638298
# 2409     Mgl2      5  0.033264  1.478020  10.638298
# 5205      Src      5  0.033264  1.478020  10.638298
# 4639     Scgn      5  0.033264  1.478020  10.638298
#
# [671 rows x 5 columns]

# %%
len(mcs[mcs.prev > 25])
# Out:
# 29

# %%
mcs[mcs.p < 0.01]
# Out:
#                gene  Count         p     nlogp       prev
# 5789         Hba-a1     28  0.000052  4.282177  59.574468
# 6950         Hbb-b1     20  0.000098  4.008701  42.553191
# 5926        Gm11428     18  0.000192  3.717258  38.297872
# 5492           Saa3     18  0.000192  3.717258  38.297872
# 1905          Vsig4     17  0.000241  3.617257  36.170213
# ...             ...    ...       ...       ...        ...
# 6831         Beta-s      8  0.006980  2.156136  17.021277
# 2529  2200002D01Rik      8  0.006980  2.156136  17.021277
# 8842          Wdfy4      8  0.006980  2.156136  17.021277
# 4142           Penk      8  0.006980  2.156136  17.021277
# 7107          Myct1      8  0.006980  2.156136  17.021277
#
# [141 rows x 5 columns]

# %%
mcs[mcs.p <= 0.05]
# Out:
#          gene  Count         p     nlogp       prev
# 5789   Hba-a1     28  0.000052  4.282177  59.574468
# 6950   Hbb-b1     20  0.000098  4.008701  42.553191
# 5926  Gm11428     18  0.000192  3.717258  38.297872
# 5492     Saa3     18  0.000192  3.717258  38.297872
# 1905    Vsig4     17  0.000241  3.617257  36.170213
# ...       ...    ...       ...       ...        ...
# 5350      F10      5  0.033264  1.478020  10.638298
# 8452    H2-Ob      5  0.033264  1.478020  10.638298
# 2409     Mgl2      5  0.033264  1.478020  10.638298
# 5205      Src      5  0.033264  1.478020  10.638298
# 4639     Scgn      5  0.033264  1.478020  10.638298
#
# [671 rows x 5 columns]

# %%
sub = mcs[:30]

#these are the stats for 3% chance based on the data
new_row = {'gene': '3% chance', 'Count': 5, 'p': 0.033264, 'nlogp':1.478, 'prev':10.6}

# append the new row to the DataFrame
#sub = sub.append(new_row, ignore_index=True)
sub = pd.concat((sub, pd.DataFrame([new_row])))

# %%
mcs
# Out:
#                gene  Count         p     nlogp       prev
# 5789         Hba-a1     28  0.000052  4.282177  59.574468
# 6950         Hbb-b1     20  0.000098  4.008701  42.553191
# 5926        Gm11428     18  0.000192  3.717258  38.297872
# 5492           Saa3     18  0.000192  3.717258  38.297872
# 1905          Vsig4     17  0.000241  3.617257  36.170213
# ...             ...    ...       ...       ...        ...
# 5681       Hepacam2      1  0.446561  0.350119   2.127660
# 5679       BC049762      1  0.446561  0.350119   2.127660
# 2410  A330076H08Rik      1  0.446561  0.350119   2.127660
# 5677         Scn2a1      1  0.446561  0.350119   2.127660
# 0             Dmbt1      1  0.446561  0.350119   2.127660
#
# [8995 rows x 5 columns]

# %% [markdown]
# ### Fig 4A

# %%
import matplotlib as mpl
from matplotlib import cm

fig, ax = plt.subplots(figsize = (0.3, 2))

cmap = mpl.cm.cool
#norm = mpl.colors.Normalize(vmin = sub.p.min(), vmax = sub.p.max())
norm = mpl.colors.Normalize(vmin = sub.nlogp.min(), vmax = sub.nlogp.max())

mapper = cm.ScalarMappable(norm = norm, cmap = cm.cool)

cbl = mpl.colorbar.ColorbarBase(ax, cmap = cmap, norm = norm, orientation = 'vertical')

plt.savefig('figures/4A_pt2.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4A_pt2.svg', bbox_inches = 'tight')

# %%
plt.figure(figsize = (2.5,6.2))

ax = sns.barplot(data = sub, x = 'prev', y = 'gene', palette = mapper.to_rgba(sub.nlogp.values),
                edgecolor = 'k', lw = 1.5)

plt.yticks(size = 11, weight = 'bold')
plt.xticks(size = 11, weight = 'bold')


for axis in ['bottom', 'left', 'top', 'right']:
    ax.spines[axis].set_linewidth(1.5)
    
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)

ax.tick_params(width = 1.5, color = '0.2')


plt.xlabel("Signature prevalence (%)", size = 11, weight = 'bold')
plt.ylabel('')


plt.savefig('figures/4A_pt1.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4A_pt1.svg', bbox_inches = 'tight')

plt.show()
# Out:
# /tmp/ipykernel_1733770/1889167768.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data = sub, x = 'prev', y = 'gene', palette = mapper.to_rgba(sub.nlogp.values),
# /tmp/ipykernel_1733770/1889167768.py:3: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   ax = sns.barplot(data = sub, x = 'prev', y = 'gene', palette = mapper.to_rgba(sub.nlogp.values),

# %%
mcs[mcs.p < 0.01]
# Out:
#                gene  Count         p     nlogp       prev
# 5789         Hba-a1     28  0.000052  4.282177  59.574468
# 6950         Hbb-b1     20  0.000098  4.008701  42.553191
# 5926        Gm11428     18  0.000192  3.717258  38.297872
# 5492           Saa3     18  0.000192  3.717258  38.297872
# 1905          Vsig4     17  0.000241  3.617257  36.170213
# ...             ...    ...       ...       ...        ...
# 6831         Beta-s      8  0.006980  2.156136  17.021277
# 2529  2200002D01Rik      8  0.006980  2.156136  17.021277
# 8842          Wdfy4      8  0.006980  2.156136  17.021277
# 4142           Penk      8  0.006980  2.156136  17.021277
# 7107          Myct1      8  0.006980  2.156136  17.021277
#
# [141 rows x 5 columns]

# %%
enr = gp.enrichr(gene_list= mcs[mcs.p < 0.01].gene,
             gene_sets=['KEGG_2019_Mouse', 'GO_Biological_Process_2021', 'WikiPathways_2019_Mouse'],
             organism='mouse', # don't forget to set organism to the one you desired!
             outdir=None, # don't write to disk,
             background = adata.var_names.tolist()
            )

# %%
uni_enr = enr.results

# %%
uni_enr = uni_enr[uni_enr['Adjusted P-value'] < 0.05][0:15]

uni_enr['nlog10'] = -np.log10(uni_enr['Adjusted P-value'])
uni_enr
# Out:
#            Gene_set                                       Term       P-value  \
# 0   KEGG_2019_Mouse     Cytokine-cytokine receptor interaction  2.886228e-12
# 1   KEGG_2019_Mouse                    African trypanosomiasis  4.083353e-09
# 2   KEGG_2019_Mouse                                    Malaria  3.048143e-08
# 3   KEGG_2019_Mouse               NF-kappa B signaling pathway  2.484465e-07
# 4   KEGG_2019_Mouse                Chemokine signaling pathway  4.678444e-07
# 5   KEGG_2019_Mouse                       Rheumatoid arthritis  1.905764e-06
# 6   KEGG_2019_Mouse            Staphylococcus aureus infection  2.329241e-06
# 7   KEGG_2019_Mouse        NOD-like receptor signaling pathway  1.380491e-05
# 8   KEGG_2019_Mouse    Transcriptional misregulation in cancer  3.178576e-05
# 9   KEGG_2019_Mouse                 Hematopoietic cell lineage  3.376664e-05
# 10  KEGG_2019_Mouse                  Graft-versus-host disease  3.449951e-05
# 11  KEGG_2019_Mouse    Human T-cell leukemia virus 1 infection  3.739444e-05
# 12  KEGG_2019_Mouse                                  Apoptosis  4.922408e-05
# 13  KEGG_2019_Mouse  Chagas disease (American trypanosomiasis)  8.723770e-05
# 14  KEGG_2019_Mouse                              Leishmaniasis  9.988060e-05
#
#     Adjusted P-value  Old P-value  Old adjusted P-value  Odds Ratio  \
# 0       3.550060e-10            0                     0   11.369240
# 1       2.511262e-07            0                     0   37.214552
# 2       1.249739e-06            0                     0   26.703406
# 3       7.639731e-06            0                     0   14.415799
# 4       1.150897e-05            0                     0    9.109261
# 5       3.906816e-05            0                     0   13.677632
# 6       4.092809e-05            0                     0   18.073469
# 7       2.122505e-04            0                     0    8.113345
# 8       3.832930e-04            0                     0    7.177824
# 9       3.832930e-04            0                     0   10.915775
# 10      3.832930e-04            0                     0   15.262714
# 11      3.832930e-04            0                     0    6.066646
# 12      4.657355e-04            0                     0    8.036677
# 13      7.664455e-04            0                     0    9.107904
# 14      8.190209e-04            0                     0   12.002170
#
#     Combined Score                                              Genes  \
# 0       302.092870  CCL22;CSF2RB;TNFRSF13C;CXCR6;CXCL13;TNF;CSF2RB...
# 1       718.849223           IL6;IL1B;HBB-B2;HBB-B1;HBA-A2;HBA-A1;TNF
# 2       462.133099           IL6;IL1B;HBB-B2;HBB-B1;HBA-A2;HBA-A1;TNF
# 3       219.236014   IL1B;TNFRSF13C;BCL2A1D;TRAF1;LTB;TNF;BCL2A1B;LAT
# 4       132.768670  CCL9;CCL8;CCL22;CCL7;CCL5;CXCR3;CCL3;CXCR6;CXC...
# 5       180.142992                 IL6;IL1B;H2-DMB1;CCL5;CCL3;LTB;TNF
# 6       234.412323                  C4B;H2-DMB1;FPR1;FPR2;FCGR2B;CAMP
# 7        90.792272          PSTPIP1;IL6;CCL5;IL1B;CASP4;CYBB;TNF;CAMP
# 8        74.337078     LYL1;IL6;CEBPE;BCL2A1D;TRAF1;BCL2A1B;MPO;ELANE
# 9       112.389226                    IL6;IL1B;H2-DMB1;CD3G;TNF;MS4A1
# 10      156.817756                         IL6;H2-Q8;IL1B;H2-DMB1;TNF
# 11       61.843322  CCNB2;CDKN2B;IL6;H2-Q8;CDKN2A;H2-DMB1;CD3G;TNF...
# 12       79.716826     CSF2RB2;BIRC5;CSF2RB;BCL2A1D;TRAF1;TNF;BCL2A1B
# 13       85.130428                        IL6;IL1B;CCL5;CCL3;CD3G;TNF
# 14      110.558408                         IL1B;H2-DMB1;NCF4;CYBB;TNF
#
#       nlog10
# 0   9.449764
# 1   6.600108
# 2   5.903181
# 3   5.116922
# 4   4.938963
# 5   4.408177
# 6   4.387979
# 7   3.673151
# 8   3.416469
# 9   3.416469
# 10  3.416469
# 11  3.416469
# 12  3.331861
# 13  3.115519
# 14  3.086705

# %% [markdown]
# ### Fig 4B

# %%
plt.figure(figsize = (3,3.5))

ax = sns.barplot(data = uni_enr, x = 'nlog10', y = 'Term', color = 'grey',
                edgecolor = 'k', lw = 1)

plt.ylabel('')
plt.xlabel("-$log_{10}$ FDR", size = 12)


plt.savefig('figures/4B.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4B.svg', bbox_inches = 'tight')

plt.show()

# %% [markdown]
# # Universal TF

# %%
mm10 = SeqIO.to_dict(SeqIO.parse('scripts/tf/mm10.fa', 'fasta'))

# %%
#convert hub list to \n sep string
seq_str = ''
for item in mcs[mcs.p < 0.01].gene:
    seq_str += str(item) + '\n'

#pass that string to this R script which returns a gene region df
child = subprocess.Popen(['scripts/tf/sym_to_reg.R'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.DEVNULL)
child.stdin.write(seq_str.encode())
child_out = child.communicate()[0].decode('utf8')
a = StringIO(child_out)
child.stdin.close()

#read the region df and slice up mm10 into a multi seq fasta
a = pd.read_csv(a).dropna().reset_index(drop = True)
a['slice_start'] = a['slice_start'].astype('int')
a['slice_end'] = a['slice_end'].astype('int')

outfa = []
for row in a.index:
    values = a.iloc[row]
    record = mm10[values.TXCHROM][values.slice_start - 1:values.slice_end -1]
    record.id = values.symbol

    outfa.append(record)


with open('tmpdir/test.fasta', 'w') as f:
    for seq in outfa:
        f.write( '>' + seq.id + '\n')
        f.write(str(seq.seq) + '\n')


#process fasta with meme sea     
child = subprocess.Popen(['sea', '--p', 'tmpdir/test.fasta', '--m',
                      'scripts/tf/JASPAR2020_CORE_vertebrates_non-redundant_pfms_meme.txt', 
                      '--text'], stdout=subprocess.PIPE, stderr=subprocess.DEVNULL)
child_out = child.communicate()[0].decode('utf8')
a = StringIO(child_out)
a = pd.read_csv(a, delimiter='\t').dropna().drop(columns = ['DB'])

# %%
out = []


for hub in tqdm(list(signatures)):

    test = signatures[hub]

    test = [x[0] for x in test]


    for i in range(0,10):
        try:
            enr = gp.enrichr(gene_list= test,
                         gene_sets=['KEGG_2019_Mouse', 'GO_Biological_Process_2021', 'WikiPathways_2019_Mouse'],
                         organism='mouse', # don't forget to set organism to the one you desired!
                         outdir=None, # don't write to disk,
                         background = adata.var_names.tolist()
                        )
            break
        except:
            pass
        

    res = enr.results

    res = res[res['Adjusted P-value'] <= 0.05].reset_index(drop = True)
    
    
    res['tissue'] = hub[0]
    res['cell'] = hub[1]
    
    out.append(res)
# Out:
# 100%|███████████████████████████████████████████| 47/47 [01:19<00:00,  1.68s/it]

# %%
#redundant and non-relevant, eg., malaria
redundant = ['Malaria', 'African trypanosomiasis', 'chemokine-mediated signaling pathway (GO:0070098)',
             'granulocyte chemotaxis (GO:0071621)', 
             'Rheumatoid arthritis', 'cellular response to chemokine (GO:1990869)', 
             'Autoimmune thyroid disease', 'Graft-versus-host disease', 'Type I diabetes mellitus',
            'Viral myocarditis', 'Leishmaniasis', 'Allograft rejection', 'Human T-cell leukemia virus 1 infection',
            'Epstein-Barr virus infection', 'neutrophil chemotaxis (GO:0030593)', 'neutrophil activation involved in immune response (GO:0002283)',
            'lymphocyte migration (GO:0072676)', 'cytokine-mediated signaling pathway (GO:0019221)']

# %%
df = pd.concat(out)

df = df[df.Gene_set != 'WikiPathways_2019_Mouse'] #some redundancy with GO

top_20 = df.groupby('Term').count().sort_values('Gene_set', ascending = False)

top_20 = top_20[~top_20.index.isin(redundant)][0:20]

order_d = dict(zip(top_20.index, range(20)))

overlap_d = dict(zip(top_20.index, top_20.Gene_set))

top_20
# Out:
#                                                     Gene_set  P-value  \
# Term
# Cytokine-cytokine receptor interaction                    21       21
# neutrophil migration (GO:1990266)                         17       17
# inflammatory response (GO:0006954)                        16       16
# regulation of immune response (GO:0050776)                15       15
# Hematopoietic cell lineage                                15       15
# positive regulation of MAPK cascade (GO:0043410)          14       14
# Chemokine signaling pathway                               14       14
# lymphocyte chemotaxis (GO:0048247)                        13       13
# Cell adhesion molecules (CAMs)                            13       13
# neutrophil mediated immunity (GO:0002446)                 12       12
# response to interferon-gamma (GO:0034341)                 12       12
# regulation of inflammatory response (GO:0050727)          11       11
# monocyte chemotaxis (GO:0002548)                          11       11
# negative regulation of lymphocyte proliferation...        11       11
# Staphylococcus aureus infection                           11       11
# innate immune response (GO:0045087)                       11       11
# positive regulation of ERK1 and ERK2 cascade (G...        11       11
# Phagosome                                                 11       11
# regulation of T cell proliferation (GO:0042129)           10       10
# NF-kappa B signaling pathway                              10       10
#
#                                                     Adjusted P-value  \
# Term
# Cytokine-cytokine receptor interaction                            21
# neutrophil migration (GO:1990266)                                 17
# inflammatory response (GO:0006954)                                16
# regulation of immune response (GO:0050776)                        15
# Hematopoietic cell lineage                                        15
# positive regulation of MAPK cascade (GO:0043410)                  14
# Chemokine signaling pathway                                       14
# lymphocyte chemotaxis (GO:0048247)                                13
# Cell adhesion molecules (CAMs)                                    13
# neutrophil mediated immunity (GO:0002446)                         12
# response to interferon-gamma (GO:0034341)                         12
# regulation of inflammatory response (GO:0050727)                  11
# monocyte chemotaxis (GO:0002548)                                  11
# negative regulation of lymphocyte proliferation...                11
# Staphylococcus aureus infection                                   11
# innate immune response (GO:0045087)                               11
# positive regulation of ERK1 and ERK2 cascade (G...                11
# Phagosome                                                         11
# regulation of T cell proliferation (GO:0042129)                   10
# NF-kappa B signaling pathway                                      10
#
#                                                     Old P-value  \
# Term
# Cytokine-cytokine receptor interaction                       21
# neutrophil migration (GO:1990266)                            17
# inflammatory response (GO:0006954)                           16
# regulation of immune response (GO:0050776)                   15
# Hematopoietic cell lineage                                   15
# positive regulation of MAPK cascade (GO:0043410)             14
# Chemokine signaling pathway                                  14
# lymphocyte chemotaxis (GO:0048247)                           13
# Cell adhesion molecules (CAMs)                               13
# neutrophil mediated immunity (GO:0002446)                    12
# response to interferon-gamma (GO:0034341)                    12
# regulation of inflammatory response (GO:0050727)             11
# monocyte chemotaxis (GO:0002548)                             11
# negative regulation of lymphocyte proliferation...           11
# Staphylococcus aureus infection                              11
# innate immune response (GO:0045087)                          11
# positive regulation of ERK1 and ERK2 cascade (G...           11
# Phagosome                                                    11
# regulation of T cell proliferation (GO:0042129)              10
# NF-kappa B signaling pathway                                 10
#
#                                                     Old adjusted P-value  \
# Term
# Cytokine-cytokine receptor interaction                                21
# neutrophil migration (GO:1990266)                                     17
# inflammatory response (GO:0006954)                                    16
# regulation of immune response (GO:0050776)                            15
# Hematopoietic cell lineage                                            15
# positive regulation of MAPK cascade (GO:0043410)                      14
# Chemokine signaling pathway                                           14
# lymphocyte chemotaxis (GO:0048247)                                    13
# Cell adhesion molecules (CAMs)                                        13
# neutrophil mediated immunity (GO:0002446)                             12
# response to interferon-gamma (GO:0034341)                             12
# regulation of inflammatory response (GO:0050727)                      11
# monocyte chemotaxis (GO:0002548)                                      11
# negative regulation of lymphocyte proliferation...                    11
# Staphylococcus aureus infection                                       11
# innate immune response (GO:0045087)                                   11
# positive regulation of ERK1 and ERK2 cascade (G...                    11
# Phagosome                                                             11
# regulation of T cell proliferation (GO:0042129)                       10
# NF-kappa B signaling pathway                                          10
#
#                                                     Odds Ratio  \
# Term
# Cytokine-cytokine receptor interaction                      21
# neutrophil migration (GO:1990266)                           17
# inflammatory response (GO:0006954)                          16
# regulation of immune response (GO:0050776)                  15
# Hematopoietic cell lineage                                  15
# positive regulation of MAPK cascade (GO:0043410)            14
# Chemokine signaling pathway                                 14
# lymphocyte chemotaxis (GO:0048247)                          13
# Cell adhesion molecules (CAMs)                              13
# neutrophil mediated immunity (GO:0002446)                   12
# response to interferon-gamma (GO:0034341)                   12
# regulation of inflammatory response (GO:0050727)            11
# monocyte chemotaxis (GO:0002548)                            11
# negative regulation of lymphocyte proliferation...          11
# Staphylococcus aureus infection                             11
# innate immune response (GO:0045087)                         11
# positive regulation of ERK1 and ERK2 cascade (G...          11
# Phagosome                                                   11
# regulation of T cell proliferation (GO:0042129)             10
# NF-kappa B signaling pathway                                10
#
#                                                     Combined Score  Genes  \
# Term
# Cytokine-cytokine receptor interaction                          21     21
# neutrophil migration (GO:1990266)                               17     17
# inflammatory response (GO:0006954)                              16     16
# regulation of immune response (GO:0050776)                      15     15
# Hematopoietic cell lineage                                      15     15
# positive regulation of MAPK cascade (GO:0043410)                14     14
# Chemokine signaling pathway                                     14     14
# lymphocyte chemotaxis (GO:0048247)                              13     13
# Cell adhesion molecules (CAMs)                                  13     13
# neutrophil mediated immunity (GO:0002446)                       12     12
# response to interferon-gamma (GO:0034341)                       12     12
# regulation of inflammatory response (GO:0050727)                11     11
# monocyte chemotaxis (GO:0002548)                                11     11
# negative regulation of lymphocyte proliferation...              11     11
# Staphylococcus aureus infection                                 11     11
# innate immune response (GO:0045087)                             11     11
# positive regulation of ERK1 and ERK2 cascade (G...              11     11
# Phagosome                                                       11     11
# regulation of T cell proliferation (GO:0042129)                 10     10
# NF-kappa B signaling pathway                                    10     10
#
#                                                     tissue  cell
# Term
# Cytokine-cytokine receptor interaction                  21    21
# neutrophil migration (GO:1990266)                       17    17
# inflammatory response (GO:0006954)                      16    16
# regulation of immune response (GO:0050776)              15    15
# Hematopoietic cell lineage                              15    15
# positive regulation of MAPK cascade (GO:0043410)        14    14
# Chemokine signaling pathway                             14    14
# lymphocyte chemotaxis (GO:0048247)                      13    13
# Cell adhesion molecules (CAMs)                          13    13
# neutrophil mediated immunity (GO:0002446)               12    12
# response to interferon-gamma (GO:0034341)               12    12
# regulation of inflammatory response (GO:0050727)        11    11
# monocyte chemotaxis (GO:0002548)                        11    11
# negative regulation of lymphocyte proliferation...      11    11
# Staphylococcus aureus infection                         11    11
# innate immune response (GO:0045087)                     11    11
# positive regulation of ERK1 and ERK2 cascade (G...      11    11
# Phagosome                                               11    11
# regulation of T cell proliferation (GO:0042129)         10    10
# NF-kappa B signaling pathway                            10    10

# %%
to_graph = df[df.Term.isin(top_20.index)]


to_graph['nlog10p'] = -np.log10(to_graph['Adjusted P-value'])

to_graph['Orderer'] = to_graph.Term.map(order_d)

to_graph = to_graph.sort_values('Orderer')


to_graph['Overlap'] = to_graph.Term.map(overlap_d)

to_graph['frac'] = to_graph['Overlap']/len(hubs) * 100

to_graph
# Out:
# /tmp/ipykernel_1733770/1837146506.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['nlog10p'] = -np.log10(to_graph['Adjusted P-value'])
# /tmp/ipykernel_1733770/1837146506.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['Orderer'] = to_graph.Term.map(order_d)
#            Gene_set                                    Term       P-value  \
# 2   KEGG_2019_Mouse  Cytokine-cytokine receptor interaction  4.270216e-04
# 2   KEGG_2019_Mouse  Cytokine-cytokine receptor interaction  4.151927e-10
# 1   KEGG_2019_Mouse  Cytokine-cytokine receptor interaction  8.644038e-05
# 5   KEGG_2019_Mouse  Cytokine-cytokine receptor interaction  3.153715e-04
# 0   KEGG_2019_Mouse  Cytokine-cytokine receptor interaction  3.799487e-14
# ..              ...                                     ...           ...
# 24  KEGG_2019_Mouse            NF-kappa B signaling pathway  4.798907e-04
# 7   KEGG_2019_Mouse            NF-kappa B signaling pathway  2.225762e-04
# 14  KEGG_2019_Mouse            NF-kappa B signaling pathway  2.154410e-06
# 15  KEGG_2019_Mouse            NF-kappa B signaling pathway  2.391661e-03
# 13  KEGG_2019_Mouse            NF-kappa B signaling pathway  1.394231e-05
#
#     Adjusted P-value  Old P-value  Old adjusted P-value  Odds Ratio  \
# 2       4.156344e-02            0                     0    1.860754
# 2       2.574195e-08            0                     0    7.428679
# 1       7.094416e-03            0                     0    2.616694
# 5       1.455965e-02            0                     0    2.214873
# 0       8.776816e-12            0                     0    5.644140
# ..               ...          ...                   ...         ...
# 24      3.570387e-03            0                     0    6.565700
# 7       6.110313e-03            0                     0    4.363335
# 14      3.375242e-05            0                     0    5.688596
# 15      4.140563e-02            0                     0    2.821486
# 13      2.529534e-04            0                     0    4.444496
#
#     Combined Score                                              Genes  \
# 2        14.436984  CNTFR;CCL12;CSF3;CCL11;CSF1;CXCR5;CXCL17;IL20R...
# 2       160.476400  CCL22;TNFSF13;CSF2RB;TNFRSF1B;CXCL3;IL2RG;CXCL...
# 1        24.481938  IL10;CD40;CCL11;CCL22;IL34;TNFRSF13C;INHBA;CXC...
# 5        17.855774  ACVRL1;CSF1R;EDA;CSF1;CXCL1;IL2RG;EDA2R;CCL9;C...
# 0       174.411391  CNTFR;CCL12;CXCL9;CCL11;MPL;CXCL17;IL20RB;CSF2...
# ..             ...                                                ...
# 24       50.174766                VCAM1;BCL2A1D;TRAF1;LTB;TNF;BCL2A1B
# 7        36.696699  GM1987;SYK;PRKCB;TNFRSF11A;TNFRSF13C;LTB;TNF;C...
# 14       74.224771  SYK;PRKCB;TNFRSF13C;TRAF1;TNFSF13B;ZAP70;CXCL1...
# 15       17.029830  SYK;IL1R1;DDX58;IL1B;PLCG2;TNFAIP3;CD14;BCL2A1...
# 13       49.692051  SYK;TNFRSF13C;TRAF1;PTGS2;CXCL2;IL1B;TRAF5;PLC...
#
#              tissue                                        cell    nlog10p  \
# 2           Trachea                                  macrophage   1.381289
# 2            Tongue                                keratinocyte   7.589359
# 1   Heart_and_Aorta                                     myocyte   2.149083
# 5            Kidney  Henle thick ascending limb epithelial cell   1.836849
# 0   Heart_and_Aorta                            endocardial cell  11.056663
# ..              ...                                         ...        ...
# 24           Tongue                                keratinocyte   2.447285
# 7   Heart_and_Aorta                            endocardial cell   2.213937
# 14          Trachea                                 basal cell    4.471695
# 15           Kidney  Henle thick ascending limb epithelial cell   1.382941
# 13             Lung                                  fibroblast   3.596959
#
#     Orderer  Overlap       frac
# 2         0       21  28.000000
# 2         0       21  28.000000
# 1         0       21  28.000000
# 5         0       21  28.000000
# 0         0       21  28.000000
# ..      ...      ...        ...
# 24       19       10  13.333333
# 7        19       10  13.333333
# 14       19       10  13.333333
# 15       19       10  13.333333
# 13       19       10  13.333333
#
# [259 rows x 15 columns]

# %%
#removing GO label to save space
def fix_term(x):
    if '(GO:' in x:
        return ' '.join(x.split(' ')[0:-1])
                        
    if x.split(' ')[-1].startswith('WP'):
        return ' '.join(x.split(' ')[0:-1])
                        
    else:
        return x
    
to_graph['term2'] = to_graph.Term.map(fix_term)

# %%
to_graph['Class'] = to_graph.cell.map(class_d)

# %% [markdown]
# ### Fig 4C

# %%
plt.figure(figsize = (4, 7))

#ax = sns.barplot(data = to_graph, x = 'nlog10p', y = 'term2', color = 'grey',
#                capsize = 0.5, lw = 1.5, errwidth = 0)


kwargs = {'edgecolor':'k', 'linewidth':0.75}

ax = sns.stripplot(data = to_graph, x = 'nlog10p', y = 'term2', s = 7, **kwargs,
                  hue = 'Class', jitter = .25,
                  hue_order = ['immune', 'endothelial', 'parenchymal', 'stromal', 'epithelial', 'progenitor'])



for x in range(len(top_20)):
#    plt.text(x = 0.1, y = x, s = str(round(top_20.iloc[x].Overlap/len(hubs),2)), va = 'center')
    ax.axhline(x, zorder = 0, ls = '--', c = 'k', alpha = 0.5, lw = 2.5)
    
    
ax.axvline(-np.log10(0.05), ls = '--', c = 'k', alpha = 0.5, lw = 2.5)

    
plt.xlim(left = 0)

ax.legend(bbox_to_anchor=(1, .4))



for axis in ['bottom', 'left', 'top', 'right']:
    ax.spines[axis].set_linewidth(2.5)


plt.xticks(size = 13, ha = 'center', weight = 'bold')
plt.yticks(size = 12, weight = 'bold')

ax.tick_params(width = 2.5)

plt.ylabel('')
plt.xlabel("-$log_{10}$ FDR", size = 15)

plt.ylim(top = -.6)

plt.savefig('figures/4C.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4C.svg', bbox_inches = 'tight')

plt.show()

# %% [markdown]
# # TF - signatures

# %%
out = []

for hub in tqdm(list(signatures)):
    
    #convert hub list to \n sep string
    seq_str = ''
    for item in [x[0] for x in signatures[hub]]:
        seq_str += str(item) + '\n'
    
    #pass that string to this R script which returns a gene region df
    child = subprocess.Popen(['scripts/tf/sym_to_reg.R'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.DEVNULL)
    child.stdin.write(seq_str.encode())
    child_out = child.communicate()[0].decode('utf8')
    a = StringIO(child_out)
    child.stdin.close()
    
    #read the region df and slice up mm10 into a multi seq fasta
    a = pd.read_csv(a).dropna().reset_index(drop = True)
    a['slice_start'] = a['slice_start'].astype('int')
    a['slice_end'] = a['slice_end'].astype('int')
    
    outfa = []
    for row in a.index:
        values = a.iloc[row]
        record = mm10[values.TXCHROM][values.slice_start - 1:values.slice_end -1]
        record.id = values.symbol

        outfa.append(record)
    
    
    with open('tmpdir/test.fasta', 'w') as f:
        for seq in outfa:
            f.write( '>' + seq.id + '\n')
            f.write(str(seq.seq) + '\n')
            
            
    #process fasta with meme sea     
    child = subprocess.Popen(['sea', '--p', 'tmpdir/test.fasta', '--m',
                          'scripts/tf/JASPAR2020_CORE_vertebrates_non-redundant_pfms_meme.txt', 
                          '--text'], stdout=subprocess.PIPE, stderr=subprocess.DEVNULL)
    child_out = child.communicate()[0].decode('utf8')
    a = StringIO(child_out)
    a = pd.read_csv(a, delimiter='\t').dropna().drop(columns = ['DB'])
    
    a['tissue'] = hub[0]
    a['cell'] = hub[1]
    
    out.append(a)
# Out:
#  23%|█████████▎                              | 11/47 [32:29<1:48:29, 180.83s/it]

# %%
a
# Out:
#     RANK        ID  ALT_ID             CONSENSUS     TP    TP%     FP    FP%  \
# 0      1  MA0073.1   RREB1  CCCCMAAMCAMCCMCMMMCV  897.0  56.92  348.0  22.08
# 1      2  MA0039.4    KLF4          NNCCCCACCCHN  927.0  58.82  400.0  25.38
# 2      3  MA0599.1    KLF5            GCCCCDCCCH  595.0  37.75  173.0  10.98
# 3      4  MA1107.2    KLF9      MNGCCACACCCACHYV  918.0  58.25  431.0  27.35
# 4      5  MA1513.1   KLF15           SCCCCGCCCCS  512.0  32.49  128.0   8.12
# ..   ...       ...     ...                   ...    ...    ...    ...    ...
# 329  330  MA0640.2    ELF3        NNCCACTTCCTGNT  430.0  27.28  374.0  23.73
# 330  331  MA0048.2   NHLH1            CGCAGCTGCK  292.0  18.53  244.0  15.48
# 331  332  MA0712.2    OTX2          NDRGGATTARNN  993.0  63.01  931.0  59.07
# 332  333  MA0699.1    LBX2            NCYAATTARN  264.0  16.75  218.0  13.83
# 333  334  MA0527.1  ZBTB33       BTCTCGCGAGABYTS  914.0  57.99  851.0  54.00
#
#      ENR_RATIO  SCORE_THR        PVALUE  LOG_PVALUE        EVALUE  LOG_EVALUE  \
# 0         2.57        4.7  2.520000e-91     -208.61  1.880000e-88     -201.99
# 1         2.31       10.0  2.440000e-82     -187.92  1.820000e-79     -181.30
# 2         3.43       12.0  1.390000e-71     -163.15  1.040000e-68     -156.54
# 3         2.13       10.0  4.640000e-70     -159.65  3.460000e-67     -153.03
# 4         3.98       14.0  2.330000e-68     -155.73  1.740000e-65     -149.11
# ..         ...        ...           ...         ...           ...         ...
# 329       1.15       11.0  1.230000e-02       -4.40  9.170000e+00        2.22
# 330       1.20       11.0  1.290000e-02       -4.35  9.620000e+00        2.26
# 331       1.07        8.0  1.290000e-02       -4.35  9.650000e+00        2.27
# 332       1.21       11.0  1.290000e-02       -4.35  9.650000e+00        2.27
# 333       1.07        5.3  1.300000e-02       -4.34  9.730000e+00        2.28
#
#            QVALUE  LOG_QVALUE   tissue        cell
# 0    8.470000e-89     -202.79  Trachea  macrophage
# 1    4.100000e-80     -182.80  Trachea  macrophage
# 2    1.560000e-69     -158.44  Trachea  macrophage
# 3    3.890000e-68     -155.22  Trachea  macrophage
# 4    1.570000e-66     -151.52  Trachea  macrophage
# ..            ...         ...      ...         ...
# 329  1.250000e-02       -4.38  Trachea  macrophage
# 330  1.300000e-02       -4.34  Trachea  macrophage
# 331  1.300000e-02       -4.34  Trachea  macrophage
# 332  1.300000e-02       -4.34  Trachea  macrophage
# 333  1.310000e-02       -4.33  Trachea  macrophage
#
# [334 rows x 18 columns]

# %%
tf = pd.concat(out)

# %%
#tf.to_pickle('../data/files/5.1_TMS_GENE_TF_ENRICHMENT_DF_SIGS.pickle')

# %%
tf = pd.read_pickle('../data/files/5.1_TMS_GENE_TF_ENRICHMENT_DF_SIGS.pickle')

# %%
tf = tf[tf.QVALUE < 0.05]

# %%
top_20 = tf.groupby('ALT_ID').count().sort_values('RANK', ascending = False)[0:20]

order_d = dict(zip(top_20.index, range(20)))

overlap_d = dict(zip(top_20.index, top_20.RANK))

top_20
# Out:
#         RANK  ID  CONSENSUS  TP  TP%  FP  FP%  ENR_RATIO  SCORE_THR  PVALUE  \
# ALT_ID
# RREB1     38  38         38  38   38  38   38         38         38      38
# KLF5      36  36         36  36   36  36   36         36         36      36
# Foxd3     35  35         35  35   35  35   35         35         35      35
# IRF1      34  34         34  34   34  34   34         34         34      34
# KLF4      34  34         34  34   34  34   34         34         34      34
# KLF15     32  32         32  32   32  32   32         32         32      32
# KLF9      32  32         32  32   32  32   32         32         32      32
# FOXC2     31  31         31  31   31  31   31         31         31      31
# SP2       31  31         31  31   31  31   31         31         31      31
# EGR1      31  31         31  31   31  31   31         31         31      31
# ZNF460    30  30         30  30   30  30   30         30         30      30
# PHOX2B    30  30         30  30   30  30   30         30         30      30
# ZNF148    30  30         30  30   30  30   30         30         30      30
# SP9       30  30         30  30   30  30   30         30         30      30
# Foxj3     30  30         30  30   30  30   30         30         30      30
# POU1F1    29  29         29  29   29  29   29         29         29      29
# SPI1      29  29         29  29   29  29   29         29         29      29
# FOXC1     29  29         29  29   29  29   29         29         29      29
# SP3       29  29         29  29   29  29   29         29         29      29
# KLF16     28  28         28  28   28  28   28         28         28      28
#
#         LOG_PVALUE  EVALUE  LOG_EVALUE  QVALUE  LOG_QVALUE  tissue  cell
# ALT_ID
# RREB1           38      38          38      38          38      38    38
# KLF5            36      36          36      36          36      36    36
# Foxd3           35      35          35      35          35      35    35
# IRF1            34      34          34      34          34      34    34
# KLF4            34      34          34      34          34      34    34
# KLF15           32      32          32      32          32      32    32
# KLF9            32      32          32      32          32      32    32
# FOXC2           31      31          31      31          31      31    31
# SP2             31      31          31      31          31      31    31
# EGR1            31      31          31      31          31      31    31
# ZNF460          30      30          30      30          30      30    30
# PHOX2B          30      30          30      30          30      30    30
# ZNF148          30      30          30      30          30      30    30
# SP9             30      30          30      30          30      30    30
# Foxj3           30      30          30      30          30      30    30
# POU1F1          29      29          29      29          29      29    29
# SPI1            29      29          29      29          29      29    29
# FOXC1           29      29          29      29          29      29    29
# SP3             29      29          29      29          29      29    29
# KLF16           28      28          28      28          28      28    28

# %%
to_graph = tf[tf.ALT_ID.isin(top_20.index)]


#to_graph['nlog10p'] = -np.log10(to_graph['Adjusted P-value'])

to_graph['Orderer'] = to_graph.ALT_ID.map(order_d)

to_graph = to_graph.sort_values('Orderer')


to_graph['Overlap'] = to_graph.ALT_ID.map(overlap_d)

to_graph['frac'] = to_graph['Overlap']/len(hubs) * 100

to_graph['Class'] = to_graph.cell.map(class_d)


to_graph
# Out:
# /tmp/ipykernel_1733770/4164331505.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['Orderer'] = to_graph.ALT_ID.map(order_d)
#    RANK        ID ALT_ID             CONSENSUS     TP    TP%     FP    FP%  \
# 3     4  MA0073.1  RREB1  CCCCMAAMCAMCCMCMMMCV   83.0  41.71   32.0  16.08
# 3     4  MA0073.1  RREB1  CCCCMAAMCAMCCMCMMMCV   18.0  20.22    1.0   1.12
# 2     3  MA0073.1  RREB1  CCCCMAAMCAMCCMCMMMCV   80.0  26.76   22.0   7.36
# 5     6  MA0073.1  RREB1  CCCCMAAMCAMCCMCMMMCV   32.0  76.19   13.0  30.95
# 5     6  MA0073.1  RREB1  CCCCMAAMCAMCCMCMMMCV   43.0  34.68    9.0   7.26
# ..  ...       ...    ...                   ...    ...    ...    ...    ...
# 7     8  MA0741.1  KLF16           GMCACGCCCCC  376.0  60.16  230.0  36.80
# 19   20  MA0741.1  KLF16           GMCACGCCCCC   49.0  59.04   29.0  34.94
# 9    10  MA0741.1  KLF16           GMCACGCCCCC  182.0  60.87  114.0  38.13
# 18   19  MA0741.1  KLF16           GMCACGCCCCC  155.0  23.66   60.0   9.16
# 47   48  MA0741.1  KLF16           GMCACGCCCCC  509.0  83.72  433.0  71.22
#
#     ENR_RATIO  SCORE_THR  ...        EVALUE  LOG_EVALUE        QVALUE  \
# 3        2.55        5.7  ...  8.090000e-06      -11.72  1.180000e-06
# 3        9.50       13.0  ...  1.210000e-02       -4.42  2.410000e-03
# 2        3.52        9.3  ...  8.220000e-08      -16.31  1.940000e-08
# 5        2.36        2.4  ...  1.180000e-01       -2.14  8.940000e-03
# 5        4.40        7.7  ...  4.170000e-05      -10.08  5.140000e-06
# ..        ...        ...  ...           ...         ...           ...
# 7        1.63        9.6  ...  6.240000e-14      -30.40  4.490000e-15
# 19       1.67       10.0  ...  1.120000e+00        0.12  4.040000e-02
# 9        1.59        9.4  ...  1.400000e-05      -11.18  9.860000e-07
# 18       2.56       12.0  ...  4.290000e-10      -21.57  1.170000e-11
# 47       1.18        7.0  ...  8.590000e-05       -9.36  1.070000e-06
#
#     LOG_QVALUE           tissue                            cell Orderer  \
# 3       -13.65              HSC         hematopoietic stem cell       0
# 3        -6.03             Skin                  epidermal cell       0
# 2       -17.76           Kidney                fenestrated cell       0
# 5        -4.72         Pancreas          pancreatic ductal cell       0
# 5       -12.18  Heart_and_Aorta              smooth muscle cell       0
# ..         ...              ...                             ...     ...
# 7       -33.04          Trachea                      fibroblast      19
# 19       -3.21              Fat           mesenchymal stem cell      19
# 9       -13.83           Kidney                fenestrated cell      19
# 18      -25.17             Lung                      fibroblast      19
# 47      -13.75        Diaphragm  skeletal muscle satellite cell      19
#
#    Overlap       frac        Class
# 3       38  50.666667   progenitor
# 3       38  50.666667  parenchymal
# 2       38  50.666667  endothelial
# 5       38  50.666667   epithelial
# 5       38  50.666667  parenchymal
# ..     ...        ...          ...
# 7       28  37.333333      stromal
# 19      28  37.333333   progenitor
# 9       28  37.333333  endothelial
# 18      28  37.333333      stromal
# 47      28  37.333333   progenitor
#
# [628 rows x 22 columns]

# %%
to_graph['ENR_RATIO'][to_graph['ENR_RATIO'] > 10] = 10 #because of a few high outliers, make sure to add >= on plot
# Out:
# /tmp/ipykernel_1733770/3884892461.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   to_graph['ENR_RATIO'][to_graph['ENR_RATIO'] > 10] = 10 #because of a few high outliers, make sure to add >= on plot
# /tmp/ipykernel_1733770/3884892461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_graph['ENR_RATIO'][to_graph['ENR_RATIO'] > 10] = 10 #because of a few high outliers, make sure to add >= on plot

# %% [markdown]
# ### Fig 4D

# %%
#note the few above 10 have been reduced to 10

plt.figure(figsize = (4, 7))

#ax = sns.barplot(data = to_graph, x = 'ENR_RATIO', y = 'ALT_ID', color = 'grey',
#                capsize = 0.5, lw = 1.5, errwidth = 0)


kwargs = {'edgecolor':'k', 'linewidth':0.75}

ax = sns.stripplot(data = to_graph, x = 'ENR_RATIO', y = 'ALT_ID', s = 7, **kwargs,
                  hue = 'Class', jitter = .25,
                  hue_order = ['immune', 'endothelial', 'parenchymal', 'stromal', 'epithelial', 'progenitor'])



for x in range(len(top_20)):
   # plt.text(x = 0.1, y = x, s = str(round(top_20.iloc[x].Overlap/len(hubs),2)), va = 'center')
    ax.axhline(x, zorder = 0, ls = '--', c = 'k', alpha = 0.5, lw = 2.5)

ax.axvline(1,zorder = 0, ls = '--', c = 'k', alpha = 0.5, lw = 2.5)
    
plt.xlim(left = 0)

ax.legend(bbox_to_anchor=(1, .4))



for axis in ['bottom', 'left', 'top', 'right']:
    ax.spines[axis].set_linewidth(2.5)


plt.xticks(size = 13, ha = 'center', weight = 'bold')
plt.yticks(size = 12, weight = 'bold')

ax.tick_params(width = 2.5)

plt.ylabel('')
plt.xlabel("Enrichment Ratio", size = 15)

plt.ylim(top = -.6)

plt.savefig('figures/4D.png', dpi = 600, bbox_inches = 'tight')
plt.savefig('figures/4D.svg', bbox_inches = 'tight')

plt.show()

# %%
test = tf.groupby('ALT_ID').count().sort_values('RANK', ascending = False)

test[test.RANK >= 24].shape #how TF with enriched in more than 50% of signatures
# Out:
# (46, 17)
